# %%
from utils.paths import ROOT, DATA_DIR, RAW_DIR, PROCESSED_DIR
from utils.save_data import save_prices, save_prices_grouped, save_eq_fundamental, save_org_economic

# %%
# Tech stocks from S&P500 index by sector filter.
tech_stocks = ['AAPL','NVDA','MSFT','AVGO','ORCL','CRM','CSCO','ACN','NOW','IBM','ADBE','AMD','PLTR','INTU','TXN','QCOM','ANET','AMAT','UBER','PANW','ADP','FI','ADI','MU','LRCX','CRWD','APH','INTC','KLAC','CDNS','DELL','MSI','SNPS','FTNT','ADSK','ROP','NXPI','FICO','PAYX','FIS','TEL','GLW','GRMN','CTSH','IT','HPQ','MCHP','ANSS','MPWR','GDDY','HPE','KEYS','ON','BR','TYL','FTV','NTAP','CPAY','CDW','PTC','TDY','WDC','TER','ZBRA','FSLR','LDOS','VRSN','SMCI','STX','TRMB','GEN','JBL','FFIV','AKAM','SWKS','EPAM','JKHY','JNPR','PAYC','DAY','ENPH','QRVO']
save_prices(tech_stocks, asset_class="equity", interval="1d")
save_prices_grouped(tech_stocks, "tech_stocks_us")
# Out:
# --- Processing these 82 Tickers | Type: equity | Timeframe: 1d ---
# Saving Prices (equity/1d):   1%|          | 1/82 [00:00<01:03,  1.28ticker/s]
# ✅ Saved AAPL At: /home/narodom.y@FUSION.LAB/research/data/raw/equity/1d/AAPL.csv
# Saving Prices (equity/1d):   2%|▏         | 2/82 [00:01<00:39,  2.02ticker/s]
# ✅ Saved NVDA At: /home/narodom.y@FUSION.LAB/research/data/raw/equity/1d/NVDA.csv
# Saving Prices (equity/1d):   4%|▎         | 3/82 [00:01<00:31,  2.49ticker/s]
# ✅ Saved MSFT At: /home/narodom.y@FUSION.LAB/research/data/raw/equity/1d/MSFT.csv
# Saving Prices (equity/1d):   5%|▍         | 4/82 [00:01<00:28,  2.78ticker/s]
# ✅ Saved AVGO At: /home/narodom.y@FUSION.LAB/research/data/raw/equity/1d/AVGO.csv
# Saving Prices (equity/1d):   6%|▌         | 5/82 [00:01<00:25,  3.06ticker/s]
# ✅ Saved ORCL At: /home/narodom.y@FUSION.LAB/research/data/raw/equity/1d/ORCL.csv
# Saving Prices (equity/1d):   7%|▋         | 6/82 [00:02<00:23,  3.28ticker/s]
# ...

# %%
# int means interest rates
organization = "fred"
group_name = "interest_rates"
int_tickers = ['DFF', 'DGS10'] 

org_int_df = save_org_economic(interest_rates_tickers, "interest_rates")
org_int_df
# Out:
# --- 💹 Processing: fred (DFF, DGS10) ---
# Loading data from 'fred'...
# Forward-filling FRED data (for weekends/holidays)...
# ✅ Saved 'fred' at: /home/narodom.y@FUSION.LAB/research/data/raw/economic/FRED_interest_rates.csv (3955 rows)
#              DFF  DGS10
# DATE
# 2015-01-01  0.06    NaN
# 2015-01-02  0.12   2.12
# 2015-01-03  0.12   2.12
# 2015-01-04  0.12   2.12
# 2015-01-05  0.12   2.04
# ...          ...    ...
# 2025-10-25  4.11   4.02
# 2025-10-26  4.11   4.02
# 2025-10-27  4.12   4.01
# 2025-10-28  4.12   3.99
# 2025-10-29  4.12   4.08
#
# [3955 rows x 2 columns]
