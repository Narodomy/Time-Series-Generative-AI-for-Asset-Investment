# %% [markdown]
# ## Import Libs

# %%
# import os
import pandas as pd
import numpy as np
import datetime as dt
import logging
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import seaborn as sns

from torch import optim
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm

from sklearn.preprocessing import MinMaxScaler
from torch.optim import AdamW
from utils import SklearnWrapper

# %%
from config import *
from entities import *
from components import *
from strategies import *
from datasets import *
from engine import Engine
from models import DiffusionTransformer
from frameworks import Diffusion

# %% [markdown]
# ## Setting

# %%
logging.basicConfig(level=logging.DEBUG)
logging.getLogger('matplotlib').setLevel(logging.WARNING)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Load Data to basket

# %%
symbols = ['AAPL', 'TSLA', 'MSFT', 'NVDA', 'GOOGL', 'AMZN', 'GOOG', 'META', 'AVGO', 'ORCL', 'CRM', 'ADBE', 'AMD', 'CSCO']
basket = Basket(symbols=symbols)
basket.load_all_assets(freq="1d")
# Out:
# DEBUG:entities.basket:Initialized Asset Basket: ['AAPL', 'TSLA', 'MSFT', 'NVDA', 'GOOGL', 'AMZN', 'GOOG', 'META', 'AVGO', 'ORCL', 'CRM', 'ADBE', 'AMD', 'CSCO'] with 0 assets which loaded.
# INFO:entities.basket:Starting batch load for 14 symbols...
# DEBUG:entities.basket:Attempting to load AAPL...
# DEBUG:entities.asset:Initialized Asset: AAPL with 2724 rows.
# INFO:entities.basket:Successfully loaded AAPL (2724 rows).
# DEBUG:entities.basket:Attempting to load TSLA...
# DEBUG:entities.asset:Initialized Asset: TSLA with 2760 rows.
# INFO:entities.basket:Successfully loaded TSLA (2760 rows).
# DEBUG:entities.basket:Attempting to load MSFT...
# DEBUG:entities.asset:Initialized Asset: MSFT with 2724 rows.
# INFO:entities.basket:Successfully loaded MSFT (2724 rows).
# DEBUG:entities.basket:Attempting to load NVDA...
# DEBUG:entities.asset:Initialized Asset: NVDA with 2724 rows.
# INFO:entities.basket:Successfully loaded NVDA (2724 rows).
# DEBUG:entities.basket:Attempting to load GOOGL...
# DEBUG:entities.asset:Initialized Asset: GOOGL with 2760 rows.
# INFO:entities.basket:Successfully loaded GOOGL (2760 rows).
# DEBUG:entities.basket:Attempting to load AMZN...
# DEBUG:entities.asset:Initialized Asset: AMZN with 2760 rows.
# INFO:entities.basket:Successfully loaded AMZN (2760 rows).
# DEBUG:entities.basket:Attempting to load GOOG...
# DEBUG:entities.asset:Initialized Asset: GOOG with 1464 rows.
# INFO:entities.basket:Successfully loaded GOOG (1464 rows).
# DEBUG:entities.basket:Attempting to load META...
# DEBUG:entities.asset:Initialized Asset: META with 2760 rows.
# INFO:entities.basket:Successfully loaded META (2760 rows).
# DEBUG:entities.basket:Attempting to load AVGO...
# DEBUG:entities.asset:Initialized Asset: AVGO with 2724 rows.
# INFO:entities.basket:Successfully loaded AVGO (2724 rows).
# DEBUG:entities.basket:Attempting to load ORCL...
# DEBUG:entities.asset:Initialized Asset: ORCL with 2724 rows.
# INFO:entities.basket:Successfully loaded ORCL (2724 rows).
# DEBUG:entities.basket:Attempting to load CRM...
# DEBUG:entities.asset:Initialized Asset: CRM with 2724 rows.
# INFO:entities.basket:Successfully loaded CRM (2724 rows).
# DEBUG:entities.basket:Attempting to load ADBE...
# DEBUG:entities.asset:Initialized Asset: ADBE with 2724 rows.
# INFO:entities.basket:Successfully loaded ADBE (2724 rows).
# DEBUG:entities.basket:Attempting to load AMD...
# DEBUG:entities.asset:Initialized Asset: AMD with 2724 rows.
# INFO:entities.basket:Successfully loaded AMD (2724 rows).
# DEBUG:entities.basket:Attempting to load CSCO...
# DEBUG:entities.asset:Initialized Asset: CSCO with 2724 rows.
# INFO:entities.basket:Successfully loaded CSCO (2724 rows).
# INFO:entities.basket:Batch load complete. Success: 14/14. Total assets in basket: 14

# %% [markdown]
# ### Norm To Returns

# %%
targets = ["Close"]
for symbol, asset in basket.assets.items():
    asset.to_returns(log=True, columns=targets)
asset.data.head(5)
# Out:
# DEBUG:entities.asset:AAPL converted to Returns (log=True)
# DEBUG:entities.asset:TSLA converted to Returns (log=True)
# DEBUG:entities.asset:MSFT converted to Returns (log=True)
# DEBUG:entities.asset:NVDA converted to Returns (log=True)
# DEBUG:entities.asset:GOOGL converted to Returns (log=True)
# DEBUG:entities.asset:AMZN converted to Returns (log=True)
# DEBUG:entities.asset:GOOG converted to Returns (log=True)
# DEBUG:entities.asset:META converted to Returns (log=True)
# DEBUG:entities.asset:AVGO converted to Returns (log=True)
# DEBUG:entities.asset:ORCL converted to Returns (log=True)
# DEBUG:entities.asset:CRM converted to Returns (log=True)
# DEBUG:entities.asset:ADBE converted to Returns (log=True)
# DEBUG:entities.asset:AMD converted to Returns (log=True)
# DEBUG:entities.asset:CSCO converted to Returns (log=True)
#                  High        Low       Open    Volume  Close (Log_Returns)
# Date
# 2015-01-05  19.700776  19.377812  19.607475  29460600            -0.020121
# 2015-01-06  19.865848  19.406522  19.478291  47297600            -0.000370
# 2015-01-07  19.664896  19.363463  19.478295  27570800             0.009200
# 2015-01-08  20.160107  19.715135  19.765374  40907000             0.007663
# 2015-01-09  20.145750  19.700779  19.858671  33619600             0.010127

# %% [markdown]
# ### Align Data (Joint Data)

# %%
strategy = IntersectionStrategy()
joint_df = basket.align(strategy)
joint_df.head()
# Out:
# DEBUG:strategies.concrete:Intersection Strategy: Aligned 14 assets. Common rows: 1463
# DEBUG:entities.basket:Aligned data shape: (1463, 70)
# INFO:entities.basket:Assets updated in-place to aligned index (Length: 1463)
#                  AAPL                                                       \
#                  High        Low       Open     Volume Close (Log_Returns)
# Date
# 2020-01-03  72.594055  71.608685  71.765667  146322800           -0.009770
# 2020-01-06  72.444344  70.703034  70.954210  118387200            0.007937
# 2020-01-07  72.671341  71.845369  72.415337  108872000           -0.004715
# 2020-01-08  73.526310  71.768094  71.768094  132079200            0.015958
# 2020-01-09  74.972955  73.951358  74.202527  170108400            0.021018
#
#                  TSLA                                                       \
#                  High        Low       Open     Volume Close (Log_Returns)
# Date
# 2020-01-03  30.266666  29.128000  29.366667  266677500            0.029203
# 2020-01-06  30.104000  29.333332  29.364668  151995000            0.019072
# 2020-01-07  31.441999  30.224001  30.760000  268231500            0.038067
# 2020-01-08  33.232666  31.215334  31.580000  467164500            0.048033
# 2020-01-09  33.253334  31.524668  33.139999  426606000           -0.022189
#
#             ...        AMD                                  \
#             ...       High        Low       Open    Volume
# Date        ...
# 2020-01-03  ...  49.389999  47.540001  48.029999  73127400
# 2020-01-06  ...  48.860001  47.860001  48.020000  47934900
# 2020-01-07  ...  49.389999  48.040001  49.349998  58061400
# 2020-01-08  ...  48.299999  47.139999  47.849998  53767000
# 2020-01-09  ...  49.959999  48.389999  48.939999  76512800
#
#                                      CSCO                                  \
#            Close (Log_Returns)       High        Low       Open    Volume
# Date
# 2020-01-03           -0.010236  40.453623  39.899004  40.260347  15577400
# 2020-01-06           -0.004330  40.184715  39.504044  39.613288  22183600
# 2020-01-07           -0.002897  40.100678  39.579670  40.100678  16501900
# 2020-01-08           -0.008743  40.159507  39.335982  39.470435  25175900
# 2020-01-09            0.023555  40.235133  39.554462  40.159503  18203600
#
#
#            Close (Log_Returns)
# Date
# 2020-01-03           -0.016450
# 2020-01-06            0.003563
# 2020-01-07           -0.006507
# 2020-01-08            0.000632
# 2020-01-09           -0.004218
#
# [5 rows x 70 columns]

# %%
features = ["Close (Log_Returns)"]
basket_tensor = basket.to_tensor(features=features)
basket_tensor.shape
# Out:
# DEBUG:entities.asset:Asset: AAPL is using cuda device.
# DEBUG:entities.asset:Asset: TSLA is using cuda device.
# DEBUG:entities.asset:Asset: MSFT is using cuda device.
# DEBUG:entities.asset:Asset: NVDA is using cuda device.
# DEBUG:entities.asset:Asset: GOOGL is using cuda device.
# DEBUG:entities.asset:Asset: AMZN is using cuda device.
# DEBUG:entities.asset:Asset: GOOG is using cuda device.
# DEBUG:entities.asset:Asset: META is using cuda device.
# DEBUG:entities.asset:Asset: AVGO is using cuda device.
# DEBUG:entities.asset:Asset: ORCL is using cuda device.
# DEBUG:entities.asset:Asset: CRM is using cuda device.
# DEBUG:entities.asset:Asset: ADBE is using cuda device.
# DEBUG:entities.asset:Asset: AMD is using cuda device.
# DEBUG:entities.asset:Asset: CSCO is using cuda device.
# torch.Size([1463, 14, 1])

# %%
def verify_scaling(t: torch.Tensor):
    print(f"Max: {t.max().item():.4f}")
    print(f"Min: {t.min().item():.4f}")
    print(f"Mean: {t.mean().item():.4f}")
    print(f"Std: {t.std().item():.4f}")

verify_scaling(basket_tensor)
# Out:
# Max: 0.3071
# Min: -0.3064
# Mean: 0.0010
# Std: 0.0263

# %% [markdown]
# #### Market Setup & Window Rolling Setup

# %%
window = RollingWindow(size=64, stride=1)
market = Market(basket, window)
market_tensor = market.setup(features=features)
# Out:
# INFO:entities.market:Setting up Market environment
# DEBUG:entities.asset:Asset: AAPL is using cuda device.
# DEBUG:entities.asset:Asset: TSLA is using cuda device.
# DEBUG:entities.asset:Asset: MSFT is using cuda device.
# DEBUG:entities.asset:Asset: NVDA is using cuda device.
# DEBUG:entities.asset:Asset: GOOGL is using cuda device.
# DEBUG:entities.asset:Asset: AMZN is using cuda device.
# DEBUG:entities.asset:Asset: GOOG is using cuda device.
# DEBUG:entities.asset:Asset: META is using cuda device.
# DEBUG:entities.asset:Asset: AVGO is using cuda device.
# DEBUG:entities.asset:Asset: ORCL is using cuda device.
# DEBUG:entities.asset:Asset: CRM is using cuda device.
# DEBUG:entities.asset:Asset: ADBE is using cuda device.
# DEBUG:entities.asset:Asset: AMD is using cuda device.
# DEBUG:entities.asset:Asset: CSCO is using cuda device.
# DEBUG:components.windowing:RollingWindow applied. Result: torch.Size([1400, 64, 14, 1])
# INFO:entities.market:Market Setup Complete. Batch Shape: torch.Size([1400, 64, 14, 1]) [B, L, N, F]

# %%
print(f"Market Tensor Shape: {market_tensor.shape}")
verify_scaling(market_tensor)
# Out:
# Market Tensor Shape: torch.Size([1400, 64, 14, 1])
# Max: 0.3071
# Min: -0.3064
# Mean: 0.0010
# Std: 0.0261

# %% [markdown]
# ### Scaler

# %%
sklearn_scaler = MinMaxScaler(feature_range=(-1, 1))
scaler = SklearnWrapper(sklearn_scaler)

scaler.fit(market_tensor)
norm_data = scaler.encode(market_tensor)

print(f"Norm data shape: {market_tensor.shape}")
print(f"Data {market_tensor[0,0,0,:]}")
verify_scaling(norm_data)
# Out:
# DEBUG:utils.scaler:Scaler Fitted using: MinMaxScaler
# Norm data shape: torch.Size([1400, 64, 14, 1])
# Data tensor([-0.0098], device='cuda:0')
# Max: 1.0000
# Min: -1.0000
# Mean: 0.0021
# Std: 0.0852

# %% [markdown]
# ### Dataloader & Datasets

# %%
modes = ["exhaustive", "random"]
market_ds = JointMarketDataset(norm_data)

print(f"Norm Data: {norm_data.shape}")
print(f"Market Dataset: {len(market_ds)}")

# market_ds = MarketDataset(norm_data, mode='random')
ratios = [0.8, 0.1, 0.1]
train_ds, val_ds, test_ds = create_randomize_datasets(market_ds, ratios)

print(f"Train samples: {len(train_ds)}")
print(f"Val samples: {len(val_ds)}") 
print(f"Test samples: {len(test_ds)}")
# Out:
# Norm Data: torch.Size([1400, 64, 14, 1])
# Market Dataset: 1400
# Train samples: 1120
# Val samples: 140
# Test samples: 140

# %%
train_loader = DataLoader(train_ds, batch_size=32, shuffle=False)
val_loader = DataLoader(val_ds, batch_size=32, shuffle=True)
test_loader = DataLoader(test_ds, batch_size=32, shuffle=True)

# %%
x = next(iter(train_loader))
print(f"x shape: {x.shape}")
verify_scaling(x)
# Out:
# x shape: torch.Size([32, 64, 14, 1])
# Max: 0.6048
# Min: -0.7251
# Mean: -0.0021
# Std: 0.1558

# %% [markdown]
# ## Model

# %% [markdown]
# ### Setup

# %%
cfg = TrainConfig(
    epochs=10000,
    optimizer=OptimizerConfig(lr=2e-4)
)

print(cfg.optimizer.lr) 
print(cfg.epochs)    
print(cfg.ddpm)
# Out:
# 0.0002
# 10000
# DDPMConfig(noise_steps=1000, beta_start=0.0001, beta_end=0.02, schedule='cosine', d_model=128, n_heads=4, n_layers=4, max_t=128)

# %%
WINDOW_SIZE = x.shape[1]       # T
NUM_ASSETS = x.shape[2]         # N
NUM_FEATURES = x.shape[3]      # F
TOTAL_INPUT_DIM = NUM_ASSETS * NUM_FEATURES # C = N * F (Flatten)

print(f"Running on: {cfg.device}")
print(f"Input Dimension (Channels): {TOTAL_INPUT_DIM}")
# Out:
# Running on: cuda
# Input Dimension (Channels): 14

# %% [markdown]
# ### Diffusion

# %%
diffusion = Diffusion(
    noise_steps=cfg.ddpm.noise_steps,
    beta_start=cfg.ddpm.beta_start,
    beta_end=cfg.ddpm.beta_end,
    schedule=cfg.scheduler.type,
    device=cfg.device
)
# Out:
# DEBUG:frameworks.ddpm:Diffusion is using cosine schedule.

# %% [markdown]
# ### NN Model

# %%
model = DiffusionTransformer(
    features_in=TOTAL_INPUT_DIM,  # รับ Input ขนาด N*F
    d_model=cfg.ddpm.d_model,                  # ความกว้าง Model
    nhead=cfg.ddpm.n_heads,
    num_layers=cfg.ddpm.n_layers,
    max_len=WINDOW_SIZE           # รองรับความยาวสูงสุดเท่า Window
).to(cfg.device)
# Out:
# /home/narodom.y@FUSION.LAB/.conda/envs/tsgenai/lib/python3.11/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(

# %% [markdown]
# ### Optimizer

# %%
optimizer = AdamW(model.parameters(), lr=cfg.optimizer.lr, weight_decay=cfg.optimizer.weight_decay)

# %% [markdown]
# ## Engine

# %%
engine = Engine(
    model=model,
    diffusion=diffusion,
    train_dataloader=train_loader,
    val_dataloader=val_loader,
    optimizer=optimizer,
    device=cfg.device,
    scaler=scaler
)

# %% [markdown]
# ### Training

# %%
engine.fit(epochs=cfg.epochs, save_dir="./checkpoints")
# Out:
# INFO:engine.trainer:Engine started Training for 10000 epochs on cuda...
# Epoch 1/10000: 100%|██████████| 35/35 [00:01<00:00, 31.61it/s, loss=0.1476]
# Epoch 2/10000: 100%|██████████| 35/35 [00:00<00:00, 43.55it/s, loss=0.1226]
# Epoch 3/10000: 100%|██████████| 35/35 [00:00<00:00, 43.47it/s, loss=0.1535]
# Epoch 4/10000: 100%|██████████| 35/35 [00:00<00:00, 43.87it/s, loss=0.1035]
# Epoch 5/10000: 100%|██████████| 35/35 [00:00<00:00, 43.79it/s, loss=0.0945]
# Epoch 6/10000: 100%|██████████| 35/35 [00:00<00:00, 43.38it/s, loss=0.0490]
# Epoch 7/10000: 100%|██████████| 35/35 [00:00<00:00, 43.76it/s, loss=0.0951]
# Epoch 8/10000: 100%|██████████| 35/35 [00:00<00:00, 42.69it/s, loss=0.0507]
# Epoch 9/10000: 100%|██████████| 35/35 [00:00<00:00, 43.81it/s, loss=0.1219]
# Epoch 10/10000: 100%|██████████| 35/35 [00:00<00:00, 44.11it/s, loss=0.0770]
# Epoch 11/10000: 100%|██████████| 35/35 [00:00<00:00, 44.09it/s, loss=0.0779]
# Epoch 12/10000: 100%|██████████| 35/35 [00:00<00:00, 44.10it/s, loss=0.0789]
# Epoch 13/10000: 100%|██████████| 35/35 [00:00<00:00, 43.78it/s, loss=0.0533]
# Epoch 14/10000: 100%|██████████| 35/35 [00:00<00:00, 43.76it/s, loss=0.0705]
# Epoch 15/10000: 100%|██████████| 35/35 [00:00<00:00, 43.79it/s, loss=0.1256]
# Epoch 16/10000: 100%|██████████| 35/35 [00:00<00:00, 43.70it/s, loss=0.0491]
# Epoch 17/10000: 100%|██████████| 35/35 [00:00<00:00, 43.73it/s, loss=0.0657]
# Epoch 18/10000: 100%|██████████| 35/35 [00:00<00:00, 43.78it/s, loss=0.0887]
# Epoch 19/10000: 100%|██████████| 35/35 [00:00<00:00, 43.65it/s, loss=0.0600]
# Epoch 20/10000: 100%|██████████| 35/35 [00:00<00:00, 43.74it/s, loss=0.0492]
# Epoch 21/10000: 100%|██████████| 35/35 [00:00<00:00, 43.79it/s, loss=0.0621]
# Epoch 22/10000: 100%|██████████| 35/35 [00:00<00:00, 43.69it/s, loss=0.0389]
# Epoch 23/10000: 100%|██████████| 35/35 [00:00<00:00, 43.72it/s, loss=0.0481]
# Epoch 24/10000: 100%|██████████| 35/35 [00:00<00:00, 43.73it/s, loss=0.0220]
# Epoch 25/10000: 100%|██████████| 35/35 [00:00<00:00, 43.74it/s, loss=0.0983]
# Epoch 26/10000: 100%|██████████| 35/35 [00:00<00:00, 43.65it/s, loss=0.0603]
# Epoch 27/10000: 100%|██████████| 35/35 [00:00<00:00, 43.63it/s, loss=0.0528]
# Epoch 28/10000: 100%|██████████| 35/35 [00:00<00:00, 43.66it/s, loss=0.0417]
# Epoch 29/10000: 100%|██████████| 35/35 [00:00<00:00, 43.69it/s, loss=0.1037]
# Epoch 30/10000: 100%|██████████| 35/35 [00:00<00:00, 43.89it/s, loss=0.0916]
# Epoch 31/10000: 100%|██████████| 35/35 [00:00<00:00, 43.85it/s, loss=0.0912]
# Epoch 32/10000: 100%|██████████| 35/35 [00:00<00:00, 43.89it/s, loss=0.0634]
# Epoch 33/10000: 100%|██████████| 35/35 [00:00<00:00, 43.19it/s, loss=0.0482]
# Epoch 34/10000: 100%|██████████| 35/35 [00:00<00:00, 43.83it/s, loss=0.0952]
# Epoch 35/10000: 100%|██████████| 35/35 [00:00<00:00, 44.15it/s, loss=0.0999]
# Epoch 36/10000: 100%|██████████| 35/35 [00:00<00:00, 44.12it/s, loss=0.0744]
# Epoch 37/10000: 100%|██████████| 35/35 [00:00<00:00, 44.13it/s, loss=0.0747]
# Epoch 38/10000: 100%|██████████| 35/35 [00:00<00:00, 44.03it/s, loss=0.0326]
# Epoch 39/10000: 100%|██████████| 35/35 [00:00<00:00, 43.73it/s, loss=0.0873]
# Epoch 40/10000: 100%|██████████| 35/35 [00:00<00:00, 43.71it/s, loss=0.0954]
# Epoch 41/10000: 100%|██████████| 35/35 [00:00<00:00, 43.79it/s, loss=0.0500]
# Epoch 42/10000: 100%|██████████| 35/35 [00:00<00:00, 43.75it/s, loss=0.0975]
# Epoch 43/10000: 100%|██████████| 35/35 [00:00<00:00, 43.72it/s, loss=0.0607]
# Epoch 44/10000: 100%|██████████| 35/35 [00:00<00:00, 43.80it/s, loss=0.0445]
# Epoch 45/10000: 100%|██████████| 35/35 [00:00<00:00, 43.82it/s, loss=0.0223]
# Epoch 46/10000: 100%|██████████| 35/35 [00:00<00:00, 43.11it/s, loss=0.0684]
# Epoch 47/10000: 100%|██████████| 35/35 [00:00<00:00, 43.01it/s, loss=0.0536]
# Epoch 48/10000: 100%|██████████| 35/35 [00:00<00:00, 43.42it/s, loss=0.0249]
# Epoch 49/10000: 100%|██████████| 35/35 [00:00<00:00, 43.44it/s, loss=0.0801]
# Epoch 50/10000: 100%|██████████| 35/35 [00:00<00:00, 43.80it/s, loss=0.0613]
# Epoch 51/10000: 100%|██████████| 35/35 [00:00<00:00, 43.83it/s, loss=0.0525]
# Epoch 52/10000: 100%|██████████| 35/35 [00:00<00:00, 43.77it/s, loss=0.0550]
# Epoch 53/10000: 100%|██████████| 35/35 [00:00<00:00, 43.78it/s, loss=0.0643]
# Epoch 54/10000: 100%|██████████| 35/35 [00:00<00:00, 43.75it/s, loss=0.0756]
# Epoch 55/10000: 100%|██████████| 35/35 [00:00<00:00, 43.75it/s, loss=0.0514]
# Epoch 56/10000: 100%|██████████| 35/35 [00:00<00:00, 43.73it/s, loss=0.0359]
# Epoch 57/10000: 100%|██████████| 35/35 [00:00<00:00, 43.65it/s, loss=0.0510]
# Epoch 58/10000: 100%|██████████| 35/35 [00:00<00:00, 43.62it/s, loss=0.1016]
# Epoch 59/10000: 100%|██████████| 35/35 [00:00<00:00, 43.59it/s, loss=0.0335]
# Epoch 60/10000: 100%|██████████| 35/35 [00:00<00:00, 43.63it/s, loss=0.0423]
# Epoch 61/10000: 100%|██████████| 35/35 [00:00<00:00, 43.58it/s, loss=0.1004]
# Epoch 62/10000: 100%|██████████| 35/35 [00:00<00:00, 43.65it/s, loss=0.0975]
# Epoch 63/10000: 100%|██████████| 35/35 [00:00<00:00, 43.60it/s, loss=0.0723]
# Epoch 64/10000: 100%|██████████| 35/35 [00:00<00:00, 43.52it/s, loss=0.0396]
# Epoch 65/10000: 100%|██████████| 35/35 [00:00<00:00, 43.60it/s, loss=0.1130]
# Epoch 66/10000: 100%|██████████| 35/35 [00:00<00:00, 43.69it/s, loss=0.0122]
# Epoch 67/10000: 100%|██████████| 35/35 [00:00<00:00, 43.66it/s, loss=0.0424]
# Epoch 68/10000: 100%|██████████| 35/35 [00:00<00:00, 43.74it/s, loss=0.0361]
# Epoch 69/10000: 100%|██████████| 35/35 [00:00<00:00, 43.69it/s, loss=0.0739]
# Epoch 70/10000: 100%|██████████| 35/35 [00:00<00:00, 43.74it/s, loss=0.0822]
# Epoch 71/10000: 100%|██████████| 35/35 [00:00<00:00, 43.70it/s, loss=0.0544]
# Epoch 72/10000: 100%|██████████| 35/35 [00:00<00:00, 43.72it/s, loss=0.0305]
# Epoch 73/10000: 100%|██████████| 35/35 [00:00<00:00, 43.72it/s, loss=0.0706]
# Epoch 74/10000: 100%|██████████| 35/35 [00:00<00:00, 43.72it/s, loss=0.0735]
# Epoch 75/10000: 100%|██████████| 35/35 [00:00<00:00, 43.64it/s, loss=0.0513]
# Epoch 76/10000: 100%|██████████| 35/35 [00:00<00:00, 43.70it/s, loss=0.0492]
# Epoch 77/10000: 100%|██████████| 35/35 [00:00<00:00, 43.66it/s, loss=0.0490]
# Epoch 78/10000: 100%|██████████| 35/35 [00:00<00:00, 43.70it/s, loss=0.0798]
# Epoch 79/10000: 100%|██████████| 35/35 [00:00<00:00, 43.74it/s, loss=0.0573]
# Epoch 80/10000: 100%|██████████| 35/35 [00:00<00:00, 43.86it/s, loss=0.0564]
# Epoch 81/10000: 100%|██████████| 35/35 [00:00<00:00, 43.81it/s, loss=0.0343]
# Epoch 82/10000: 100%|██████████| 35/35 [00:00<00:00, 43.88it/s, loss=0.0350]
# Epoch 83/10000: 100%|██████████| 35/35 [00:00<00:00, 42.91it/s, loss=0.0734]
# Epoch 84/10000: 100%|██████████| 35/35 [00:00<00:00, 43.78it/s, loss=0.0566]
# Epoch 85/10000: 100%|██████████| 35/35 [00:00<00:00, 43.80it/s, loss=0.0471]
# Epoch 86/10000: 100%|██████████| 35/35 [00:00<00:00, 43.83it/s, loss=0.0697]
# Epoch 87/10000: 100%|██████████| 35/35 [00:00<00:00, 43.82it/s, loss=0.0275]
# Epoch 88/10000: 100%|██████████| 35/35 [00:00<00:00, 43.82it/s, loss=0.0605]
# Epoch 89/10000: 100%|██████████| 35/35 [00:00<00:00, 43.80it/s, loss=0.0435]
# Epoch 90/10000: 100%|██████████| 35/35 [00:00<00:00, 43.73it/s, loss=0.0632]
# Epoch 91/10000: 100%|██████████| 35/35 [00:00<00:00, 43.80it/s, loss=0.0463]
# Epoch 92/10000: 100%|██████████| 35/35 [00:00<00:00, 43.82it/s, loss=0.0471]
# Epoch 93/10000: 100%|██████████| 35/35 [00:00<00:00, 43.85it/s, loss=0.0506]
# Epoch 94/10000: 100%|██████████| 35/35 [00:00<00:00, 43.89it/s, loss=0.0732]
# Epoch 95/10000: 100%|██████████| 35/35 [00:00<00:00, 43.84it/s, loss=0.0377]
# Epoch 96/10000: 100%|██████████| 35/35 [00:00<00:00, 46.60it/s, loss=0.0593]
# Epoch 97/10000: 100%|██████████| 35/35 [00:00<00:00, 42.93it/s, loss=0.0850]
# Epoch 98/10000: 100%|██████████| 35/35 [00:00<00:00, 42.89it/s, loss=0.0148]
# Epoch 99/10000: 100%|██████████| 35/35 [00:00<00:00, 43.36it/s, loss=0.1020]
# Epoch 100/10000: 100%|██████████| 35/35 [00:00<00:00, 43.81it/s, loss=0.0823]
# Epoch 101/10000: 100%|██████████| 35/35 [00:00<00:00, 43.73it/s, loss=0.0412]
# Epoch 102/10000: 100%|██████████| 35/35 [00:00<00:00, 43.79it/s, loss=0.1256]
# Epoch 103/10000: 100%|██████████| 35/35 [00:00<00:00, 43.83it/s, loss=0.0840]
# Epoch 104/10000: 100%|██████████| 35/35 [00:00<00:00, 43.82it/s, loss=0.0844]
# Epoch 105/10000: 100%|██████████| 35/35 [00:00<00:00, 42.84it/s, loss=0.0477]
# Epoch 106/10000: 100%|██████████| 35/35 [00:00<00:00, 42.88it/s, loss=0.0655]
# Epoch 107/10000: 100%|██████████| 35/35 [00:00<00:00, 42.85it/s, loss=0.0509]
# Epoch 108/10000: 100%|██████████| 35/35 [00:00<00:00, 42.86it/s, loss=0.0463]
# Epoch 109/10000: 100%|██████████| 35/35 [00:00<00:00, 42.87it/s, loss=0.0655]
# Epoch 110/10000: 100%|██████████| 35/35 [00:00<00:00, 42.81it/s, loss=0.0582]
# Epoch 111/10000: 100%|██████████| 35/35 [00:00<00:00, 42.83it/s, loss=0.0558]
# Epoch 112/10000: 100%|██████████| 35/35 [00:00<00:00, 42.84it/s, loss=0.0475]
# Epoch 113/10000: 100%|██████████| 35/35 [00:00<00:00, 42.82it/s, loss=0.0597]
# Epoch 114/10000: 100%|██████████| 35/35 [00:00<00:00, 42.67it/s, loss=0.0339]
# Epoch 115/10000: 100%|██████████| 35/35 [00:00<00:00, 48.99it/s, loss=0.0922]
# Epoch 116/10000: 100%|██████████| 35/35 [00:00<00:00, 49.85it/s, loss=0.0792]
# Epoch 117/10000: 100%|██████████| 35/35 [00:00<00:00, 49.76it/s, loss=0.0275]
# Epoch 118/10000: 100%|██████████| 35/35 [00:00<00:00, 49.82it/s, loss=0.0820]
# Epoch 119/10000: 100%|██████████| 35/35 [00:00<00:00, 49.88it/s, loss=0.0662]
# Epoch 120/10000: 100%|██████████| 35/35 [00:00<00:00, 49.78it/s, loss=0.0469]
# Epoch 121/10000: 100%|██████████| 35/35 [00:00<00:00, 49.83it/s, loss=0.0492]
# Epoch 122/10000: 100%|██████████| 35/35 [00:00<00:00, 49.92it/s, loss=0.0467]
# Epoch 123/10000: 100%|██████████| 35/35 [00:00<00:00, 49.95it/s, loss=0.0624]
# Epoch 124/10000: 100%|██████████| 35/35 [00:00<00:00, 49.84it/s, loss=0.0435]
# Epoch 125/10000: 100%|██████████| 35/35 [00:00<00:00, 49.73it/s, loss=0.0497]
# Epoch 126/10000: 100%|██████████| 35/35 [00:00<00:00, 49.76it/s, loss=0.0527]
# Epoch 127/10000: 100%|██████████| 35/35 [00:00<00:00, 49.67it/s, loss=0.1119]
# Epoch 128/10000: 100%|██████████| 35/35 [00:00<00:00, 49.72it/s, loss=0.0533]
# Epoch 129/10000: 100%|██████████| 35/35 [00:00<00:00, 49.34it/s, loss=0.0528]
# Epoch 130/10000: 100%|██████████| 35/35 [00:00<00:00, 49.69it/s, loss=0.0400]
# Epoch 131/10000: 100%|██████████| 35/35 [00:00<00:00, 49.46it/s, loss=0.0641]
# Epoch 132/10000: 100%|██████████| 35/35 [00:00<00:00, 49.59it/s, loss=0.0385]
# Epoch 133/10000: 100%|██████████| 35/35 [00:00<00:00, 49.82it/s, loss=0.0585]
# Epoch 134/10000: 100%|██████████| 35/35 [00:00<00:00, 49.75it/s, loss=0.0474]
# Epoch 135/10000: 100%|██████████| 35/35 [00:00<00:00, 49.67it/s, loss=0.0184]
# Epoch 136/10000: 100%|██████████| 35/35 [00:00<00:00, 49.87it/s, loss=0.0513]
# Epoch 137/10000: 100%|██████████| 35/35 [00:00<00:00, 49.82it/s, loss=0.1036]
# Epoch 138/10000: 100%|██████████| 35/35 [00:00<00:00, 49.82it/s, loss=0.0314]
# Epoch 139/10000: 100%|██████████| 35/35 [00:00<00:00, 49.71it/s, loss=0.0318]
# Epoch 140/10000: 100%|██████████| 35/35 [00:00<00:00, 49.65it/s, loss=0.0456]
# Epoch 141/10000: 100%|██████████| 35/35 [00:00<00:00, 49.59it/s, loss=0.0252]
# Epoch 142/10000: 100%|██████████| 35/35 [00:00<00:00, 49.36it/s, loss=0.0419]
# Epoch 143/10000: 100%|██████████| 35/35 [00:00<00:00, 49.70it/s, loss=0.0199]
# Epoch 144/10000: 100%|██████████| 35/35 [00:00<00:00, 49.82it/s, loss=0.0353]
# Epoch 145/10000: 100%|██████████| 35/35 [00:00<00:00, 49.68it/s, loss=0.0413]
# Epoch 146/10000: 100%|██████████| 35/35 [00:00<00:00, 49.56it/s, loss=0.0164]
# Epoch 147/10000: 100%|██████████| 35/35 [00:00<00:00, 49.85it/s, loss=0.0849]
# Epoch 148/10000: 100%|██████████| 35/35 [00:00<00:00, 49.79it/s, loss=0.0731]
# Epoch 149/10000: 100%|██████████| 35/35 [00:00<00:00, 49.62it/s, loss=0.0890]
# Epoch 150/10000: 100%|██████████| 35/35 [00:00<00:00, 49.64it/s, loss=0.0619]
# Epoch 151/10000: 100%|██████████| 35/35 [00:00<00:00, 49.61it/s, loss=0.0321]
# Epoch 152/10000: 100%|██████████| 35/35 [00:00<00:00, 49.54it/s, loss=0.0695]
# Epoch 153/10000: 100%|██████████| 35/35 [00:00<00:00, 49.80it/s, loss=0.0336]
# Epoch 154/10000: 100%|██████████| 35/35 [00:00<00:00, 49.78it/s, loss=0.0512]
# Epoch 155/10000: 100%|██████████| 35/35 [00:00<00:00, 49.67it/s, loss=0.0365]
# Epoch 156/10000: 100%|██████████| 35/35 [00:00<00:00, 49.76it/s, loss=0.0560]
# Epoch 157/10000: 100%|██████████| 35/35 [00:00<00:00, 49.38it/s, loss=0.0800]
# Epoch 158/10000: 100%|██████████| 35/35 [00:00<00:00, 49.57it/s, loss=0.0818]
# Epoch 159/10000: 100%|██████████| 35/35 [00:00<00:00, 49.60it/s, loss=0.0691]
# Epoch 160/10000: 100%|██████████| 35/35 [00:00<00:00, 49.71it/s, loss=0.0770]
# Epoch 161/10000: 100%|██████████| 35/35 [00:00<00:00, 49.68it/s, loss=0.0513]
# Epoch 162/10000: 100%|██████████| 35/35 [00:00<00:00, 49.76it/s, loss=0.0717]
# Epoch 163/10000: 100%|██████████| 35/35 [00:00<00:00, 49.73it/s, loss=0.0276]
# Epoch 164/10000: 100%|██████████| 35/35 [00:00<00:00, 49.22it/s, loss=0.0645]
# Epoch 165/10000: 100%|██████████| 35/35 [00:00<00:00, 49.85it/s, loss=0.0942]
# Epoch 166/10000: 100%|██████████| 35/35 [00:00<00:00, 49.58it/s, loss=0.0418]
# Epoch 167/10000: 100%|██████████| 35/35 [00:00<00:00, 49.76it/s, loss=0.0589]
# Epoch 168/10000: 100%|██████████| 35/35 [00:00<00:00, 49.89it/s, loss=0.0144]
# Epoch 169/10000: 100%|██████████| 35/35 [00:00<00:00, 49.71it/s, loss=0.1190]
# Epoch 170/10000: 100%|██████████| 35/35 [00:00<00:00, 49.61it/s, loss=0.0183]
# Epoch 171/10000: 100%|██████████| 35/35 [00:00<00:00, 49.48it/s, loss=0.0361]
# Epoch 172/10000: 100%|██████████| 35/35 [00:00<00:00, 49.81it/s, loss=0.0997]
# Epoch 173/10000: 100%|██████████| 35/35 [00:00<00:00, 49.75it/s, loss=0.0481]
# Epoch 174/10000: 100%|██████████| 35/35 [00:00<00:00, 49.71it/s, loss=0.0473]
# Epoch 175/10000: 100%|██████████| 35/35 [00:00<00:00, 49.81it/s, loss=0.0339]
# Epoch 176/10000: 100%|██████████| 35/35 [00:00<00:00, 49.86it/s, loss=0.0652]
# Epoch 177/10000: 100%|██████████| 35/35 [00:00<00:00, 49.71it/s, loss=0.0171]
# Epoch 178/10000: 100%|██████████| 35/35 [00:00<00:00, 49.42it/s, loss=0.0969]
# Epoch 179/10000: 100%|██████████| 35/35 [00:00<00:00, 49.71it/s, loss=0.0830]
# Epoch 180/10000: 100%|██████████| 35/35 [00:00<00:00, 49.51it/s, loss=0.0450]
# Epoch 181/10000: 100%|██████████| 35/35 [00:00<00:00, 49.70it/s, loss=0.0597]
# Epoch 182/10000: 100%|██████████| 35/35 [00:00<00:00, 49.87it/s, loss=0.0423]
# Epoch 183/10000: 100%|██████████| 35/35 [00:00<00:00, 49.79it/s, loss=0.0997]
# Epoch 184/10000: 100%|██████████| 35/35 [00:00<00:00, 49.40it/s, loss=0.0812]
# Epoch 185/10000: 100%|██████████| 35/35 [00:00<00:00, 49.66it/s, loss=0.0116]
# Epoch 186/10000: 100%|██████████| 35/35 [00:00<00:00, 50.57it/s, loss=0.0374]
# Epoch 187/10000: 100%|██████████| 35/35 [00:00<00:00, 50.12it/s, loss=0.0577]
# Epoch 188/10000: 100%|██████████| 35/35 [00:00<00:00, 50.39it/s, loss=0.0621]
# Epoch 189/10000: 100%|██████████| 35/35 [00:00<00:00, 50.88it/s, loss=0.0334]
# Epoch 190/10000: 100%|██████████| 35/35 [00:00<00:00, 50.77it/s, loss=0.0534]
# Epoch 191/10000: 100%|██████████| 35/35 [00:00<00:00, 50.86it/s, loss=0.0663]
# Epoch 192/10000: 100%|██████████| 35/35 [00:00<00:00, 50.92it/s, loss=0.0889]
# Epoch 193/10000: 100%|██████████| 35/35 [00:00<00:00, 50.94it/s, loss=0.0385]
# Epoch 194/10000: 100%|██████████| 35/35 [00:00<00:00, 50.90it/s, loss=0.0734]
# Epoch 195/10000: 100%|██████████| 35/35 [00:00<00:00, 50.92it/s, loss=0.0469]
# Epoch 196/10000: 100%|██████████| 35/35 [00:00<00:00, 50.02it/s, loss=0.0229]
# Epoch 197/10000: 100%|██████████| 35/35 [00:00<00:00, 49.94it/s, loss=0.0335]
# Epoch 198/10000: 100%|██████████| 35/35 [00:00<00:00, 49.96it/s, loss=0.0391]
# Epoch 199/10000: 100%|██████████| 35/35 [00:00<00:00, 49.84it/s, loss=0.0478]
# Epoch 200/10000: 100%|██████████| 35/35 [00:00<00:00, 49.94it/s, loss=0.0512]
# Epoch 201/10000: 100%|██████████| 35/35 [00:00<00:00, 49.95it/s, loss=0.0389]
# Epoch 202/10000: 100%|██████████| 35/35 [00:00<00:00, 49.91it/s, loss=0.0688]
# Epoch 203/10000: 100%|██████████| 35/35 [00:00<00:00, 49.91it/s, loss=0.0214]
# Epoch 204/10000: 100%|██████████| 35/35 [00:00<00:00, 49.93it/s, loss=0.0417]
# Epoch 205/10000: 100%|██████████| 35/35 [00:00<00:00, 49.95it/s, loss=0.0424]
# Epoch 206/10000: 100%|██████████| 35/35 [00:00<00:00, 49.95it/s, loss=0.0306]
# Epoch 207/10000: 100%|██████████| 35/35 [00:00<00:00, 49.14it/s, loss=0.0588]
# Epoch 208/10000: 100%|██████████| 35/35 [00:00<00:00, 49.64it/s, loss=0.0488]
# Epoch 209/10000: 100%|██████████| 35/35 [00:00<00:00, 49.86it/s, loss=0.0420]
# Epoch 210/10000: 100%|██████████| 35/35 [00:00<00:00, 49.92it/s, loss=0.0203]
# Epoch 211/10000: 100%|██████████| 35/35 [00:00<00:00, 49.89it/s, loss=0.0905]
# Epoch 212/10000: 100%|██████████| 35/35 [00:00<00:00, 49.96it/s, loss=0.0397]
# Epoch 213/10000: 100%|██████████| 35/35 [00:00<00:00, 49.91it/s, loss=0.0871]
# Epoch 214/10000: 100%|██████████| 35/35 [00:00<00:00, 49.85it/s, loss=0.0468]
# Epoch 215/10000: 100%|██████████| 35/35 [00:00<00:00, 49.94it/s, loss=0.0407]
# Epoch 216/10000: 100%|██████████| 35/35 [00:00<00:00, 49.82it/s, loss=0.0715]
# Epoch 217/10000: 100%|██████████| 35/35 [00:00<00:00, 49.94it/s, loss=0.0159]
# Epoch 218/10000: 100%|██████████| 35/35 [00:00<00:00, 49.87it/s, loss=0.0818]
# Epoch 219/10000: 100%|██████████| 35/35 [00:00<00:00, 49.91it/s, loss=0.0821]
# Epoch 220/10000: 100%|██████████| 35/35 [00:00<00:00, 49.93it/s, loss=0.0845]
# Epoch 221/10000: 100%|██████████| 35/35 [00:00<00:00, 49.96it/s, loss=0.0531]
# Epoch 222/10000: 100%|██████████| 35/35 [00:00<00:00, 49.91it/s, loss=0.1021]
# Epoch 223/10000: 100%|██████████| 35/35 [00:00<00:00, 49.87it/s, loss=0.0556]
# Epoch 224/10000: 100%|██████████| 35/35 [00:00<00:00, 49.88it/s, loss=0.1141]
# Epoch 225/10000: 100%|██████████| 35/35 [00:00<00:00, 49.91it/s, loss=0.0358]
# Epoch 226/10000: 100%|██████████| 35/35 [00:00<00:00, 49.91it/s, loss=0.0783]
# Epoch 227/10000: 100%|██████████| 35/35 [00:00<00:00, 49.94it/s, loss=0.0640]
# Epoch 228/10000: 100%|██████████| 35/35 [00:00<00:00, 49.93it/s, loss=0.0287]
# Epoch 229/10000: 100%|██████████| 35/35 [00:00<00:00, 51.27it/s, loss=0.0833]
# Epoch 230/10000: 100%|██████████| 35/35 [00:00<00:00, 51.20it/s, loss=0.0267]
# Epoch 231/10000: 100%|██████████| 35/35 [00:00<00:00, 51.25it/s, loss=0.0861]
# Epoch 232/10000: 100%|██████████| 35/35 [00:00<00:00, 51.24it/s, loss=0.0172]
# Epoch 233/10000: 100%|██████████| 35/35 [00:00<00:00, 51.26it/s, loss=0.0571]
# Epoch 234/10000: 100%|██████████| 35/35 [00:00<00:00, 51.27it/s, loss=0.0665]
# Epoch 235/10000: 100%|██████████| 35/35 [00:00<00:00, 51.30it/s, loss=0.0426]
# Epoch 236/10000: 100%|██████████| 35/35 [00:00<00:00, 51.22it/s, loss=0.0240]
# Epoch 237/10000: 100%|██████████| 35/35 [00:00<00:00, 51.31it/s, loss=0.0515]
# Epoch 238/10000: 100%|██████████| 35/35 [00:00<00:00, 51.03it/s, loss=0.0335]
# Epoch 239/10000: 100%|██████████| 35/35 [00:00<00:00, 51.07it/s, loss=0.0305]
# Epoch 240/10000: 100%|██████████| 35/35 [00:00<00:00, 51.28it/s, loss=0.0787]
# Epoch 241/10000: 100%|██████████| 35/35 [00:00<00:00, 51.06it/s, loss=0.0352]
# Epoch 242/10000: 100%|██████████| 35/35 [00:00<00:00, 50.86it/s, loss=0.0482]
# Epoch 243/10000: 100%|██████████| 35/35 [00:00<00:00, 50.83it/s, loss=0.0832]
# Epoch 244/10000: 100%|██████████| 35/35 [00:00<00:00, 51.09it/s, loss=0.0989]
# Epoch 245/10000: 100%|██████████| 35/35 [00:00<00:00, 50.61it/s, loss=0.0465]
# Epoch 246/10000: 100%|██████████| 35/35 [00:00<00:00, 51.06it/s, loss=0.0479]
# Epoch 247/10000: 100%|██████████| 35/35 [00:00<00:00, 50.99it/s, loss=0.0746]
# Epoch 248/10000: 100%|██████████| 35/35 [00:00<00:00, 51.17it/s, loss=0.0647]
# Epoch 249/10000: 100%|██████████| 35/35 [00:00<00:00, 51.16it/s, loss=0.0522]
# Epoch 250/10000: 100%|██████████| 35/35 [00:00<00:00, 49.87it/s, loss=0.0381]
# Epoch 251/10000: 100%|██████████| 35/35 [00:00<00:00, 48.91it/s, loss=0.0234]
# Epoch 252/10000: 100%|██████████| 35/35 [00:00<00:00, 49.39it/s, loss=0.0449]
# Epoch 253/10000: 100%|██████████| 35/35 [00:00<00:00, 49.26it/s, loss=0.0349]
# Epoch 254/10000: 100%|██████████| 35/35 [00:00<00:00, 48.29it/s, loss=0.0896]
# Epoch 255/10000: 100%|██████████| 35/35 [00:00<00:00, 49.06it/s, loss=0.0808]
# Epoch 256/10000: 100%|██████████| 35/35 [00:00<00:00, 49.22it/s, loss=0.0429]
# Epoch 257/10000: 100%|██████████| 35/35 [00:00<00:00, 49.16it/s, loss=0.0481]
# Epoch 258/10000: 100%|██████████| 35/35 [00:00<00:00, 49.33it/s, loss=0.0303]
# Epoch 259/10000: 100%|██████████| 35/35 [00:00<00:00, 49.13it/s, loss=0.0505]
# Epoch 260/10000: 100%|██████████| 35/35 [00:00<00:00, 49.08it/s, loss=0.0711]
# Epoch 261/10000: 100%|██████████| 35/35 [00:00<00:00, 49.30it/s, loss=0.0385]
# Epoch 262/10000: 100%|██████████| 35/35 [00:00<00:00, 49.38it/s, loss=0.0193]
# Epoch 263/10000: 100%|██████████| 35/35 [00:00<00:00, 49.38it/s, loss=0.0498]
# Epoch 264/10000: 100%|██████████| 35/35 [00:00<00:00, 49.41it/s, loss=0.0489]
# Epoch 265/10000: 100%|██████████| 35/35 [00:00<00:00, 49.30it/s, loss=0.0793]
# Epoch 266/10000: 100%|██████████| 35/35 [00:00<00:00, 49.40it/s, loss=0.0690]
# Epoch 267/10000: 100%|██████████| 35/35 [00:00<00:00, 49.08it/s, loss=0.0160]
# Epoch 268/10000: 100%|██████████| 35/35 [00:00<00:00, 49.31it/s, loss=0.0460]
# Epoch 269/10000: 100%|██████████| 35/35 [00:00<00:00, 49.26it/s, loss=0.0959]
# Epoch 270/10000: 100%|██████████| 35/35 [00:00<00:00, 49.32it/s, loss=0.0420]
# Epoch 271/10000: 100%|██████████| 35/35 [00:00<00:00, 49.10it/s, loss=0.0768]
# Epoch 272/10000: 100%|██████████| 35/35 [00:00<00:00, 49.27it/s, loss=0.0439]
# Epoch 273/10000: 100%|██████████| 35/35 [00:00<00:00, 49.39it/s, loss=0.0244]
# Epoch 274/10000: 100%|██████████| 35/35 [00:00<00:00, 49.79it/s, loss=0.0882]
# Epoch 275/10000: 100%|██████████| 35/35 [00:00<00:00, 49.75it/s, loss=0.0590]
# Epoch 276/10000: 100%|██████████| 35/35 [00:00<00:00, 49.80it/s, loss=0.0868]
# Epoch 277/10000: 100%|██████████| 35/35 [00:00<00:00, 49.79it/s, loss=0.0305]
# Epoch 278/10000: 100%|██████████| 35/35 [00:00<00:00, 49.57it/s, loss=0.0447]
# Epoch 279/10000: 100%|██████████| 35/35 [00:00<00:00, 49.86it/s, loss=0.0216]
# Epoch 280/10000: 100%|██████████| 35/35 [00:00<00:00, 49.65it/s, loss=0.0434]
# Epoch 281/10000: 100%|██████████| 35/35 [00:00<00:00, 49.29it/s, loss=0.0704]
# Epoch 282/10000: 100%|██████████| 35/35 [00:00<00:00, 49.82it/s, loss=0.0958]
# Epoch 283/10000: 100%|██████████| 35/35 [00:00<00:00, 49.65it/s, loss=0.0428]
# Epoch 284/10000: 100%|██████████| 35/35 [00:00<00:00, 49.83it/s, loss=0.0122]
# Epoch 285/10000: 100%|██████████| 35/35 [00:00<00:00, 50.74it/s, loss=0.0664]
# Epoch 286/10000: 100%|██████████| 35/35 [00:00<00:00, 50.79it/s, loss=0.0612]
# Epoch 287/10000: 100%|██████████| 35/35 [00:00<00:00, 50.74it/s, loss=0.0463]
# Epoch 288/10000: 100%|██████████| 35/35 [00:00<00:00, 50.71it/s, loss=0.0294]
# Epoch 289/10000: 100%|██████████| 35/35 [00:00<00:00, 50.70it/s, loss=0.0566]
# Epoch 290/10000: 100%|██████████| 35/35 [00:00<00:00, 50.72it/s, loss=0.0441]
# Epoch 291/10000: 100%|██████████| 35/35 [00:00<00:00, 50.75it/s, loss=0.0935]
# Epoch 292/10000: 100%|██████████| 35/35 [00:00<00:00, 50.77it/s, loss=0.0385]
# Epoch 293/10000: 100%|██████████| 35/35 [00:00<00:00, 50.76it/s, loss=0.0484]
# Epoch 294/10000: 100%|██████████| 35/35 [00:00<00:00, 50.78it/s, loss=0.0406]
# Epoch 295/10000: 100%|██████████| 35/35 [00:00<00:00, 50.77it/s, loss=0.0546]
# Epoch 296/10000: 100%|██████████| 35/35 [00:00<00:00, 50.80it/s, loss=0.0359]
# Epoch 297/10000: 100%|██████████| 35/35 [00:00<00:00, 50.77it/s, loss=0.0891]
# Epoch 298/10000: 100%|██████████| 35/35 [00:00<00:00, 50.80it/s, loss=0.0253]
# Epoch 299/10000: 100%|██████████| 35/35 [00:00<00:00, 50.78it/s, loss=0.0722]
# Epoch 300/10000: 100%|██████████| 35/35 [00:00<00:00, 50.90it/s, loss=0.0588]
# Epoch 301/10000: 100%|██████████| 35/35 [00:00<00:00, 50.84it/s, loss=0.0527]
# Epoch 302/10000: 100%|██████████| 35/35 [00:00<00:00, 50.91it/s, loss=0.0235]
# Epoch 303/10000: 100%|██████████| 35/35 [00:00<00:00, 50.87it/s, loss=0.0357]
# Epoch 304/10000: 100%|██████████| 35/35 [00:00<00:00, 50.87it/s, loss=0.0404]
# Epoch 305/10000: 100%|██████████| 35/35 [00:00<00:00, 50.89it/s, loss=0.0389]
# Epoch 306/10000: 100%|██████████| 35/35 [00:00<00:00, 50.90it/s, loss=0.0593]
# Epoch 307/10000: 100%|██████████| 35/35 [00:00<00:00, 50.86it/s, loss=0.0533]
# Epoch 308/10000: 100%|██████████| 35/35 [00:00<00:00, 50.77it/s, loss=0.0541]
# Epoch 309/10000: 100%|██████████| 35/35 [00:00<00:00, 50.85it/s, loss=0.0260]
# Epoch 310/10000: 100%|██████████| 35/35 [00:00<00:00, 50.78it/s, loss=0.0553]
# Epoch 311/10000: 100%|██████████| 35/35 [00:00<00:00, 50.86it/s, loss=0.0405]
# Epoch 312/10000: 100%|██████████| 35/35 [00:00<00:00, 50.84it/s, loss=0.1265]
# Epoch 313/10000: 100%|██████████| 35/35 [00:00<00:00, 50.79it/s, loss=0.0282]
# Epoch 314/10000: 100%|██████████| 35/35 [00:00<00:00, 50.82it/s, loss=0.0451]
# Epoch 315/10000: 100%|██████████| 35/35 [00:00<00:00, 50.81it/s, loss=0.0620]
# Epoch 316/10000: 100%|██████████| 35/35 [00:00<00:00, 50.74it/s, loss=0.0469]
# Epoch 317/10000: 100%|██████████| 35/35 [00:00<00:00, 50.75it/s, loss=0.1086]
# Epoch 318/10000: 100%|██████████| 35/35 [00:00<00:00, 50.72it/s, loss=0.0295]
# Epoch 319/10000: 100%|██████████| 35/35 [00:00<00:00, 50.15it/s, loss=0.0433]
# Epoch 320/10000: 100%|██████████| 35/35 [00:00<00:00, 49.21it/s, loss=0.0523]
# Epoch 321/10000: 100%|██████████| 35/35 [00:00<00:00, 49.14it/s, loss=0.0374]
# Epoch 322/10000: 100%|██████████| 35/35 [00:00<00:00, 49.14it/s, loss=0.0581]
# Epoch 323/10000: 100%|██████████| 35/35 [00:00<00:00, 49.27it/s, loss=0.0438]
# Epoch 324/10000: 100%|██████████| 35/35 [00:00<00:00, 49.12it/s, loss=0.0495]
# Epoch 325/10000: 100%|██████████| 35/35 [00:00<00:00, 49.29it/s, loss=0.0199]
# Epoch 326/10000: 100%|██████████| 35/35 [00:00<00:00, 48.81it/s, loss=0.0211]
# Epoch 327/10000: 100%|██████████| 35/35 [00:00<00:00, 49.04it/s, loss=0.0717]
# Epoch 328/10000: 100%|██████████| 35/35 [00:00<00:00, 49.12it/s, loss=0.0553]
# Epoch 329/10000: 100%|██████████| 35/35 [00:00<00:00, 49.31it/s, loss=0.0418]
# Epoch 330/10000: 100%|██████████| 35/35 [00:00<00:00, 49.20it/s, loss=0.0658]
# Epoch 331/10000: 100%|██████████| 35/35 [00:00<00:00, 49.28it/s, loss=0.0728]
# Epoch 332/10000: 100%|██████████| 35/35 [00:00<00:00, 49.21it/s, loss=0.0411]
# Epoch 333/10000: 100%|██████████| 35/35 [00:00<00:00, 49.21it/s, loss=0.0342]
# Epoch 334/10000: 100%|██████████| 35/35 [00:00<00:00, 49.24it/s, loss=0.0612]
# Epoch 335/10000: 100%|██████████| 35/35 [00:00<00:00, 49.11it/s, loss=0.0405]
# Epoch 336/10000: 100%|██████████| 35/35 [00:00<00:00, 48.78it/s, loss=0.0249]
# Epoch 337/10000: 100%|██████████| 35/35 [00:00<00:00, 49.27it/s, loss=0.0526]
# Epoch 338/10000: 100%|██████████| 35/35 [00:00<00:00, 49.32it/s, loss=0.0465]
# Epoch 339/10000: 100%|██████████| 35/35 [00:00<00:00, 49.23it/s, loss=0.0584]
# Epoch 340/10000: 100%|██████████| 35/35 [00:00<00:00, 49.27it/s, loss=0.0329]
# Epoch 341/10000: 100%|██████████| 35/35 [00:00<00:00, 49.02it/s, loss=0.0323]
# Epoch 342/10000: 100%|██████████| 35/35 [00:00<00:00, 48.24it/s, loss=0.0252]
# Epoch 343/10000: 100%|██████████| 35/35 [00:00<00:00, 48.44it/s, loss=0.0511]
# Epoch 344/10000: 100%|██████████| 35/35 [00:00<00:00, 48.53it/s, loss=0.0394]
# Epoch 345/10000: 100%|██████████| 35/35 [00:00<00:00, 48.36it/s, loss=0.0795]
# Epoch 346/10000: 100%|██████████| 35/35 [00:00<00:00, 48.43it/s, loss=0.0139]
# Epoch 347/10000: 100%|██████████| 35/35 [00:00<00:00, 48.36it/s, loss=0.0953]
# Epoch 348/10000: 100%|██████████| 35/35 [00:00<00:00, 48.81it/s, loss=0.0332]
# Epoch 349/10000: 100%|██████████| 35/35 [00:00<00:00, 49.32it/s, loss=0.0382]
# Epoch 350/10000: 100%|██████████| 35/35 [00:00<00:00, 49.30it/s, loss=0.0545]
# Epoch 351/10000: 100%|██████████| 35/35 [00:00<00:00, 49.24it/s, loss=0.0521]
# Epoch 352/10000: 100%|██████████| 35/35 [00:00<00:00, 49.32it/s, loss=0.0321]
# Epoch 353/10000: 100%|██████████| 35/35 [00:00<00:00, 49.32it/s, loss=0.0290]
# Epoch 354/10000: 100%|██████████| 35/35 [00:00<00:00, 49.29it/s, loss=0.0556]
# Epoch 355/10000: 100%|██████████| 35/35 [00:00<00:00, 49.31it/s, loss=0.0493]
# Epoch 356/10000: 100%|██████████| 35/35 [00:00<00:00, 48.94it/s, loss=0.0648]
# Epoch 357/10000: 100%|██████████| 35/35 [00:00<00:00, 49.35it/s, loss=0.0259]
# Epoch 358/10000: 100%|██████████| 35/35 [00:00<00:00, 49.83it/s, loss=0.0659]
# Epoch 359/10000: 100%|██████████| 35/35 [00:00<00:00, 50.06it/s, loss=0.0258]
# Epoch 360/10000: 100%|██████████| 35/35 [00:00<00:00, 50.15it/s, loss=0.0277]
# Epoch 361/10000: 100%|██████████| 35/35 [00:00<00:00, 49.83it/s, loss=0.0550]
# Epoch 362/10000: 100%|██████████| 35/35 [00:00<00:00, 50.24it/s, loss=0.0395]
# Epoch 363/10000: 100%|██████████| 35/35 [00:00<00:00, 50.46it/s, loss=0.0624]
# Epoch 364/10000: 100%|██████████| 35/35 [00:00<00:00, 50.54it/s, loss=0.0248]
# Epoch 365/10000: 100%|██████████| 35/35 [00:00<00:00, 50.52it/s, loss=0.0526]
# Epoch 366/10000: 100%|██████████| 35/35 [00:00<00:00, 50.47it/s, loss=0.0876]
# Epoch 367/10000: 100%|██████████| 35/35 [00:00<00:00, 50.37it/s, loss=0.0655]
# Epoch 368/10000: 100%|██████████| 35/35 [00:00<00:00, 50.39it/s, loss=0.0402]
# Epoch 369/10000: 100%|██████████| 35/35 [00:00<00:00, 48.32it/s, loss=0.0537]
# Epoch 370/10000: 100%|██████████| 35/35 [00:00<00:00, 45.59it/s, loss=0.0363]
# Epoch 371/10000: 100%|██████████| 35/35 [00:00<00:00, 45.61it/s, loss=0.0518]
# Epoch 372/10000: 100%|██████████| 35/35 [00:00<00:00, 49.18it/s, loss=0.0369]
# Epoch 373/10000: 100%|██████████| 35/35 [00:00<00:00, 49.52it/s, loss=0.0246]
# Epoch 374/10000: 100%|██████████| 35/35 [00:00<00:00, 49.56it/s, loss=0.0749]
# Epoch 375/10000: 100%|██████████| 35/35 [00:00<00:00, 49.53it/s, loss=0.0396]
# Epoch 376/10000: 100%|██████████| 35/35 [00:00<00:00, 49.60it/s, loss=0.0582]
# Epoch 377/10000: 100%|██████████| 35/35 [00:00<00:00, 49.49it/s, loss=0.0505]
# Epoch 378/10000: 100%|██████████| 35/35 [00:00<00:00, 49.52it/s, loss=0.0153]
# Epoch 379/10000: 100%|██████████| 35/35 [00:00<00:00, 49.47it/s, loss=0.0460]
# Epoch 380/10000: 100%|██████████| 35/35 [00:00<00:00, 49.72it/s, loss=0.0588]
# Epoch 381/10000: 100%|██████████| 35/35 [00:00<00:00, 49.69it/s, loss=0.0183]
# Epoch 382/10000: 100%|██████████| 35/35 [00:00<00:00, 49.69it/s, loss=0.0423]
# Epoch 383/10000: 100%|██████████| 35/35 [00:00<00:00, 49.68it/s, loss=0.0781]
# Epoch 384/10000: 100%|██████████| 35/35 [00:00<00:00, 49.36it/s, loss=0.0895]
# Epoch 385/10000: 100%|██████████| 35/35 [00:00<00:00, 49.41it/s, loss=0.0282]
# Epoch 386/10000: 100%|██████████| 35/35 [00:00<00:00, 49.46it/s, loss=0.0645]
# Epoch 387/10000: 100%|██████████| 35/35 [00:00<00:00, 49.50it/s, loss=0.0330]
# Epoch 388/10000: 100%|██████████| 35/35 [00:00<00:00, 49.47it/s, loss=0.0847]
# Epoch 389/10000: 100%|██████████| 35/35 [00:00<00:00, 49.42it/s, loss=0.0981]
# Epoch 390/10000: 100%|██████████| 35/35 [00:00<00:00, 49.68it/s, loss=0.0739]
# Epoch 391/10000: 100%|██████████| 35/35 [00:00<00:00, 49.65it/s, loss=0.0340]
# Epoch 392/10000: 100%|██████████| 35/35 [00:00<00:00, 49.44it/s, loss=0.0362]
# Epoch 393/10000: 100%|██████████| 35/35 [00:00<00:00, 49.29it/s, loss=0.0546]
# Epoch 394/10000: 100%|██████████| 35/35 [00:00<00:00, 49.56it/s, loss=0.0295]
# Epoch 395/10000: 100%|██████████| 35/35 [00:00<00:00, 49.55it/s, loss=0.0716]
# Epoch 396/10000: 100%|██████████| 35/35 [00:00<00:00, 49.31it/s, loss=0.1173]
# Epoch 397/10000: 100%|██████████| 35/35 [00:00<00:00, 49.34it/s, loss=0.0201]
# Epoch 398/10000: 100%|██████████| 35/35 [00:00<00:00, 49.27it/s, loss=0.0672]
# Epoch 399/10000: 100%|██████████| 35/35 [00:00<00:00, 49.47it/s, loss=0.0426]
# Epoch 400/10000: 100%|██████████| 35/35 [00:00<00:00, 49.44it/s, loss=0.0504]
# Epoch 401/10000: 100%|██████████| 35/35 [00:00<00:00, 49.25it/s, loss=0.0369]
# Epoch 402/10000: 100%|██████████| 35/35 [00:00<00:00, 49.30it/s, loss=0.0392]
# Epoch 403/10000: 100%|██████████| 35/35 [00:00<00:00, 49.44it/s, loss=0.0408]
# Epoch 404/10000: 100%|██████████| 35/35 [00:00<00:00, 49.39it/s, loss=0.0443]
# Epoch 405/10000: 100%|██████████| 35/35 [00:00<00:00, 49.45it/s, loss=0.0248]
# Epoch 406/10000: 100%|██████████| 35/35 [00:00<00:00, 49.42it/s, loss=0.0608]
# Epoch 407/10000: 100%|██████████| 35/35 [00:00<00:00, 49.57it/s, loss=0.0750]
# Epoch 408/10000: 100%|██████████| 35/35 [00:00<00:00, 49.50it/s, loss=0.0564]
# Epoch 409/10000: 100%|██████████| 35/35 [00:00<00:00, 49.51it/s, loss=0.0283]
# Epoch 410/10000: 100%|██████████| 35/35 [00:00<00:00, 49.55it/s, loss=0.0269]
# Epoch 411/10000: 100%|██████████| 35/35 [00:00<00:00, 49.42it/s, loss=0.0280]
# Epoch 412/10000: 100%|██████████| 35/35 [00:00<00:00, 49.49it/s, loss=0.0451]
# Epoch 413/10000: 100%|██████████| 35/35 [00:00<00:00, 49.25it/s, loss=0.0990]
# Epoch 414/10000: 100%|██████████| 35/35 [00:00<00:00, 49.56it/s, loss=0.0203]
# Epoch 415/10000: 100%|██████████| 35/35 [00:00<00:00, 49.59it/s, loss=0.0233]
# Epoch 416/10000: 100%|██████████| 35/35 [00:00<00:00, 49.58it/s, loss=0.0244]
# Epoch 417/10000: 100%|██████████| 35/35 [00:00<00:00, 49.46it/s, loss=0.0187]
# Epoch 418/10000: 100%|██████████| 35/35 [00:00<00:00, 50.46it/s, loss=0.0758]
# Epoch 419/10000: 100%|██████████| 35/35 [00:00<00:00, 50.55it/s, loss=0.0700]
# Epoch 420/10000: 100%|██████████| 35/35 [00:00<00:00, 50.41it/s, loss=0.0415]
# Epoch 421/10000: 100%|██████████| 35/35 [00:00<00:00, 49.20it/s, loss=0.0338]
# Epoch 422/10000: 100%|██████████| 35/35 [00:00<00:00, 49.67it/s, loss=0.0458]
# Epoch 423/10000: 100%|██████████| 35/35 [00:00<00:00, 49.71it/s, loss=0.0417]
# Epoch 424/10000: 100%|██████████| 35/35 [00:00<00:00, 49.81it/s, loss=0.0767]
# Epoch 425/10000: 100%|██████████| 35/35 [00:00<00:00, 49.75it/s, loss=0.0564]
# Epoch 426/10000: 100%|██████████| 35/35 [00:00<00:00, 49.55it/s, loss=0.0595]
# Epoch 427/10000: 100%|██████████| 35/35 [00:00<00:00, 49.75it/s, loss=0.0289]
# Epoch 428/10000: 100%|██████████| 35/35 [00:00<00:00, 49.70it/s, loss=0.0283]
# Epoch 429/10000: 100%|██████████| 35/35 [00:00<00:00, 49.60it/s, loss=0.0568]
# Epoch 430/10000: 100%|██████████| 35/35 [00:00<00:00, 49.69it/s, loss=0.0981]
# Epoch 431/10000: 100%|██████████| 35/35 [00:00<00:00, 49.53it/s, loss=0.1047]
# Epoch 432/10000: 100%|██████████| 35/35 [00:00<00:00, 49.48it/s, loss=0.0612]
# Epoch 433/10000: 100%|██████████| 35/35 [00:00<00:00, 49.51it/s, loss=0.0352]
# Epoch 434/10000: 100%|██████████| 35/35 [00:00<00:00, 49.51it/s, loss=0.0408]
# Epoch 435/10000: 100%|██████████| 35/35 [00:00<00:00, 49.57it/s, loss=0.0248]
# Epoch 436/10000: 100%|██████████| 35/35 [00:00<00:00, 49.47it/s, loss=0.0651]
# Epoch 437/10000: 100%|██████████| 35/35 [00:00<00:00, 49.53it/s, loss=0.0570]
# Epoch 438/10000: 100%|██████████| 35/35 [00:00<00:00, 49.55it/s, loss=0.0177]
# Epoch 439/10000: 100%|██████████| 35/35 [00:00<00:00, 49.61it/s, loss=0.0836]
# Epoch 440/10000: 100%|██████████| 35/35 [00:00<00:00, 49.56it/s, loss=0.0702]
# Epoch 441/10000: 100%|██████████| 35/35 [00:00<00:00, 49.34it/s, loss=0.0370]
# Epoch 442/10000: 100%|██████████| 35/35 [00:00<00:00, 49.56it/s, loss=0.0518]
# Epoch 443/10000: 100%|██████████| 35/35 [00:00<00:00, 49.06it/s, loss=0.0395]
# Epoch 444/10000: 100%|██████████| 35/35 [00:00<00:00, 49.02it/s, loss=0.0931]
# Epoch 445/10000: 100%|██████████| 35/35 [00:00<00:00, 49.14it/s, loss=0.0675]
# Epoch 446/10000: 100%|██████████| 35/35 [00:00<00:00, 50.01it/s, loss=0.0337]
# Epoch 447/10000: 100%|██████████| 35/35 [00:00<00:00, 49.92it/s, loss=0.0303]
# Epoch 448/10000: 100%|██████████| 35/35 [00:00<00:00, 49.92it/s, loss=0.0586]
# Epoch 449/10000: 100%|██████████| 35/35 [00:00<00:00, 49.90it/s, loss=0.0310]
# Epoch 450/10000: 100%|██████████| 35/35 [00:00<00:00, 49.87it/s, loss=0.0475]
# Epoch 451/10000: 100%|██████████| 35/35 [00:00<00:00, 49.85it/s, loss=0.0404]
# Epoch 452/10000: 100%|██████████| 35/35 [00:00<00:00, 49.91it/s, loss=0.0579]
# Epoch 453/10000: 100%|██████████| 35/35 [00:00<00:00, 49.79it/s, loss=0.0482]
# Epoch 454/10000: 100%|██████████| 35/35 [00:00<00:00, 49.83it/s, loss=0.0548]
# Epoch 455/10000: 100%|██████████| 35/35 [00:00<00:00, 49.78it/s, loss=0.0319]
# Epoch 456/10000: 100%|██████████| 35/35 [00:00<00:00, 49.77it/s, loss=0.0643]
# Epoch 457/10000: 100%|██████████| 35/35 [00:00<00:00, 49.71it/s, loss=0.0317]
# Epoch 458/10000: 100%|██████████| 35/35 [00:00<00:00, 49.74it/s, loss=0.0430]
# Epoch 459/10000: 100%|██████████| 35/35 [00:00<00:00, 49.81it/s, loss=0.0412]
# Epoch 460/10000: 100%|██████████| 35/35 [00:00<00:00, 49.80it/s, loss=0.0471]
# Epoch 461/10000: 100%|██████████| 35/35 [00:00<00:00, 49.87it/s, loss=0.0503]
# Epoch 462/10000: 100%|██████████| 35/35 [00:00<00:00, 49.83it/s, loss=0.0588]
# Epoch 463/10000: 100%|██████████| 35/35 [00:00<00:00, 49.89it/s, loss=0.0648]
# Epoch 464/10000: 100%|██████████| 35/35 [00:00<00:00, 49.92it/s, loss=0.0442]
# Epoch 465/10000: 100%|██████████| 35/35 [00:00<00:00, 49.91it/s, loss=0.0530]
# Epoch 466/10000: 100%|██████████| 35/35 [00:00<00:00, 49.86it/s, loss=0.0271]
# Epoch 467/10000: 100%|██████████| 35/35 [00:00<00:00, 49.81it/s, loss=0.0380]
# Epoch 468/10000: 100%|██████████| 35/35 [00:00<00:00, 49.74it/s, loss=0.0450]
# Epoch 469/10000: 100%|██████████| 35/35 [00:00<00:00, 49.82it/s, loss=0.0568]
# Epoch 470/10000: 100%|██████████| 35/35 [00:00<00:00, 49.94it/s, loss=0.0606]
# Epoch 471/10000: 100%|██████████| 35/35 [00:00<00:00, 49.92it/s, loss=0.0521]
# Epoch 472/10000: 100%|██████████| 35/35 [00:00<00:00, 49.85it/s, loss=0.0313]
# Epoch 473/10000: 100%|██████████| 35/35 [00:00<00:00, 49.85it/s, loss=0.0540]
# Epoch 474/10000: 100%|██████████| 35/35 [00:00<00:00, 49.93it/s, loss=0.0266]
# Epoch 475/10000: 100%|██████████| 35/35 [00:00<00:00, 49.82it/s, loss=0.0786]
# Epoch 476/10000: 100%|██████████| 35/35 [00:00<00:00, 49.95it/s, loss=0.0257]
# Epoch 477/10000: 100%|██████████| 35/35 [00:00<00:00, 49.85it/s, loss=0.0401]
# Epoch 478/10000: 100%|██████████| 35/35 [00:00<00:00, 49.86it/s, loss=0.0508]
# Epoch 479/10000: 100%|██████████| 35/35 [00:00<00:00, 49.87it/s, loss=0.0769]
# Epoch 480/10000: 100%|██████████| 35/35 [00:00<00:00, 49.84it/s, loss=0.0155]
# Epoch 481/10000: 100%|██████████| 35/35 [00:00<00:00, 49.89it/s, loss=0.0176]
# Epoch 482/10000: 100%|██████████| 35/35 [00:00<00:00, 49.62it/s, loss=0.0552]
# Epoch 483/10000: 100%|██████████| 35/35 [00:00<00:00, 49.51it/s, loss=0.0827]
# Epoch 484/10000: 100%|██████████| 35/35 [00:00<00:00, 50.47it/s, loss=0.0641]
# Epoch 485/10000: 100%|██████████| 35/35 [00:00<00:00, 50.55it/s, loss=0.0758]
# Epoch 486/10000: 100%|██████████| 35/35 [00:00<00:00, 50.54it/s, loss=0.0394]
# Epoch 487/10000: 100%|██████████| 35/35 [00:00<00:00, 50.52it/s, loss=0.0215]
# Epoch 488/10000: 100%|██████████| 35/35 [00:00<00:00, 50.65it/s, loss=0.0578]
# Epoch 489/10000: 100%|██████████| 35/35 [00:00<00:00, 50.66it/s, loss=0.0332]
# Epoch 490/10000: 100%|██████████| 35/35 [00:00<00:00, 50.56it/s, loss=0.0534]
# Epoch 491/10000: 100%|██████████| 35/35 [00:00<00:00, 50.31it/s, loss=0.0832]
# Epoch 492/10000: 100%|██████████| 35/35 [00:00<00:00, 50.30it/s, loss=0.0278]
# Epoch 493/10000: 100%|██████████| 35/35 [00:00<00:00, 50.32it/s, loss=0.0608]
# Epoch 494/10000: 100%|██████████| 35/35 [00:00<00:00, 49.84it/s, loss=0.0552]
# Epoch 495/10000: 100%|██████████| 35/35 [00:00<00:00, 49.48it/s, loss=0.0210]
# Epoch 496/10000: 100%|██████████| 35/35 [00:00<00:00, 49.46it/s, loss=0.0464]
# Epoch 497/10000: 100%|██████████| 35/35 [00:00<00:00, 49.04it/s, loss=0.0426]
# Epoch 498/10000: 100%|██████████| 35/35 [00:00<00:00, 48.65it/s, loss=0.0504]
# Epoch 499/10000: 100%|██████████| 35/35 [00:00<00:00, 48.94it/s, loss=0.0420]
# Epoch 500/10000: 100%|██████████| 35/35 [00:00<00:00, 49.08it/s, loss=0.0486]
# Epoch 501/10000: 100%|██████████| 35/35 [00:00<00:00, 49.71it/s, loss=0.0674]
# Epoch 502/10000: 100%|██████████| 35/35 [00:00<00:00, 49.99it/s, loss=0.0466]
# Epoch 503/10000: 100%|██████████| 35/35 [00:00<00:00, 50.11it/s, loss=0.0513]
# Epoch 504/10000: 100%|██████████| 35/35 [00:00<00:00, 50.22it/s, loss=0.0319]
# Epoch 505/10000: 100%|██████████| 35/35 [00:00<00:00, 50.17it/s, loss=0.0617]
# Epoch 506/10000: 100%|██████████| 35/35 [00:00<00:00, 50.18it/s, loss=0.0217]
# Epoch 507/10000: 100%|██████████| 35/35 [00:00<00:00, 49.91it/s, loss=0.0421]
# Epoch 508/10000: 100%|██████████| 35/35 [00:00<00:00, 50.13it/s, loss=0.0509]
# Epoch 509/10000: 100%|██████████| 35/35 [00:00<00:00, 50.27it/s, loss=0.0729]
# Epoch 510/10000: 100%|██████████| 35/35 [00:00<00:00, 50.19it/s, loss=0.0407]
# Epoch 511/10000: 100%|██████████| 35/35 [00:00<00:00, 49.78it/s, loss=0.0677]
# Epoch 512/10000: 100%|██████████| 35/35 [00:00<00:00, 50.12it/s, loss=0.0225]
# Epoch 513/10000: 100%|██████████| 35/35 [00:00<00:00, 50.15it/s, loss=0.0295]
# Epoch 514/10000: 100%|██████████| 35/35 [00:00<00:00, 50.12it/s, loss=0.0407]
# Epoch 515/10000: 100%|██████████| 35/35 [00:00<00:00, 50.18it/s, loss=0.0759]
# Epoch 516/10000: 100%|██████████| 35/35 [00:00<00:00, 50.24it/s, loss=0.0713]
# Epoch 517/10000: 100%|██████████| 35/35 [00:00<00:00, 50.16it/s, loss=0.0388]
# Epoch 518/10000: 100%|██████████| 35/35 [00:00<00:00, 50.19it/s, loss=0.0222]
# Epoch 519/10000: 100%|██████████| 35/35 [00:00<00:00, 50.13it/s, loss=0.0504]
# Epoch 520/10000: 100%|██████████| 35/35 [00:00<00:00, 50.35it/s, loss=0.0458]
# Epoch 521/10000: 100%|██████████| 35/35 [00:00<00:00, 50.31it/s, loss=0.0416]
# Epoch 522/10000: 100%|██████████| 35/35 [00:00<00:00, 49.95it/s, loss=0.0663]
# Epoch 523/10000: 100%|██████████| 35/35 [00:00<00:00, 49.56it/s, loss=0.0259]
# Epoch 524/10000: 100%|██████████| 35/35 [00:00<00:00, 49.54it/s, loss=0.0482]
# Epoch 525/10000: 100%|██████████| 35/35 [00:00<00:00, 49.59it/s, loss=0.0396]
# Epoch 526/10000: 100%|██████████| 35/35 [00:00<00:00, 49.32it/s, loss=0.0634]
# Epoch 527/10000: 100%|██████████| 35/35 [00:00<00:00, 49.65it/s, loss=0.0324]
# Epoch 528/10000: 100%|██████████| 35/35 [00:00<00:00, 49.55it/s, loss=0.0715]
# Epoch 529/10000: 100%|██████████| 35/35 [00:00<00:00, 49.95it/s, loss=0.0180]
# Epoch 530/10000: 100%|██████████| 35/35 [00:00<00:00, 51.14it/s, loss=0.0228]
# Epoch 531/10000: 100%|██████████| 35/35 [00:00<00:00, 51.17it/s, loss=0.0197]
# Epoch 532/10000: 100%|██████████| 35/35 [00:00<00:00, 51.17it/s, loss=0.0184]
# Epoch 533/10000: 100%|██████████| 35/35 [00:00<00:00, 51.26it/s, loss=0.0272]
# Epoch 534/10000: 100%|██████████| 35/35 [00:00<00:00, 51.14it/s, loss=0.0310]
# Epoch 535/10000: 100%|██████████| 35/35 [00:00<00:00, 51.22it/s, loss=0.0408]
# Epoch 536/10000: 100%|██████████| 35/35 [00:00<00:00, 51.13it/s, loss=0.0336]
# Epoch 537/10000: 100%|██████████| 35/35 [00:00<00:00, 51.13it/s, loss=0.0589]
# Epoch 538/10000: 100%|██████████| 35/35 [00:00<00:00, 51.14it/s, loss=0.0392]
# Epoch 539/10000: 100%|██████████| 35/35 [00:00<00:00, 51.11it/s, loss=0.0745]
# Epoch 540/10000: 100%|██████████| 35/35 [00:00<00:00, 51.09it/s, loss=0.0497]
# Epoch 541/10000: 100%|██████████| 35/35 [00:00<00:00, 51.10it/s, loss=0.0648]
# Epoch 542/10000: 100%|██████████| 35/35 [00:00<00:00, 51.14it/s, loss=0.0231]
# Epoch 543/10000: 100%|██████████| 35/35 [00:00<00:00, 51.12it/s, loss=0.0916]
# Epoch 544/10000: 100%|██████████| 35/35 [00:00<00:00, 51.03it/s, loss=0.0147]
# Epoch 545/10000: 100%|██████████| 35/35 [00:00<00:00, 51.11it/s, loss=0.0943]
# Epoch 546/10000: 100%|██████████| 35/35 [00:00<00:00, 49.78it/s, loss=0.0365]
# Epoch 547/10000: 100%|██████████| 35/35 [00:00<00:00, 49.57it/s, loss=0.0538]
# Epoch 548/10000: 100%|██████████| 35/35 [00:00<00:00, 49.56it/s, loss=0.0524]
# Epoch 549/10000: 100%|██████████| 35/35 [00:00<00:00, 51.11it/s, loss=0.0392]
# Epoch 550/10000: 100%|██████████| 35/35 [00:00<00:00, 51.21it/s, loss=0.0585]
# Epoch 551/10000: 100%|██████████| 35/35 [00:00<00:00, 51.10it/s, loss=0.0667]
# Epoch 552/10000: 100%|██████████| 35/35 [00:00<00:00, 51.17it/s, loss=0.0373]
# Epoch 553/10000: 100%|██████████| 35/35 [00:00<00:00, 50.90it/s, loss=0.0622]
# Epoch 554/10000: 100%|██████████| 35/35 [00:00<00:00, 48.95it/s, loss=0.0483]
# Epoch 555/10000: 100%|██████████| 35/35 [00:00<00:00, 49.19it/s, loss=0.0144]
# Epoch 556/10000: 100%|██████████| 35/35 [00:00<00:00, 49.32it/s, loss=0.0391]
# Epoch 557/10000: 100%|██████████| 35/35 [00:00<00:00, 49.35it/s, loss=0.0872]
# Epoch 558/10000: 100%|██████████| 35/35 [00:00<00:00, 49.50it/s, loss=0.0212]
# Epoch 559/10000: 100%|██████████| 35/35 [00:00<00:00, 49.58it/s, loss=0.0316]
# Epoch 560/10000: 100%|██████████| 35/35 [00:00<00:00, 49.63it/s, loss=0.0835]
# Epoch 561/10000: 100%|██████████| 35/35 [00:00<00:00, 49.41it/s, loss=0.0457]
# Epoch 562/10000: 100%|██████████| 35/35 [00:00<00:00, 49.33it/s, loss=0.0818]
# Epoch 563/10000: 100%|██████████| 35/35 [00:00<00:00, 49.58it/s, loss=0.0692]
# Epoch 564/10000: 100%|██████████| 35/35 [00:00<00:00, 49.58it/s, loss=0.0583]
# Epoch 565/10000: 100%|██████████| 35/35 [00:00<00:00, 49.39it/s, loss=0.0626]
# Epoch 566/10000: 100%|██████████| 35/35 [00:00<00:00, 49.89it/s, loss=0.0464]
# Epoch 567/10000: 100%|██████████| 35/35 [00:00<00:00, 49.94it/s, loss=0.0400]
# Epoch 568/10000: 100%|██████████| 35/35 [00:00<00:00, 49.89it/s, loss=0.0283]
# Epoch 569/10000: 100%|██████████| 35/35 [00:00<00:00, 49.74it/s, loss=0.0442]
# Epoch 570/10000: 100%|██████████| 35/35 [00:00<00:00, 49.95it/s, loss=0.0515]
# Epoch 571/10000: 100%|██████████| 35/35 [00:00<00:00, 49.87it/s, loss=0.0568]
# Epoch 572/10000: 100%|██████████| 35/35 [00:00<00:00, 49.90it/s, loss=0.0754]
# Epoch 573/10000: 100%|██████████| 35/35 [00:00<00:00, 49.77it/s, loss=0.0634]
# Epoch 574/10000: 100%|██████████| 35/35 [00:00<00:00, 49.38it/s, loss=0.0286]
# Epoch 575/10000: 100%|██████████| 35/35 [00:00<00:00, 49.67it/s, loss=0.0357]
# Epoch 576/10000: 100%|██████████| 35/35 [00:00<00:00, 49.76it/s, loss=0.0180]
# Epoch 577/10000: 100%|██████████| 35/35 [00:00<00:00, 49.71it/s, loss=0.0570]
# Epoch 578/10000: 100%|██████████| 35/35 [00:00<00:00, 50.57it/s, loss=0.0462]
# Epoch 579/10000: 100%|██████████| 35/35 [00:00<00:00, 51.12it/s, loss=0.0502]
# Epoch 580/10000: 100%|██████████| 35/35 [00:00<00:00, 50.81it/s, loss=0.0221]
# Epoch 581/10000: 100%|██████████| 35/35 [00:00<00:00, 51.05it/s, loss=0.0367]
# Epoch 582/10000: 100%|██████████| 35/35 [00:00<00:00, 50.87it/s, loss=0.0327]
# Epoch 583/10000: 100%|██████████| 35/35 [00:00<00:00, 50.89it/s, loss=0.0281]
# Epoch 584/10000: 100%|██████████| 35/35 [00:00<00:00, 50.40it/s, loss=0.0560]
# Epoch 585/10000: 100%|██████████| 35/35 [00:00<00:00, 49.66it/s, loss=0.0328]
# Epoch 586/10000: 100%|██████████| 35/35 [00:00<00:00, 49.73it/s, loss=0.0343]
# Epoch 587/10000: 100%|██████████| 35/35 [00:00<00:00, 49.87it/s, loss=0.0327]
# Epoch 588/10000: 100%|██████████| 35/35 [00:00<00:00, 50.01it/s, loss=0.0688]
# Epoch 589/10000: 100%|██████████| 35/35 [00:00<00:00, 49.90it/s, loss=0.0670]
# Epoch 590/10000: 100%|██████████| 35/35 [00:00<00:00, 49.89it/s, loss=0.0270]
# Epoch 591/10000: 100%|██████████| 35/35 [00:00<00:00, 49.91it/s, loss=0.0359]
# Epoch 592/10000: 100%|██████████| 35/35 [00:00<00:00, 49.79it/s, loss=0.0827]
# Epoch 593/10000: 100%|██████████| 35/35 [00:00<00:00, 49.48it/s, loss=0.0514]
# Epoch 594/10000: 100%|██████████| 35/35 [00:00<00:00, 50.00it/s, loss=0.0816]
# Epoch 595/10000: 100%|██████████| 35/35 [00:00<00:00, 49.95it/s, loss=0.0622]
# Epoch 596/10000: 100%|██████████| 35/35 [00:00<00:00, 50.01it/s, loss=0.0192]
# Epoch 597/10000: 100%|██████████| 35/35 [00:00<00:00, 49.87it/s, loss=0.0614]
# Epoch 598/10000: 100%|██████████| 35/35 [00:00<00:00, 49.86it/s, loss=0.0426]
# Epoch 599/10000: 100%|██████████| 35/35 [00:00<00:00, 50.00it/s, loss=0.0439]
# Epoch 600/10000: 100%|██████████| 35/35 [00:00<00:00, 49.62it/s, loss=0.0425]
# Epoch 601/10000: 100%|██████████| 35/35 [00:00<00:00, 49.62it/s, loss=0.0349]
# Epoch 602/10000: 100%|██████████| 35/35 [00:00<00:00, 49.75it/s, loss=0.0672]
# Epoch 603/10000: 100%|██████████| 35/35 [00:00<00:00, 50.09it/s, loss=0.0385]
# Epoch 604/10000: 100%|██████████| 35/35 [00:00<00:00, 49.98it/s, loss=0.0497]
# Epoch 605/10000: 100%|██████████| 35/35 [00:00<00:00, 49.72it/s, loss=0.0725]
# Epoch 606/10000: 100%|██████████| 35/35 [00:00<00:00, 49.94it/s, loss=0.0610]
# Epoch 607/10000: 100%|██████████| 35/35 [00:00<00:00, 49.99it/s, loss=0.0578]
# Epoch 608/10000: 100%|██████████| 35/35 [00:00<00:00, 50.08it/s, loss=0.0386]
# Epoch 609/10000: 100%|██████████| 35/35 [00:00<00:00, 49.95it/s, loss=0.0216]
# Epoch 610/10000: 100%|██████████| 35/35 [00:00<00:00, 50.01it/s, loss=0.0422]
# Epoch 611/10000: 100%|██████████| 35/35 [00:00<00:00, 50.04it/s, loss=0.0622]
# Epoch 612/10000: 100%|██████████| 35/35 [00:00<00:00, 50.02it/s, loss=0.0584]
# Epoch 613/10000: 100%|██████████| 35/35 [00:00<00:00, 50.11it/s, loss=0.0774]
# Epoch 614/10000: 100%|██████████| 35/35 [00:00<00:00, 49.98it/s, loss=0.0119]
# Epoch 615/10000: 100%|██████████| 35/35 [00:00<00:00, 49.96it/s, loss=0.0488]
# ...
# Epoch 7655/10000: 100%|██████████| 35/35 [00:00<00:00, 49.69it/s, loss=0.0304]
# Epoch 7656/10000: 100%|██████████| 35/35 [00:00<00:00, 49.66it/s, loss=0.0164]
# Epoch 7657/10000: 100%|██████████| 35/35 [00:00<00:00, 49.30it/s, loss=0.0343]
# Epoch 7658/10000: 100%|██████████| 35/35 [00:00<00:00, 49.85it/s, loss=0.0306]
# Epoch 7659/10000: 100%|██████████| 35/35 [00:00<00:00, 49.79it/s, loss=0.0433]
# Epoch 7660/10000: 100%|██████████| 35/35 [00:00<00:00, 49.86it/s, loss=0.0396]
# Epoch 7661/10000: 100%|██████████| 35/35 [00:00<00:00, 49.81it/s, loss=0.0216]
# Epoch 7662/10000: 100%|██████████| 35/35 [00:00<00:00, 49.94it/s, loss=0.0227]
# Epoch 7663/10000: 100%|██████████| 35/35 [00:00<00:00, 49.95it/s, loss=0.0573]
# Epoch 7664/10000: 100%|██████████| 35/35 [00:00<00:00, 50.02it/s, loss=0.0221]
# Epoch 7665/10000: 100%|██████████| 35/35 [00:00<00:00, 50.12it/s, loss=0.0502]
# Epoch 7666/10000: 100%|██████████| 35/35 [00:00<00:00, 50.00it/s, loss=0.0401]
# Epoch 7667/10000: 100%|██████████| 35/35 [00:00<00:00, 49.96it/s, loss=0.0308]
# Epoch 7668/10000: 100%|██████████| 35/35 [00:00<00:00, 49.93it/s, loss=0.0698]
# Epoch 7669/10000:  14%|█▍        | 5/35 [00:00<00:00, 49.60it/s, loss=0.0307]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# Epoch 8036/10000: 100%|██████████| 35/35 [00:00<00:00, 50.60it/s, loss=0.0207]
# Epoch 8037/10000: 100%|██████████| 35/35 [00:00<00:00, 50.52it/s, loss=0.0255]
# Epoch 8038/10000: 100%|██████████| 35/35 [00:00<00:00, 50.63it/s, loss=0.0534]
# Epoch 8039/10000: 100%|██████████| 35/35 [00:00<00:00, 50.52it/s, loss=0.0502]
# Epoch 8040/10000: 100%|██████████| 35/35 [00:00<00:00, 50.50it/s, loss=0.0240]
# Epoch 8041/10000: 100%|██████████| 35/35 [00:00<00:00, 49.41it/s, loss=0.0367]
# Epoch 8042/10000: 100%|██████████| 35/35 [00:00<00:00, 50.43it/s, loss=0.0384]
# Epoch 8043/10000: 100%|██████████| 35/35 [00:00<00:00, 50.47it/s, loss=0.0352]
# Epoch 8044/10000: 100%|██████████| 35/35 [00:00<00:00, 50.48it/s, loss=0.0314]
# Epoch 8045/10000: 100%|██████████| 35/35 [00:00<00:00, 50.46it/s, loss=0.0302]
# Epoch 8046/10000: 100%|██████████| 35/35 [00:00<00:00, 50.60it/s, loss=0.0351]
# Epoch 8047/10000: 100%|██████████| 35/35 [00:00<00:00, 50.73it/s, loss=0.0277]
# Epoch 8048/10000: 100%|██████████| 35/35 [00:00<00:00, 50.63it/s, loss=0.0354]
# Epoch 8049/10000: 100%|██████████| 35/35 [00:00<00:00, 50.49it/s, loss=0.0207]
# Epoch 8050/10000: 100%|██████████| 35/35 [00:00<00:00, 50.55it/s, loss=0.0230]
# Epoch 8051/10000: 100%|██████████| 35/35 [00:00<00:00, 50.51it/s, loss=0.0213]
# Epoch 8052/10000: 100%|██████████| 35/35 [00:00<00:00, 50.56it/s, loss=0.0228]
# Epoch 8053/10000: 100%|██████████| 35/35 [00:00<00:00, 50.60it/s, loss=0.0386]
# Epoch 8054/10000: 100%|██████████| 35/35 [00:00<00:00, 50.54it/s, loss=0.0187]
# Epoch 8055/10000: 100%|██████████| 35/35 [00:00<00:00, 50.16it/s, loss=0.0292]
# Epoch 8056/10000: 100%|██████████| 35/35 [00:00<00:00, 50.45it/s, loss=0.0201]
# Epoch 8057/10000: 100%|██████████| 35/35 [00:00<00:00, 50.50it/s, loss=0.0287]
# Epoch 8058/10000: 100%|██████████| 35/35 [00:00<00:00, 50.24it/s, loss=0.0259]
# Epoch 8059/10000: 100%|██████████| 35/35 [00:00<00:00, 50.07it/s, loss=0.0148]
# Epoch 8060/10000: 100%|██████████| 35/35 [00:00<00:00, 49.89it/s, loss=0.0309]
# Epoch 8061/10000: 100%|██████████| 35/35 [00:00<00:00, 50.34it/s, loss=0.0245]
# Epoch 8062/10000: 100%|██████████| 35/35 [00:00<00:00, 50.20it/s, loss=0.0101]
# Epoch 8063/10000: 100%|██████████| 35/35 [00:00<00:00, 50.47it/s, loss=0.0230]
# Epoch 8064/10000: 100%|██████████| 35/35 [00:00<00:00, 50.49it/s, loss=0.0217]
# Epoch 8065/10000: 100%|██████████| 35/35 [00:00<00:00, 50.47it/s, loss=0.0270]
# Epoch 8066/10000: 100%|██████████| 35/35 [00:00<00:00, 50.50it/s, loss=0.0186]
# Epoch 8067/10000: 100%|██████████| 35/35 [00:00<00:00, 50.47it/s, loss=0.0259]
# Epoch 8068/10000: 100%|██████████| 35/35 [00:00<00:00, 50.65it/s, loss=0.0217]
# Epoch 8069/10000: 100%|██████████| 35/35 [00:00<00:00, 50.51it/s, loss=0.0362]
# Epoch 8070/10000: 100%|██████████| 35/35 [00:00<00:00, 49.59it/s, loss=0.0206]
# Epoch 8071/10000: 100%|██████████| 35/35 [00:00<00:00, 50.47it/s, loss=0.0278]
# Epoch 8072/10000: 100%|██████████| 35/35 [00:00<00:00, 50.57it/s, loss=0.0441]
# Epoch 8073/10000: 100%|██████████| 35/35 [00:00<00:00, 50.60it/s, loss=0.0310]
# Epoch 8074/10000: 100%|██████████| 35/35 [00:00<00:00, 50.18it/s, loss=0.0227]
# Epoch 8168/10000: 100%|██████████| 35/35 [00:00<00:00, 51.02it/s, loss=0.0273]
# Epoch 8169/10000: 100%|██████████| 35/35 [00:00<00:00, 51.15it/s, loss=0.0232]
# Epoch 8170/10000: 100%|██████████| 35/35 [00:00<00:00, 50.80it/s, loss=0.0338]
# Epoch 8171/10000: 100%|██████████| 35/35 [00:00<00:00, 50.88it/s, loss=0.0376]
# Epoch 8172/10000: 100%|██████████| 35/35 [00:00<00:00, 50.99it/s, loss=0.0312]
# Epoch 8173/10000: 100%|██████████| 35/35 [00:00<00:00, 50.92it/s, loss=0.0461]
# Epoch 8174/10000: 100%|██████████| 35/35 [00:00<00:00, 50.81it/s, loss=0.0197]
# Epoch 8175/10000: 100%|██████████| 35/35 [00:00<00:00, 50.90it/s, loss=0.0230]
# Epoch 8176/10000: 100%|██████████| 35/35 [00:00<00:00, 51.02it/s, loss=0.0499]
# Epoch 8177/10000: 100%|██████████| 35/35 [00:00<00:00, 50.92it/s, loss=0.0301]
# Epoch 8178/10000: 100%|██████████| 35/35 [00:00<00:00, 51.01it/s, loss=0.0244]
# Epoch 8179/10000: 100%|██████████| 35/35 [00:00<00:00, 50.97it/s, loss=0.0183]
# Epoch 8180/10000: 100%|██████████| 35/35 [00:00<00:00, 50.91it/s, loss=0.0236]
# Epoch 8181/10000: 100%|██████████| 35/35 [00:00<00:00, 50.94it/s, loss=0.0277]
# Epoch 8182/10000: 100%|██████████| 35/35 [00:00<00:00, 50.95it/s, loss=0.0292]
# Epoch 8183/10000: 100%|██████████| 35/35 [00:00<00:00, 50.95it/s, loss=0.0236]
# Epoch 8184/10000: 100%|██████████| 35/35 [00:00<00:00, 50.84it/s, loss=0.0203]
# Epoch 8185/10000: 100%|██████████| 35/35 [00:00<00:00, 50.74it/s, loss=0.0462]
# Epoch 8186/10000: 100%|██████████| 35/35 [00:00<00:00, 50.96it/s, loss=0.0326]
# Epoch 8187/10000: 100%|██████████| 35/35 [00:00<00:00, 51.04it/s, loss=0.0183]
# Epoch 8188/10000: 100%|██████████| 35/35 [00:00<00:00, 51.08it/s, loss=0.0451]
# Epoch 8189/10000: 100%|██████████| 35/35 [00:00<00:00, 51.08it/s, loss=0.0269]
# Epoch 8190/10000: 100%|██████████| 35/35 [00:00<00:00, 51.08it/s, loss=0.0115]
# Epoch 8191/10000: 100%|██████████| 35/35 [00:00<00:00, 51.31it/s, loss=0.0272]
# Epoch 8192/10000: 100%|██████████| 35/35 [00:00<00:00, 51.25it/s, loss=0.0264]
# Epoch 8193/10000: 100%|██████████| 35/35 [00:00<00:00, 51.18it/s, loss=0.0276]
# Epoch 8194/10000: 100%|██████████| 35/35 [00:00<00:00, 51.31it/s, loss=0.0405]
# Epoch 8195/10000: 100%|██████████| 35/35 [00:00<00:00, 51.11it/s, loss=0.0205]
# Epoch 8196/10000: 100%|██████████| 35/35 [00:00<00:00, 51.24it/s, loss=0.0289]
# Epoch 8197/10000: 100%|██████████| 35/35 [00:00<00:00, 51.31it/s, loss=0.0368]
# Epoch 8198/10000: 100%|██████████| 35/35 [00:00<00:00, 51.31it/s, loss=0.0419]
# Epoch 8199/10000: 100%|██████████| 35/35 [00:00<00:00, 51.05it/s, loss=0.0458]
# Epoch 8200/10000: 100%|██████████| 35/35 [00:00<00:00, 50.90it/s, loss=0.0444]
# Epoch 8201/10000: 100%|██████████| 35/35 [00:00<00:00, 51.07it/s, loss=0.0187]
# Epoch 8202/10000: 100%|██████████| 35/35 [00:00<00:00, 50.02it/s, loss=0.0222]
# Epoch 8203/10000: 100%|██████████| 35/35 [00:00<00:00, 50.11it/s, loss=0.0190]
# Epoch 8204/10000: 100%|██████████| 35/35 [00:00<00:00, 49.96it/s, loss=0.0231]
# Epoch 8205/10000: 100%|██████████| 35/35 [00:00<00:00, 50.23it/s, loss=0.0174]
# Epoch 8206/10000: 100%|██████████| 35/35 [00:00<00:00, 50.24it/s, loss=0.0157]
# Epoch 8207/10000: 100%|██████████| 35/35 [00:00<00:00, 50.22it/s, loss=0.0430]
# Epoch 8208/10000: 100%|██████████| 35/35 [00:00<00:00, 50.14it/s, loss=0.0295]
# Epoch 8209/10000: 100%|██████████| 35/35 [00:00<00:00, 49.67it/s, loss=0.0174]
# Epoch 8210/10000: 100%|██████████| 35/35 [00:00<00:00, 50.01it/s, loss=0.0295]
# Epoch 8211/10000: 100%|██████████| 35/35 [00:00<00:00, 50.03it/s, loss=0.0532]
# Epoch 8212/10000: 100%|██████████| 35/35 [00:00<00:00, 49.76it/s, loss=0.0263]
# Epoch 8213/10000: 100%|██████████| 35/35 [00:00<00:00, 49.64it/s, loss=0.0140]
# Epoch 8214/10000: 100%|██████████| 35/35 [00:00<00:00, 51.32it/s, loss=0.0065]
# Epoch 8215/10000: 100%|██████████| 35/35 [00:00<00:00, 49.19it/s, loss=0.0485]
# Epoch 8216/10000: 100%|██████████| 35/35 [00:00<00:00, 50.34it/s, loss=0.0480]
# Epoch 8217/10000: 100%|██████████| 35/35 [00:00<00:00, 50.52it/s, loss=0.0241]
# Epoch 8218/10000: 100%|██████████| 35/35 [00:00<00:00, 51.01it/s, loss=0.0550]
# Epoch 8219/10000: 100%|██████████| 35/35 [00:00<00:00, 50.83it/s, loss=0.0331]
# Epoch 8220/10000: 100%|██████████| 35/35 [00:00<00:00, 51.01it/s, loss=0.0371]
# Epoch 8221/10000: 100%|██████████| 35/35 [00:00<00:00, 51.03it/s, loss=0.0334]
# Epoch 8222/10000: 100%|██████████| 35/35 [00:00<00:00, 50.87it/s, loss=0.0231]
# Epoch 8223/10000: 100%|██████████| 35/35 [00:00<00:00, 50.85it/s, loss=0.0433]
# Epoch 8224/10000: 100%|██████████| 35/35 [00:00<00:00, 50.63it/s, loss=0.0377]
# Epoch 8225/10000: 100%|██████████| 35/35 [00:00<00:00, 50.86it/s, loss=0.0499]
# Epoch 8226/10000: 100%|██████████| 35/35 [00:00<00:00, 50.81it/s, loss=0.0270]
# Epoch 8227/10000: 100%|██████████| 35/35 [00:00<00:00, 50.97it/s, loss=0.0241]
# Epoch 8228/10000: 100%|██████████| 35/35 [00:00<00:00, 50.61it/s, loss=0.0486]
# Epoch 8229/10000: 100%|██████████| 35/35 [00:00<00:00, 50.17it/s, loss=0.0345]
# Epoch 8230/10000: 100%|██████████| 35/35 [00:00<00:00, 50.57it/s, loss=0.0196]
# Epoch 8231/10000: 100%|██████████| 35/35 [00:00<00:00, 50.71it/s, loss=0.0248]
# Epoch 8232/10000: 100%|██████████| 35/35 [00:00<00:00, 50.27it/s, loss=0.0368]
# Epoch 8233/10000: 100%|██████████| 35/35 [00:00<00:00, 50.98it/s, loss=0.0363]
# Epoch 8234/10000: 100%|██████████| 35/35 [00:00<00:00, 50.95it/s, loss=0.0185]
# Epoch 8235/10000: 100%|██████████| 35/35 [00:00<00:00, 50.96it/s, loss=0.0319]
# Epoch 8236/10000:  86%|████████▌ | 30/35 [00:00<00:00, 50.78it/s, loss=0.0294]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# Epoch 9563/10000: 100%|██████████| 35/35 [00:00<00:00, 45.90it/s, loss=0.0326]
# Epoch 9564/10000: 100%|██████████| 35/35 [00:00<00:00, 45.79it/s, loss=0.0277]
# Epoch 9565/10000: 100%|██████████| 35/35 [00:00<00:00, 45.65it/s, loss=0.0411]
# Epoch 9566/10000: 100%|██████████| 35/35 [00:00<00:00, 46.10it/s, loss=0.0226]
# Epoch 9567/10000: 100%|██████████| 35/35 [00:00<00:00, 45.92it/s, loss=0.0352]
# Epoch 9568/10000: 100%|██████████| 35/35 [00:00<00:00, 45.55it/s, loss=0.0212]
# Epoch 9569/10000: 100%|██████████| 35/35 [00:00<00:00, 46.03it/s, loss=0.0319]
# Epoch 9570/10000: 100%|██████████| 35/35 [00:00<00:00, 45.86it/s, loss=0.0160]
# Epoch 9571/10000: 100%|██████████| 35/35 [00:00<00:00, 48.97it/s, loss=0.0205]
# Epoch 9572/10000: 100%|██████████| 35/35 [00:00<00:00, 49.61it/s, loss=0.0262]
# Epoch 9573/10000: 100%|██████████| 35/35 [00:00<00:00, 46.24it/s, loss=0.0201]
# Epoch 9574/10000: 100%|██████████| 35/35 [00:00<00:00, 45.57it/s, loss=0.0299]
# Epoch 9575/10000: 100%|██████████| 35/35 [00:00<00:00, 46.05it/s, loss=0.0293]
# Epoch 9576/10000: 100%|██████████| 35/35 [00:00<00:00, 46.07it/s, loss=0.0357]
# Epoch 9577/10000: 100%|██████████| 35/35 [00:00<00:00, 46.03it/s, loss=0.0148]
# Epoch 9578/10000: 100%|██████████| 35/35 [00:00<00:00, 45.94it/s, loss=0.0184]
# Epoch 9579/10000: 100%|██████████| 35/35 [00:00<00:00, 45.89it/s, loss=0.0200]
# Epoch 9580/10000: 100%|██████████| 35/35 [00:00<00:00, 45.69it/s, loss=0.0244]
# Epoch 9581/10000: 100%|██████████| 35/35 [00:00<00:00, 46.07it/s, loss=0.0183]
# Epoch 9582/10000: 100%|██████████| 35/35 [00:00<00:00, 50.92it/s, loss=0.0258]
# Epoch 9583/10000: 100%|██████████| 35/35 [00:00<00:00, 48.60it/s, loss=0.0225]
# Epoch 9584/10000: 100%|██████████| 35/35 [00:00<00:00, 46.06it/s, loss=0.0295]
# Epoch 9585/10000: 100%|██████████| 35/35 [00:00<00:00, 46.05it/s, loss=0.0234]
# Epoch 9586/10000: 100%|██████████| 35/35 [00:00<00:00, 45.89it/s, loss=0.0337]
# Epoch 9587/10000: 100%|██████████| 35/35 [00:00<00:00, 46.05it/s, loss=0.0268]
# Epoch 9588/10000: 100%|██████████| 35/35 [00:00<00:00, 46.02it/s, loss=0.0297]
# Epoch 9589/10000: 100%|██████████| 35/35 [00:00<00:00, 46.03it/s, loss=0.0311]
# Epoch 9590/10000: 100%|██████████| 35/35 [00:00<00:00, 46.07it/s, loss=0.0297]
# Epoch 9591/10000: 100%|██████████| 35/35 [00:00<00:00, 46.06it/s, loss=0.0368]
# Epoch 9592/10000: 100%|██████████| 35/35 [00:00<00:00, 45.91it/s, loss=0.0206]
# Epoch 9593/10000: 100%|██████████| 35/35 [00:00<00:00, 49.08it/s, loss=0.0163]
# Epoch 9594/10000: 100%|██████████| 35/35 [00:00<00:00, 51.03it/s, loss=0.0264]
# Epoch 9595/10000: 100%|██████████| 35/35 [00:00<00:00, 51.12it/s, loss=0.0298]
# Epoch 9596/10000: 100%|██████████| 35/35 [00:00<00:00, 51.12it/s, loss=0.0229]
# Epoch 9597/10000: 100%|██████████| 35/35 [00:00<00:00, 51.17it/s, loss=0.0223]
# Epoch 9598/10000: 100%|██████████| 35/35 [00:00<00:00, 50.66it/s, loss=0.0336]
# Epoch 9599/10000: 100%|██████████| 35/35 [00:00<00:00, 51.10it/s, loss=0.0377]
# Epoch 9600/10000: 100%|██████████| 35/35 [00:00<00:00, 51.07it/s, loss=0.0220]
# Epoch 9601/10000: 100%|██████████| 35/35 [00:00<00:00, 51.02it/s, loss=0.0250]
# Epoch 9602/10000: 100%|██████████| 35/35 [00:00<00:00, 51.06it/s, loss=0.0294]
# Epoch 9603/10000: 100%|██████████| 35/35 [00:00<00:00, 51.15it/s, loss=0.0237]
# Epoch 9604/10000: 100%|██████████| 35/35 [00:00<00:00, 51.19it/s, loss=0.0184]
# Epoch 9605/10000: 100%|██████████| 35/35 [00:00<00:00, 51.21it/s, loss=0.0178]
# Epoch 9606/10000: 100%|██████████| 35/35 [00:00<00:00, 46.99it/s, loss=0.0203]
# Epoch 9607/10000: 100%|██████████| 35/35 [00:00<00:00, 46.12it/s, loss=0.0203]
# Epoch 9608/10000: 100%|██████████| 35/35 [00:00<00:00, 46.08it/s, loss=0.0312]
# Epoch 9609/10000: 100%|██████████| 35/35 [00:00<00:00, 46.04it/s, loss=0.0147]
# Epoch 9610/10000: 100%|██████████| 35/35 [00:00<00:00, 46.04it/s, loss=0.0343]
# Epoch 9611/10000: 100%|██████████| 35/35 [00:00<00:00, 46.02it/s, loss=0.0300]
# Epoch 9612/10000: 100%|██████████| 35/35 [00:00<00:00, 46.09it/s, loss=0.0299]
# Epoch 9613/10000: 100%|██████████| 35/35 [00:00<00:00, 45.96it/s, loss=0.0164]
# Epoch 9614/10000: 100%|██████████| 35/35 [00:00<00:00, 48.74it/s, loss=0.0251]
# Epoch 9615/10000: 100%|██████████| 35/35 [00:00<00:00, 49.56it/s, loss=0.0360]
# Epoch 9616/10000: 100%|██████████| 35/35 [00:00<00:00, 49.66it/s, loss=0.0179]
# Epoch 9617/10000: 100%|██████████| 35/35 [00:00<00:00, 49.59it/s, loss=0.0334]
# Epoch 9618/10000: 100%|██████████| 35/35 [00:00<00:00, 49.65it/s, loss=0.0149]
# Epoch 9619/10000: 100%|██████████| 35/35 [00:00<00:00, 49.61it/s, loss=0.0252]
# Epoch 9620/10000: 100%|██████████| 35/35 [00:00<00:00, 49.63it/s, loss=0.0375]
# Epoch 9621/10000: 100%|██████████| 35/35 [00:00<00:00, 49.62it/s, loss=0.0172]
# Epoch 9622/10000: 100%|██████████| 35/35 [00:00<00:00, 49.54it/s, loss=0.0203]
# Epoch 9623/10000: 100%|██████████| 35/35 [00:00<00:00, 47.52it/s, loss=0.0216]
# Epoch 9624/10000: 100%|██████████| 35/35 [00:00<00:00, 46.01it/s, loss=0.0191]
# Epoch 9625/10000: 100%|██████████| 35/35 [00:00<00:00, 45.98it/s, loss=0.0395]
# Epoch 9626/10000: 100%|██████████| 35/35 [00:00<00:00, 45.98it/s, loss=0.0217]
# Epoch 9627/10000: 100%|██████████| 35/35 [00:00<00:00, 45.97it/s, loss=0.0212]
# Epoch 9628/10000: 100%|██████████| 35/35 [00:00<00:00, 46.01it/s, loss=0.0245]
# Epoch 9629/10000:   0%|          | 0/35 [00:00<?, ?it/s, loss=0.0385]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ### Test

# %%
x_test = next(iter(test_loader))
x_test.shape
# Out:
# torch.Size([32, 64, 14, 1])

# %%
verify_scaling(x_test)
# Out:
# Max: 0.7534
# Min: -1.0000
# Mean: 0.0029
# Std: 0.0867

# %%
prediction = engine.simulate(x_test, steps_to_predict=8)
prediction.shape
# Out:
# INFO:engine.trainer:Simulating... (Masking last 8 steps)
# In-painting: 1000it [00:04, 231.70it/s]
# (32, 64, 14, 1)

# %%
verify_scaling(prediction)
# Out:
# Max: 0.7534
# Min: -1.0000
# Mean: 0.0034
# Std: 0.0855

# %% [markdown]
# ## Monte Carlo Sim (GenAI)

# %%
@torch.no_grad()
def monte_carlo_simulate(context_data, steps_to_simulate, engine,num_simulations=100):
    x_context = context_data.repeat(num_simulations, 1, 1, 1).to(engine.device)
    mc_results = engine.simulate(x_context, steps_to_simulate)
    return mc_results

# %%
x_test_sampling = x_test[0].unsqueeze(0)
x_test_sampling.shape
# Out:
# torch.Size([1, 64, 14, 1])

# %%
mc_y = monte_carlo_simulate(context_data=x_test_sampling, steps_to_simulate=24, engine=engine,num_simulations=100)
mc_y.shape # [Sims, Time, Assets, Features]
# Out:
# INFO:engine.trainer:Simulating... (Masking last 24 steps)
# In-painting: 1000it [00:05, 188.43it/s]
# (100, 64, 14, 1)

# %% [markdown]
# ## Monete Carlo Statistic

# %%
def gbm_monte_carlo_simulate(hist_log_returns: np.ndarray, steps_to_predict: int, num_sims: int = 100, dt: float = 1.0):
    """ Arg: 
            dt: Time increment
        Returns: 
            future_prices: [num_sims, steps_to_predict]
    """
    mu = np.mean(hist_log_returns)
    sigma = np.std(hist_log_returns)

    # Random Shock (Z) from Normal Dist (0, 1) -> shape: [num_sims, steps_to_predict]
    Z = np.random.normal(0, 1, (num_sims, steps_to_predict))

    # Future log returns (GBM)
    # r_t = (mu - 0.5 * sigma^2) * dt + sigma * sqrt(dt) * Z
    drift_term = (mu - 0.5 * sigma**2) * dt
    shock_term = sigma * np.sqrt(dt) * Z

    future_daily_log_returns = drift_term + shock_term
    cum_log_returns = np.cumsum(future_daily_log_returns, axis=1)

    # future_prices = last_price * np.exp(cum_log_returns)
    
    return future_daily_log_returns

# %%
x_test_sampling.shape
# Out:
# torch.Size([1, 64, 14, 1])

# %%
x_test_statistic_sampling = x_test_sampling[0,:,:,:]
x_test_statistic_sampling.shape
# Out:
# torch.Size([64, 14, 1])

# %%
x_test_statistic_sampling = x_test_statistic_sampling[:,0,0]
x_test_statistic_sampling.shape
# Out:
# torch.Size([64])

# %%
type(x_test_statistic_sampling)
# Out:
# torch.Tensor

# %%
mc_paths = gbm_monte_carlo_simulate(
    hist_log_returns=x_test_statistic_sampling.cpu().numpy(), 
    steps_to_predict=14, 
    num_sims=1000
)
type(mc_paths)
# Out:
# numpy.ndarray

# %%
asset_tests = x_test_sampling[0, :,:, :]
asset_tests.shape
# Out:
# torch.Size([64, 14, 1])

# %%
asset_tests = asset_tests.permute(1,0,2)
asset_tests.shape
# Out:
# torch.Size([14, 64, 1])

# %%
mc_simed_ret_assets = []
for asset in asset_tests:
    mc_sim_ret = gbm_monte_carlo_simulate(
        hist_log_returns=asset[:, 0].cpu().numpy(), 
        steps_to_predict=14, 
        num_sims=1000
    )
    mc_simed_ret_assets.append(mc_sim_ret)

# %%
len(mc_simed_ret_assets)
# Out:
# 14

# %%
for asset in mc_simed_ret_assets:
    mc_ret_context = asset[:, -1]
    mc_ret_sim = asset[-1, :]

    mean_ret_sim = np.mean(mc_ret_sim)
    std_ret_sim = np.std(mc_ret_sim)
    upper_bound = np.percentile(mc_ret_sim, 95) # Best case 5%
    lower_bound = np.percentile(mc_ret_sim, 5) # Worst case 5%
    print(f"mean: {mean_ret_sim}, std: {std_ret_sim}")
    print(f"lower bound: {lower_bound}, upper bound:{upper_bound}")
# Out:
# mean: 0.002491280837437757, std: 0.08141816507859992
# lower bound: -0.1252065970692252, upper bound:0.10483787847538428
# mean: 0.04716399162746091, std: 0.10936617481394569
# lower bound: -0.11293988520344413, upper bound:0.1845300599346691
# mean: -0.012204400285022485, std: 0.03539453197413641
# lower bound: -0.06170342043078813, upper bound:0.04110536303782341
# mean: -0.0007115863467340633, std: 0.047569639485703086
# lower bound: -0.07548524584718386, upper bound:0.06048306215666034
# mean: -0.004862042215274051, std: 0.04969240564477675
# lower bound: -0.06484472568901019, upper bound:0.0772373421422919
# mean: -0.021368856465613855, std: 0.059578225264141624
# lower bound: -0.10077731825207402, upper bound:0.06878581308903141
# mean: -0.011499687616607463, std: 0.05599845564963771
# lower bound: -0.10940968500214636, upper bound:0.05742788708742507
# mean: -0.04428694703068197, std: 0.06728134535336518
# lower bound: -0.1596704680788574, upper bound:0.04995866440779526
# mean: -0.010277519310936147, std: 0.04568396437208417
# lower bound: -0.08247636016434862, upper bound:0.06903400343891924
# mean: 0.0021479433348108555, std: 0.03183760755478977
# lower bound: -0.03704888130746667, upper bound:0.04886289409681136
# mean: -0.015948231943064335, std: 0.0687154343938609
# lower bound: -0.11882834656155071, upper bound:0.08703870260305689
# mean: -0.018352563018625277, std: 0.06218202941139255
# lower bound: -0.12890327438145505, upper bound:0.05399433122618419
# mean: 0.020744761759218272, std: 0.09397435007072212
# lower bound: -0.10667176659191739, upper bound:0.1632946883310966
# mean: -0.00046772327146450785, std: 0.036898233576147445
# lower bound: -0.058169020461267, upper bound:0.05380402526627498

# %%
sim_results_per_asset = []

for asset_sim in mc_simed_ret_assets:
    # asset_sim shape: (1000, 14) -> Daily Log Returns
    
    # รวม Log Return 14 วัน เป็นก้อนเดียว (Total Log Return)
    # axis=1 คือรวมตามแกนเวลา (Time)
    total_return = np.sum(asset_sim, axis=1) # ได้ shape (1000,)
    
    sim_results_per_asset.append(total_return)

# 2. แปลงเป็น Matrix (Num_Assets, Num_Sims)
# เช่น (3, 1000)
comparison_matrix = np.array(sim_results_per_asset)

# 3. คำนวณ Correlation Matrix
corr_matrix = np.corrcoef(comparison_matrix)

print("Correlation Matrix:")
print(corr_matrix)

# (แถม) วาด Heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.show()
# Out:
# Correlation Matrix:
# [[ 1.00000000e+00 -3.58463846e-02  1.88759744e-02  3.41571748e-02
#    2.66954313e-02  2.78027950e-02 -3.86282760e-02  4.00300163e-02
#    5.63335148e-02 -2.96361808e-02  1.41270441e-03  1.07710915e-02
#   -5.81165880e-02  1.85740780e-02]
#  [-3.58463846e-02  1.00000000e+00 -1.19901559e-02 -1.00175528e-02
#   -9.23696902e-03 -1.98877877e-02 -5.00104792e-03 -3.02605061e-02
#    1.05330307e-02 -1.19506156e-02  2.70976712e-02 -2.01694642e-02
#   -8.80831577e-03  2.20235190e-02]
#  [ 1.88759744e-02 -1.19901559e-02  1.00000000e+00 -3.38911836e-02
#   -1.95395155e-02 -3.97201522e-02  2.33402387e-02 -1.04229684e-02
#   -2.59397170e-02 -1.23440282e-02 -1.27085493e-02 -3.60418869e-03
#   -6.73065283e-03 -3.83781086e-02]
#  [ 3.41571748e-02 -1.00175528e-02 -3.38911836e-02  1.00000000e+00
#   -2.24242792e-02 -2.81002446e-02  4.52738417e-02 -1.35548015e-02
#    2.44772743e-02 -1.20878659e-02  9.01888078e-03  3.96628848e-03
#    3.90561769e-02  1.95297290e-02]
#  [ 2.66954313e-02 -9.23696902e-03 -1.95395155e-02 -2.24242792e-02
#    1.00000000e+00 -5.46249154e-02 -3.63572828e-02 -1.04883592e-02
#    3.34533629e-02 -9.92700378e-03 -4.86715648e-03 -5.66230810e-03
#    1.43012547e-02  1.33314194e-02]
#  [ 2.78027950e-02 -1.98877877e-02 -3.97201522e-02 -2.81002446e-02
#   -5.46249154e-02  1.00000000e+00 -7.38649072e-02 -2.77478148e-03
#   -5.38057341e-02 -1.68029067e-03 -8.06887669e-02 -4.43530266e-02
#   -1.61921446e-02  1.31085555e-02]
#  [-3.86282760e-02 -5.00104792e-03  2.33402387e-02  4.52738417e-02
#   -3.63572828e-02 -7.38649072e-02  1.00000000e+00  4.20492227e-02
#    1.93944009e-02  2.61410021e-02  1.41657259e-02 -2.58973865e-02
#    5.69178838e-02 -5.62640910e-02]
#  [ 4.00300163e-02 -3.02605061e-02 -1.04229684e-02 -1.35548015e-02
#   -1.04883592e-02 -2.77478148e-03  4.20492227e-02  1.00000000e+00
#    1.57766242e-02 -2.00775741e-02 -3.01393126e-02  1.19747093e-03
#   -1.94527809e-03 -1.82041381e-02]
#  [ 5.63335148e-02  1.05330307e-02 -2.59397170e-02  2.44772743e-02
#    3.34533629e-02 -5.38057341e-02  1.93944009e-02  1.57766242e-02
#    1.00000000e+00 -2.53261994e-02 -2.62478867e-03 -6.49231704e-03
#    3.69726402e-02  2.06733298e-02]
#  [-2.96361808e-02 -1.19506156e-02 -1.23440282e-02 -1.20878659e-02
#   -9.92700378e-03 -1.68029067e-03  2.61410021e-02 -2.00775741e-02
#   -2.53261994e-02  1.00000000e+00 -1.38050030e-02  3.37700991e-02
#    3.93747219e-02 -5.62290734e-02]
#  [ 1.41270441e-03  2.70976712e-02 -1.27085493e-02  9.01888078e-03
#   -4.86715648e-03 -8.06887669e-02  1.41657259e-02 -3.01393126e-02
#   -2.62478867e-03 -1.38050030e-02  1.00000000e+00 -2.77422043e-02
#   -4.29082077e-02 -4.00741493e-02]
#  [ 1.07710915e-02 -2.01694642e-02 -3.60418869e-03  3.96628848e-03
#   -5.66230810e-03 -4.43530266e-02 -2.58973865e-02  1.19747093e-03
#   -6.49231704e-03  3.37700991e-02 -2.77422043e-02  1.00000000e+00
#    3.08895769e-04 -7.40420134e-03]
#  [-5.81165880e-02 -8.80831577e-03 -6.73065283e-03  3.90561769e-02
#    1.43012547e-02 -1.61921446e-02  5.69178838e-02 -1.94527809e-03
#    3.69726402e-02  3.93747219e-02 -4.29082077e-02  3.08895769e-04
#    1.00000000e+00 -2.43009167e-02]
#  [ 1.85740780e-02  2.20235190e-02 -3.83781086e-02  1.95297290e-02
#    1.33314194e-02  1.31085555e-02 -5.62640910e-02 -1.82041381e-02
#    2.06733298e-02 -5.62290734e-02 -4.00741493e-02 -7.40420134e-03
#   -2.43009167e-02  1.00000000e+00]]

# %% [markdown]
# ## Experiment

# %% [markdown]
# ### Ground Truth Stats

# %%
x_test = next(iter(test_loader))
x_test_sampling = x_test[2, :, :, :]
x_test_sampling.shape
# Out:
# torch.Size([64, 14, 1])

# %%
x_test_sampling_np = x_test_sampling.cpu().numpy()
print(type(x_test_sampling))
print(type(x_test_sampling_np))
# Out:
# <class 'torch.Tensor'>
# <class 'numpy.ndarray'>

# %%
def calc_stats(x):
    if x.ndim == 2:
        # Shape: [64, 3] -> [L, N]
        print(x.shape)
        mean = np.mean(x, axis=0)
        std = np.std(x, axis=0)
        avg_corr = np.corrcoef(x.T)

    # Calc All na
    if x.ndim == 3:
        # Shape: (1000, 64, 3) -> [Num of sims, L, N]
        mean = np.mean(x, axis=(0, 1))
        std = np.std(x, axis=(0, 1))

        corrs = []
        for i in range(x.shape[0]):
            c_mat = np.corrcoef(x[i].T)
            corrs.append(c_mat)

        avg_corr = np.mean(corrs,axis=0)
    return mean, std, avg_corr

# %%
gt_mean, gt_std, gt_corr = calc_stats(x_test_sampling_np[:,:,-1])
# Out:
# (64, 14)

# %%
gt_corr
# Out:
# array([[1.        , 0.49994617, 0.76339455, 0.74182204, 0.76441889,
#         0.59307952, 0.75594194, 0.47478648, 0.80554683, 0.47062362,
#         0.5868092 , 0.7716805 , 0.76857981, 0.70285258],
#        [0.49994617, 1.        , 0.29603523, 0.62143085, 0.29743284,
#         0.35110409, 0.30179553, 0.10717069, 0.39015915, 0.21294977,
#         0.40240044, 0.37097953, 0.49317301, 0.24488883],
#        [0.76339455, 0.29603523, 1.        , 0.71016425, 0.88360242,
#         0.69936989, 0.88093408, 0.48298566, 0.70346077, 0.44666081,
#         0.54760454, 0.72716539, 0.72134122, 0.61236923],
#        [0.74182204, 0.62143085, 0.71016425, 1.        , 0.63200046,
#         0.63877197, 0.63468033, 0.32805516, 0.7114327 , 0.42712361,
#         0.58375794, 0.69944516, 0.88780137, 0.55551397],
#        [0.76441889, 0.29743284, 0.88360242, 0.63200046, 1.        ,
#         0.70370861, 0.99844608, 0.53834628, 0.62727151, 0.38440606,
#         0.55949889, 0.74048807, 0.6736865 , 0.51475072],
#        [0.59307952, 0.35110409, 0.69936989, 0.63877197, 0.70370861,
#         1.        , 0.70006094, 0.45927089, 0.60566289, 0.42839272,
#         0.56788232, 0.67340983, 0.64717606, 0.45163926],
#        [0.75594194, 0.30179553, 0.88093408, 0.63468033, 0.99844608,
#         0.70006094, 1.        , 0.52369272, 0.62321407, 0.37275079,
#         0.56310685, 0.73948522, 0.67008654, 0.51259051],
#        [0.47478648, 0.10717069, 0.48298566, 0.32805516, 0.53834628,
#         0.45927089, 0.52369272, 1.        , 0.41274523, 0.15349998,
#         0.33168649, 0.48246753, 0.42445649, 0.29498002],
#        [0.80554683, 0.39015915, 0.70346077, 0.7114327 , 0.62727151,
#         0.60566289, 0.62321407, 0.41274523, 1.        , 0.51427247,
#         0.57396145, 0.68718756, 0.70451034, 0.69504303],
#        [0.47062362, 0.21294977, 0.44666081, 0.42712361, 0.38440606,
#         0.42839272, 0.37275079, 0.15349998, 0.51427247, 1.        ,
#         0.48205135, 0.44932698, 0.43341248, 0.49527219],
#        [0.5868092 , 0.40240044, 0.54760454, 0.58375794, 0.55949889,
#         0.56788232, 0.56310685, 0.33168649, 0.57396145, 0.48205135,
#         1.        , 0.71842244, 0.61804532, 0.41821793],
#        [0.7716805 , 0.37097953, 0.72716539, 0.69944516, 0.74048807,
#         0.67340983, 0.73948522, 0.48246753, 0.68718756, 0.44932698,
#         0.71842244, 1.        , 0.70909394, 0.56961818],
#        [0.76857981, 0.49317301, 0.72134122, 0.88780137, 0.6736865 ,
#         0.64717606, 0.67008654, 0.42445649, 0.70451034, 0.43341248,
#         0.61804532, 0.70909394, 1.        , 0.61276928],
#        [0.70285258, 0.24488883, 0.61236923, 0.55551397, 0.51475072,
#         0.45163926, 0.51259051, 0.29498002, 0.69504303, 0.49527219,
#         0.41821793, 0.56961818, 0.61276928, 1.        ]])

# %%
print("--- Ground Truth Stats ---")
print(f"Mean: {gt_mean}")
print(f"Std:  {gt_std}")
print(f"Corr Matrix:\n{gt_corr}")
print("-" * 30)
# Out:
# --- Ground Truth Stats ---
# Mean: [-0.00321257 -0.02668866 -0.00066025  0.01917933 -0.00257902 -0.01030797
#  -0.00224085  0.00129004  0.01311105  0.01245    -0.00193173  0.00880866
#   0.00853048  0.00498141]
# Std:  [0.0785631  0.14800541 0.07917162 0.11965352 0.08599364 0.09739576
#  0.0877514  0.15336393 0.0709594  0.05133785 0.09695854 0.08073133
#  0.10755908 0.04774885]
# Corr Matrix:
# [[1.         0.49994617 0.76339455 0.74182204 0.76441889 0.59307952
#   0.75594194 0.47478648 0.80554683 0.47062362 0.5868092  0.7716805
#   0.76857981 0.70285258]
#  [0.49994617 1.         0.29603523 0.62143085 0.29743284 0.35110409
#   0.30179553 0.10717069 0.39015915 0.21294977 0.40240044 0.37097953
#   0.49317301 0.24488883]
#  [0.76339455 0.29603523 1.         0.71016425 0.88360242 0.69936989
#   0.88093408 0.48298566 0.70346077 0.44666081 0.54760454 0.72716539
#   0.72134122 0.61236923]
#  [0.74182204 0.62143085 0.71016425 1.         0.63200046 0.63877197
#   0.63468033 0.32805516 0.7114327  0.42712361 0.58375794 0.69944516
#   0.88780137 0.55551397]
#  [0.76441889 0.29743284 0.88360242 0.63200046 1.         0.70370861
#   0.99844608 0.53834628 0.62727151 0.38440606 0.55949889 0.74048807
#   0.6736865  0.51475072]
#  [0.59307952 0.35110409 0.69936989 0.63877197 0.70370861 1.
#   0.70006094 0.45927089 0.60566289 0.42839272 0.56788232 0.67340983
#   0.64717606 0.45163926]
#  [0.75594194 0.30179553 0.88093408 0.63468033 0.99844608 0.70006094
#   1.         0.52369272 0.62321407 0.37275079 0.56310685 0.73948522
#   0.67008654 0.51259051]
#  [0.47478648 0.10717069 0.48298566 0.32805516 0.53834628 0.45927089
#   0.52369272 1.         0.41274523 0.15349998 0.33168649 0.48246753
#   0.42445649 0.29498002]
#  [0.80554683 0.39015915 0.70346077 0.7114327  0.62727151 0.60566289
#   0.62321407 0.41274523 1.         0.51427247 0.57396145 0.68718756
#   0.70451034 0.69504303]
#  [0.47062362 0.21294977 0.44666081 0.42712361 0.38440606 0.42839272
#   0.37275079 0.15349998 0.51427247 1.         0.48205135 0.44932698
#   0.43341248 0.49527219]
#  [0.5868092  0.40240044 0.54760454 0.58375794 0.55949889 0.56788232
#   0.56310685 0.33168649 0.57396145 0.48205135 1.         0.71842244
#   0.61804532 0.41821793]
#  [0.7716805  0.37097953 0.72716539 0.69944516 0.74048807 0.67340983
#   0.73948522 0.48246753 0.68718756 0.44932698 0.71842244 1.
#   0.70909394 0.56961818]
#  [0.76857981 0.49317301 0.72134122 0.88780137 0.6736865  0.64717606
#   0.67008654 0.42445649 0.70451034 0.43341248 0.61804532 0.70909394
#   1.         0.61276928]
#  [0.70285258 0.24488883 0.61236923 0.55551397 0.51475072 0.45163926
#   0.51259051 0.29498002 0.69504303 0.49527219 0.41821793 0.56961818
#   0.61276928 1.        ]]
# ------------------------------

# %% [markdown]
# ### MC Stats

# %%
length , num_assets, num_features = x_test_sampling.shape

# Config
SPLIT_IDX = 60
STEPS_SIMS = 4
NUM_SIMS = 5000

# %%
x_test_sampling.shape
# Out:
# torch.Size([64, 14, 1])

# %%
y = x_test_sampling[-4:]
y.shape
# Out:
# torch.Size([4, 14, 1])

# %%
context_data = x_test_sampling[:SPLIT_IDX, :]
context_data.shape
# Out:
# torch.Size([60, 14, 1])

# %%
mc_sims_paths = []
for i in range(num_assets):
    print("---" * 30)
    asset_context = context_data[:, i][:, 0]
    print(f"Shape: {asset_context.shape}")
    mc_pred_returns = gbm_monte_carlo_simulate(
        hist_log_returns=asset_context.cpu().numpy(), 
        steps_to_predict=STEPS_SIMS, 
        num_sims=NUM_SIMS
    )
    print(f"MC Pred Returns Shape: {mc_pred_returns.shape}")
    
    context_expanded = np.tile(asset_context.cpu(), (NUM_SIMS, 1))
    print(f"Context Expanded Shape: {context_expanded.shape}")
    
    full_paths = np.hstack([context_expanded, mc_pred_returns])
    print(f"Full Paths Shape: {full_paths.shape}")
    mc_sims_paths.append(full_paths)
# Out:
# ------------------------------------------------------------------------------------------
# Shape: torch.Size([60])
# MC Pred Returns Shape: (5000, 4)
# Context Expanded Shape: (5000, 60)
# Full Paths Shape: (5000, 64)
# ------------------------------------------------------------------------------------------
# Shape: torch.Size([60])
# MC Pred Returns Shape: (5000, 4)
# Context Expanded Shape: (5000, 60)
# Full Paths Shape: (5000, 64)
# ------------------------------------------------------------------------------------------
# Shape: torch.Size([60])
# MC Pred Returns Shape: (5000, 4)
# Context Expanded Shape: (5000, 60)
# Full Paths Shape: (5000, 64)
# ------------------------------------------------------------------------------------------
# Shape: torch.Size([60])
# MC Pred Returns Shape: (5000, 4)
# Context Expanded Shape: (5000, 60)
# Full Paths Shape: (5000, 64)
# ------------------------------------------------------------------------------------------
# Shape: torch.Size([60])
# MC Pred Returns Shape: (5000, 4)
# Context Expanded Shape: (5000, 60)
# Full Paths Shape: (5000, 64)
# ------------------------------------------------------------------------------------------
# Shape: torch.Size([60])
# MC Pred Returns Shape: (5000, 4)
# Context Expanded Shape: (5000, 60)
# Full Paths Shape: (5000, 64)
# ------------------------------------------------------------------------------------------
# Shape: torch.Size([60])
# MC Pred Returns Shape: (5000, 4)
# Context Expanded Shape: (5000, 60)
# Full Paths Shape: (5000, 64)
# ------------------------------------------------------------------------------------------
# Shape: torch.Size([60])
# MC Pred Returns Shape: (5000, 4)
# Context Expanded Shape: (5000, 60)
# Full Paths Shape: (5000, 64)
# ------------------------------------------------------------------------------------------
# Shape: torch.Size([60])
# MC Pred Returns Shape: (5000, 4)
# Context Expanded Shape: (5000, 60)
# Full Paths Shape: (5000, 64)
# ------------------------------------------------------------------------------------------
# Shape: torch.Size([60])
# MC Pred Returns Shape: (5000, 4)
# Context Expanded Shape: (5000, 60)
# Full Paths Shape: (5000, 64)
# ------------------------------------------------------------------------------------------
# Shape: torch.Size([60])
# MC Pred Returns Shape: (5000, 4)
# Context Expanded Shape: (5000, 60)
# Full Paths Shape: (5000, 64)
# ------------------------------------------------------------------------------------------
# Shape: torch.Size([60])
# MC Pred Returns Shape: (5000, 4)
# Context Expanded Shape: (5000, 60)
# Full Paths Shape: (5000, 64)
# ------------------------------------------------------------------------------------------
# Shape: torch.Size([60])
# MC Pred Returns Shape: (5000, 4)
# Context Expanded Shape: (5000, 60)
# Full Paths Shape: (5000, 64)
# ------------------------------------------------------------------------------------------
# Shape: torch.Size([60])
# MC Pred Returns Shape: (5000, 4)
# Context Expanded Shape: (5000, 60)
# Full Paths Shape: (5000, 64)

# %% [markdown]
# #### Inside detail in the loop

# %%
mc_pred_returns = gbm_monte_carlo_simulate(
    hist_log_returns=asset_context.cpu().numpy(), 
    steps_to_predict=STEPS_SIMS, 
    num_sims=NUM_SIMS
)
mc_pred_returns.shape
# Out:
# (5000, 4)

# %%
context_expanded = np.tile(asset_context.cpu(), (NUM_SIMS, 1))
context_expanded.shape
# Out:
# (5000, 60)

# %%
full_paths = np.hstack([context_expanded, mc_pred_returns])
full_paths.shape
# Out:
# (5000, 64)

# %% [markdown]
# #### MC Stats Calc

# %%
mc_sims_paths[0].shape
# Out:
# (5000, 64)

# %%
mc_sims = np.stack(mc_sims_paths, axis=-1)
mc_sims.shape
# Out:
# (5000, 64, 14)

# %%
type(mc_sims)
# Out:
# numpy.ndarray

# %%
mc_sims_mean, mc_sims_std, mc_sims_corr = calc_stats(mc_sims)

# %%
print("--- MC Stats ---")
print(f"Mean: {mc_sims_mean}")
print(f"Std:  {mc_sims_std}")
print(f"Corr Matrix:\n{mc_sims_corr}")
print("-" * 30)
# Out:
# --- MC Stats ---
# Mean: [-0.00476016 -0.03381146 -0.00107924  0.01719126 -0.00630441 -0.01076179
#  -0.00624299 -0.00014634  0.01471712  0.0144377  -0.00292266  0.00737994
#   0.009466    0.00768426]
# Std:  [0.08055712 0.14711163 0.07966364 0.11837037 0.08543851 0.09863195
#  0.08682862 0.15757076 0.07226105 0.05117415 0.09876889 0.081772
#  0.10842602 0.04703242]
# Corr Matrix:
# [[1.         0.46470865 0.72058358 0.70622595 0.72778257 0.55887132
#   0.72072551 0.44569882 0.76897944 0.45331366 0.54928539 0.72603211
#   0.73184407 0.69679389]
#  [0.46470865 1.         0.2597439  0.5679318  0.27213653 0.33959086
#   0.27191387 0.10268937 0.38020363 0.21452949 0.38030321 0.34205267
#   0.4666529  0.27245782]
#  [0.72058358 0.2597439  1.         0.65693524 0.85069026 0.65291593
#   0.84814142 0.458618   0.66109445 0.40452744 0.50659182 0.67711501
#   0.66965714 0.58480659]
#  [0.70622595 0.5679318  0.65693524 1.         0.61582294 0.60655041
#   0.61696516 0.32077711 0.67594463 0.39782845 0.55629931 0.6610184
#   0.83640672 0.55197985]
#  [0.72778257 0.27213653 0.85069026 0.61582294 1.         0.66295172
#   0.93837117 0.50595633 0.62101906 0.37421305 0.51510345 0.68953095
#   0.66248201 0.5204206 ]
#  [0.55887132 0.33959086 0.65291593 0.60655041 0.66295172 1.
#   0.66107783 0.43315201 0.56936496 0.39467067 0.52788962 0.6259682
#   0.60538969 0.4243209 ]
#  [0.72072551 0.27191387 0.84814142 0.61696516 0.93837117 0.66107783
#   1.         0.49294749 0.61967826 0.36295382 0.51885009 0.68850564
#   0.66107768 0.52013215]
#  [0.44569882 0.10268937 0.458618   0.32077711 0.50595633 0.43315201
#   0.49294749 1.         0.39573502 0.13840428 0.30381372 0.4509828
#   0.41101892 0.27980637]
#  [0.76897944 0.38020363 0.66109445 0.67594463 0.62101906 0.56936496
#   0.61967826 0.39573502 1.         0.47099059 0.5447035  0.65502782
#   0.65496706 0.65723906]
#  [0.45331366 0.21452949 0.40452744 0.39782845 0.37421305 0.39467067
#   0.36295382 0.13840428 0.47099059 1.         0.44731317 0.41762773
#   0.39221658 0.42780065]
#  [0.54928539 0.38030321 0.50659182 0.55629931 0.51510345 0.52788962
#   0.51885009 0.30381372 0.5447035  0.44731317 1.         0.66808462
#   0.58730907 0.39178705]
#  [0.72603211 0.34205267 0.67711501 0.6610184  0.68953095 0.6259682
#   0.68850564 0.4509828  0.65502782 0.41762773 0.66808462 1.
#   0.67181885 0.54879089]
#  [0.73184407 0.4666529  0.66965714 0.83640672 0.66248201 0.60538969
#   0.66107768 0.41101892 0.65496706 0.39221658 0.58730907 0.67181885
#   1.         0.58433485]
#  [0.69679389 0.27245782 0.58480659 0.55197985 0.5204206  0.4243209
#   0.52013215 0.27980637 0.65723906 0.42780065 0.39178705 0.54879089
#   0.58433485 1.        ]]
# ------------------------------

# %% [markdown]
# ## MC (GenAI) Stats

# %%
# x_test_sampling = x_test[0].unsqueeze(0)
x_test_sampling.shape
# Out:
# torch.Size([64, 14, 1])

# %%
length , num_assets, num_features = x_test_sampling.shape

# Config
SPLIT_IDX = 60
STEPS_SIMS = 4
NUM_SIMS = 5000

# %%
mc_genai_y = x_test_sampling[-4:]
mc_genai_y.shape
# Out:
# torch.Size([4, 14, 1])

# %%
mc_genai_context_x = x_test_sampling[:SPLIT_IDX, :]
mc_genai_context_x.shape
# Out:
# torch.Size([60, 14, 1])

# %%
mc_genai_context_x = mc_genai_context_x.unsqueeze(0)
mc_genai_context_x.shape
# Out:
# torch.Size([1, 60, 14, 1])

# %%
# Shape requires [1, 64, 3, 2]
mc_y = monte_carlo_simulate(context_data=mc_genai_context_x, steps_to_simulate=STEPS_SIMS, engine=engine,num_simulations=NUM_SIMS)
mc_y.shape # [Sims, Time, Assets, Features]
# Out:
# INFO:engine.trainer:Simulating... (Masking last 4 steps)
# In-painting: 892it [02:30,  5.85it/s]

# %%
# Shape require for calc stats is (1000, 64, 3)
mc_genai_y = mc_y[:,:,:,0]
mc_genai_y.shape

# %%
mc_genai_mean, mc_genai_std, mc_genai_corr = calc_stats(mc_genai_y)
print("--- MC GenAI Stats ---")
print(f"Mean: {mc_genai_mean}")
print(f"Std:  {mc_genai_std}")
print(f"Corr Matrix:\n{mc_genai_corr}")
print("-" * 30)

# %%
mc_genai_corr, mc_sims_corr, gt_corr
