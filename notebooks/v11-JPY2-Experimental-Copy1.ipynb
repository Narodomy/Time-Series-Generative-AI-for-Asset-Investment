# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import datetime as dt
import logging
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import seaborn as sns
import talib as ta
from torch import optim
from torch.utils.data import DataLoader, Dataset, TensorDataset, random_split
from tqdm import tqdm
from numpy.lib.stride_tricks import sliding_window_view
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from torch.optim import AdamW
from utils import scale, inverse_scale, inverse_scale_pair, inspect
from utils.paths import CHECKPOINTS_DIR, REPORTS_SIM_DIR
from pypfopt import risk_models, expected_returns, plotting, EfficientFrontier
import warnings

# Own Libs
from config import *
from entities import *
from strategies import *
from datasets import *
from engine import Engine
from models import DiffusionTransformer, Diffusion

# %% [markdown]
# # Setup

# %%
logging.basicConfig(level=logging.DEBUG)
logging.getLogger('matplotlib').setLevel(logging.WARNING)

logging.getLogger('matplotlib.font_manager').setLevel(logging.ERROR)
warnings.filterwarnings("ignore", category=UserWarning, message="findfont: Font family")

# %%
cfg = TrainConfig(epochs=2, window_size=64, steps_to_sim=16, num_sims=1000)
window_size = cfg.window_size
device = cfg.device
batch_size = cfg.batch_size
epochs = cfg.epochs
sim_steps = cfg.steps_to_sim
num_sims = cfg.num_sims

# Optimizer
weight_decay = cfg.optimizer.weight_decay
lr = cfg.optimizer.lr

time_range = {
    'start_date': '2021-01-01',
    'end_date': '2024-12-31'
}

ddpm = {
    'timesteps': int(1000),
    'beta_start': 0.0001,
    'beta_end': 0.02
}

ddpm_transformer = {
    'window_size': window_size,
    'd_model': 64,
    'nhead': 4,
    'num_layers': 64,
    'dim_feedforward': 512,
    'dropout': 0.1
}

# %% [markdown]
# # Data [N, W, A, F]
# **[N, T, A, F]** means:
# * **N**: Num of Window or Num of Batch
# * **W**: Window
# * **A**: Assets
# * **F**: Features or Channels

# %%
def time_range_info(df):
    info = (df.index.min(), df.index.max())
    print(f"Data range: {info[0]} to {info[1]}")
    
    duration = df.index.max() - df.index.min()
    print(f"Total duration: {duration}")

def time_range_mask(df, start_date, end_date):
    mask = (df.index >= start_date) & (df.index <= end_date)
    return mask

# %%
symbols = ['AAPL', 'TSLA', 'MSFT', 'NVDA', 'GOOGL', 'AMZN', 'GOOG', 'META', 'AVGO', 'ORCL', 'CRM', 'ADBE', 'AMD', 'CSCO']
freq = "1d"

# Basket
basket = Basket(symbols=symbols)
basket.load_all_assets(freq=freq)

print(f"Basket data shape: {basket.data.shape}")
basket.data.head(5)
# Out:
# DEBUG:entities.basket:Initialized Asset Basket: ['AAPL', 'TSLA', 'MSFT', 'NVDA', 'GOOGL', 'AMZN', 'GOOG', 'META', 'AVGO', 'ORCL', 'CRM', 'ADBE', 'AMD', 'CSCO'] with 0 assets which loaded.
# INFO:entities.basket:Starting batch load for 14 symbols...
# DEBUG:entities.basket:Attempting to load AAPL...
# DEBUG:entities.asset:Initialized Asset: AAPL with 2724 rows.
# INFO:entities.basket:Successfully loaded AAPL (2724 rows).
# DEBUG:entities.basket:Attempting to load TSLA...
# DEBUG:entities.asset:Initialized Asset: TSLA with 2760 rows.
# INFO:entities.basket:Successfully loaded TSLA (2760 rows).
# DEBUG:entities.basket:Attempting to load MSFT...
# DEBUG:entities.asset:Initialized Asset: MSFT with 2724 rows.
# INFO:entities.basket:Successfully loaded MSFT (2724 rows).
# DEBUG:entities.basket:Attempting to load NVDA...
# DEBUG:entities.asset:Initialized Asset: NVDA with 2724 rows.
# INFO:entities.basket:Successfully loaded NVDA (2724 rows).
# DEBUG:entities.basket:Attempting to load GOOGL...
# DEBUG:entities.asset:Initialized Asset: GOOGL with 2760 rows.
# INFO:entities.basket:Successfully loaded GOOGL (2760 rows).
# DEBUG:entities.basket:Attempting to load AMZN...
# DEBUG:entities.asset:Initialized Asset: AMZN with 2760 rows.
# INFO:entities.basket:Successfully loaded AMZN (2760 rows).
# DEBUG:entities.basket:Attempting to load GOOG...
# DEBUG:entities.asset:Initialized Asset: GOOG with 1464 rows.
# INFO:entities.basket:Successfully loaded GOOG (1464 rows).
# DEBUG:entities.basket:Attempting to load META...
# DEBUG:entities.asset:Initialized Asset: META with 2760 rows.
# INFO:entities.basket:Successfully loaded META (2760 rows).
# DEBUG:entities.basket:Attempting to load AVGO...
# DEBUG:entities.asset:Initialized Asset: AVGO with 2724 rows.
# INFO:entities.basket:Successfully loaded AVGO (2724 rows).
# DEBUG:entities.basket:Attempting to load ORCL...
# DEBUG:entities.asset:Initialized Asset: ORCL with 2724 rows.
# INFO:entities.basket:Successfully loaded ORCL (2724 rows).
# DEBUG:entities.basket:Attempting to load CRM...
# DEBUG:entities.asset:Initialized Asset: CRM with 2724 rows.
# INFO:entities.basket:Successfully loaded CRM (2724 rows).
# DEBUG:entities.basket:Attempting to load ADBE...
# DEBUG:entities.asset:Initialized Asset: ADBE with 2724 rows.
# INFO:entities.basket:Successfully loaded ADBE (2724 rows).
# DEBUG:entities.basket:Attempting to load AMD...
# DEBUG:entities.asset:Initialized Asset: AMD with 2724 rows.
# INFO:entities.basket:Successfully loaded AMD (2724 rows).
# DEBUG:entities.basket:Attempting to load CSCO...
# DEBUG:entities.asset:Initialized Asset: CSCO with 2724 rows.
# INFO:entities.basket:Successfully loaded CSCO (2724 rows).
# INFO:entities.basket:Batch load complete. Success: 14/14. Total assets in basket: 14
# Basket data shape: (2760, 70)
#                  AAPL                                                \
#                 Close       High        Low       Open       Volume
# Date
# 2015-01-02  24.261047  24.729270  23.821672  24.718174  212818400.0
# 2015-01-05  23.577574  24.110150  23.391173  24.030263  257142000.0
# 2015-01-06  23.579794  23.839424  23.218085  23.641928  263188400.0
# 2015-01-07  23.910433  24.010290  23.677430  23.788384  160423600.0
# 2015-01-08  24.829119  24.886815  24.121236  24.238848  237458000.0
#
#                  TSLA                                             ...   AMD  \
#                 Close       High        Low       Open    Volume  ... Close
# Date                                                              ...
# 2015-01-02  14.620667  14.883333  14.217333  14.858000  71466000  ...  2.67
# 2015-01-05  14.006000  14.433333  13.810667  14.303333  80527500  ...  2.66
# 2015-01-06  14.085333  14.280000  13.614000  14.004000  93928500  ...  2.63
# 2015-01-07  14.063333  14.318667  13.985333  14.223333  44526000  ...  2.58
# 2015-01-08  14.041333  14.253333  14.000667  14.187333  51637500  ...  2.61
#
#                                                CSCO                        \
#             High   Low  Open      Volume      Close       High        Low
# Date
# 2015-01-02  2.67  2.67  2.67         0.0  19.815605  20.181631  19.650534
# 2015-01-05  2.70  2.64  2.67   8878200.0  19.420874  19.700776  19.377812
# 2015-01-06  2.66  2.55  2.65  13912500.0  19.413698  19.865848  19.406522
# 2015-01-07  2.65  2.54  2.63  12377600.0  19.593126  19.664896  19.363463
# 2015-01-08  2.65  2.56  2.59  11136600.0  19.743843  20.160107  19.715135
#
#
#                  Open      Volume
# Date
# 2015-01-02  19.995029  22926500.0
# 2015-01-05  19.607475  29460600.0
# 2015-01-06  19.478291  47297600.0
# 2015-01-07  19.478295  27570800.0
# 2015-01-08  19.765374  40907000.0
#
# [5 rows x 70 columns]

# %% [markdown]
# ## Time Range Custom

# %%
time_range_info(basket.data)

for symbol, asset in basket.assets.items():
    mask = time_range_mask(asset.data, time_range['start_date'], time_range['end_date'])
    asset.data = asset.data[mask]

time_range_info(basket.data)
# Out:
# Data range: 2015-01-02 00:00:00 to 2025-12-22 00:00:00
# Total duration: 4007 days 00:00:00
# Data range: 2021-01-04 00:00:00 to 2024-12-31 00:00:00
# Total duration: 1457 days 00:00:00

# %% [markdown]
# ## Features/Channels ($F$)
# 1. Find Joint Distribution $F_{\text{date\ A}} \cap F_{\text{date\ B}}$ with intersection
# 2. Select $F$ to norm as Return values

# %%
targets = ["Close"]
features = basket.get_unique_features()
print(f"Features:\t{features}\nTargets:\t{targets}")
# Out:
# Features:	['Close', 'High', 'Low', 'Open', 'Volume']
# Targets:	['Close']

# %%
print(f"Basket data shape before Joint: {basket.data.shape}")

joint_strategy = IntersectionStrategy()
basket.align(joint_strategy)

print(f"Basket data shape after Joint: {basket.data.shape}")
# Out:
# INFO:strategies.concrete:Aligned: 14 orig -> 14 clean assets -> 1005 rows
# DEBUG:entities.basket:Aligned data shape: (1005, 70)
# INFO:entities.basket:Assets updated in-place to aligned index (Length: 1005)
# Basket data shape before Joint: (1005, 70)
# Basket data shape after Joint: (1005, 70)

# %%
basket.to_returns(features=targets, log=True, keep=False)
targets = basket.get_keyword_features("Returns")
features = basket.get_unique_features()

print(f"Features:\t{features}\nTargets:\t{targets}")
basket.data.head(5)
# Out:
# DEBUG:entities.asset:AAPL converted to Returns (log=True)
# DEBUG:entities.asset:TSLA converted to Returns (log=True)
# DEBUG:entities.asset:MSFT converted to Returns (log=True)
# DEBUG:entities.asset:NVDA converted to Returns (log=True)
# DEBUG:entities.asset:GOOGL converted to Returns (log=True)
# DEBUG:entities.asset:AMZN converted to Returns (log=True)
# DEBUG:entities.asset:GOOG converted to Returns (log=True)
# DEBUG:entities.asset:META converted to Returns (log=True)
# DEBUG:entities.asset:AVGO converted to Returns (log=True)
# DEBUG:entities.asset:ORCL converted to Returns (log=True)
# DEBUG:entities.asset:CRM converted to Returns (log=True)
# DEBUG:entities.asset:ADBE converted to Returns (log=True)
# DEBUG:entities.asset:AMD converted to Returns (log=True)
# DEBUG:entities.asset:CSCO converted to Returns (log=True)
# Features:	['Close_Log_Returns', 'High', 'Low', 'Open', 'Volume']
# Targets:	{'Close_Log_Returns'}
#                   AAPL                                                       \
#                   High         Low        Open     Volume Close_Log_Returns
# Date
# 2021-01-05  128.366929  125.141666  125.589894   97664900          0.012288
# 2021-01-06  127.694587  123.144152  124.449847  155088000         -0.034241
# 2021-01-07  128.259768  124.586290  125.073488  109578200          0.033554
# 2021-01-08  129.234127  126.895568  129.039236  105158200          0.008594
# 2021-01-11  126.837115  125.209876  125.882211  100384500         -0.023523
#
#                   TSLA                                                       \
#                   High         Low        Open     Volume Close_Log_Returns
# Date
# 2021-01-05  246.946671  239.733337  241.220001   96735600          0.007291
# 2021-01-06  258.000000  249.699997  252.830002  134100000          0.027995
# 2021-01-07  272.329987  258.399994  259.209991  154496700          0.076448
# 2021-01-08  294.829987  279.463318  285.333344  225166500          0.075481
# 2021-01-11  284.809998  267.873322  283.133331  177904800         -0.081442
#
#             ...        AMD                                                    \
#             ...       High        Low       Open    Volume Close_Log_Returns
# Date        ...
# 2021-01-05  ...  93.209999  91.410004  92.099998  34208000          0.005079
# 2021-01-06  ...  92.279999  89.459999  91.620003  51911700         -0.026654
# 2021-01-07  ...  95.510002  91.199997  91.330002  42897200          0.052090
# 2021-01-08  ...  96.400002  93.269997  95.980003  39816400         -0.006114
# 2021-01-11  ...  99.230003  93.760002  94.029999  48600200          0.027839
#
#                  CSCO
#                  High        Low       Open    Volume Close_Log_Returns
# Date
# 2021-01-05  38.335017  37.734811  37.995770  17763700          0.000455
# 2021-01-06  39.030909  38.178440  38.387210  21823100          0.009505
# 2021-01-07  39.239677  38.422000  38.448099  18218800          0.012534
# 2021-01-08  39.500638  38.491593  38.691662  20936300          0.002222
# 2021-01-11  39.970367  39.161391  39.274475  25058200          0.006636
#
# [5 rows x 70 columns]

# %% [markdown]
# ## Add Indicators as Features ($F$)

# %%
# Indicator
time_prd = 20
fast_prd, slow_prd, signal_prd = 12, 26, 9

for symbol, asset in basket.assets.items():
    df = asset.data 
    
    for target in targets:
        s = df[target]
        
        df[f"SMA_{time_prd} {target}"] = ta.SMA(s, timeperiod=time_prd)
        df[f"EMA_{time_prd} {target}"] = ta.EMA(s, timeperiod=time_prd)
        df[f"RSI_{time_prd} {target}"] = ta.RSI(s, timeperiod=time_prd)
        
        macd, signal, hist = ta.MACD(s, fastperiod=fast_prd, slowperiod=slow_prd, signalperiod=signal_prd)
        df[f"MACD {target}"] = macd
        df[f"MACD_Sig {target}"] = signal
        df[f"MACD_Hist {target}"] = hist

print(f"Basket data shape: {basket.data.shape}")
basket.data.head(5)
# Out:
# Basket data shape: (1004, 154)
#                   AAPL                                                       \
#                   High         Low        Open     Volume Close_Log_Returns
# Date
# 2021-01-05  128.366929  125.141666  125.589894   97664900          0.012288
# 2021-01-06  127.694587  123.144152  124.449847  155088000         -0.034241
# 2021-01-07  128.259768  124.586290  125.073488  109578200          0.033554
# 2021-01-08  129.234127  126.895568  129.039236  105158200          0.008594
# 2021-01-11  126.837115  125.209876  125.882211  100384500         -0.023523
#
#                                                               \
#            SMA_20 Close_Log_Returns EMA_20 Close_Log_Returns
# Date
# 2021-01-05                      NaN                      NaN
# 2021-01-06                      NaN                      NaN
# 2021-01-07                      NaN                      NaN
# 2021-01-08                      NaN                      NaN
# 2021-01-11                      NaN                      NaN
#
#                                                             \
#            RSI_20 Close_Log_Returns MACD Close_Log_Returns
# Date
# 2021-01-05                      NaN                    NaN
# 2021-01-06                      NaN                    NaN
# 2021-01-07                      NaN                    NaN
# 2021-01-08                      NaN                    NaN
# 2021-01-11                      NaN                    NaN
#
#                                        ...       CSCO                       \
#            MACD_Sig Close_Log_Returns  ...        Low       Open    Volume
# Date                                   ...
# 2021-01-05                        NaN  ...  37.734811  37.995770  17763700
# 2021-01-06                        NaN  ...  38.178440  38.387210  21823100
# 2021-01-07                        NaN  ...  38.422000  38.448099  18218800
# 2021-01-08                        NaN  ...  38.491593  38.691662  20936300
# 2021-01-11                        NaN  ...  39.161391  39.274475  25058200
#
#                                                        \
#            Close_Log_Returns SMA_20 Close_Log_Returns
# Date
# 2021-01-05          0.000455                      NaN
# 2021-01-06          0.009505                      NaN
# 2021-01-07          0.012534                      NaN
# 2021-01-08          0.002222                      NaN
# 2021-01-11          0.006636                      NaN
#
#                                                               \
#            EMA_20 Close_Log_Returns RSI_20 Close_Log_Returns
# Date
# 2021-01-05                      NaN                      NaN
# 2021-01-06                      NaN                      NaN
# 2021-01-07                      NaN                      NaN
# 2021-01-08                      NaN                      NaN
# 2021-01-11                      NaN                      NaN
#
#                                                               \
#            MACD Close_Log_Returns MACD_Sig Close_Log_Returns
# Date
# 2021-01-05                    NaN                        NaN
# 2021-01-06                    NaN                        NaN
# 2021-01-07                    NaN                        NaN
# 2021-01-08                    NaN                        NaN
# 2021-01-11                    NaN                        NaN
#
#
#            MACD_Hist Close_Log_Returns
# Date
# 2021-01-05                         NaN
# 2021-01-06                         NaN
# 2021-01-07                         NaN
# 2021-01-08                         NaN
# 2021-01-11                         NaN
#
# [5 rows x 154 columns]

# %% [markdown]
# ## Additional! Shift data for future simulation (forward)

# %%
for symbol, asset in basket.assets.items():
    df = asset.data 
    
    for target in targets:
        df[f"SMA_{time_prd} {target}"] = df[f"SMA_{time_prd} {target}"].shift(1)
        df[f"EMA_{time_prd} {target}"] = df[f"EMA_{time_prd} {target}"].shift(1)
        df[f"RSI_{time_prd} {target}"] = df[f"RSI_{time_prd} {target}"].shift(1)
        df[f"MACD {target}"] = df[f"MACD {target}"].shift(1)
        df[f"MACD_Sig {target}"] = df[f"MACD_Sig {target}"].shift(1)
        df[f"MACD_Hist {target}"] = df[f"MACD_Hist {target}"].shift(1)

    asset.data = df.dropna() 
    
print(f"Basket data shape: {basket.data.shape}")
basket.data.head(5)
# Out:
# Basket data shape: (970, 154)
#                   AAPL                                                       \
#                   High         Low        Open     Volume Close_Log_Returns
# Date
# 2021-02-24  122.527972  119.278390  121.922948  111039900         -0.004060
# 2021-02-25  123.406232  117.629191  121.669217  148199500         -0.035402
# 2021-02-26  121.835107  118.273246  119.629680  164560400          0.002229
# 2021-03-01  124.840766  119.824887  120.761704  116307900          0.052452
# 2021-03-02  125.611668  121.991258  125.309156  102260900         -0.021115
#
#                                                               \
#            SMA_20 Close_Log_Returns EMA_20 Close_Log_Returns
# Date
# 2021-02-24                -0.006281                -0.004764
# 2021-02-25                -0.006568                -0.004697
# 2021-02-26                -0.007952                -0.007621
# 2021-03-01                -0.006060                -0.006683
# 2021-03-02                -0.001531                -0.001051
#
#                                                             \
#            RSI_20 Close_Log_Returns MACD Close_Log_Returns
# Date
# 2021-02-24                49.443327              -0.005006
# 2021-02-25                49.042061              -0.004288
# 2021-02-26                44.959599              -0.006177
# 2021-03-01                50.199121              -0.004584
# 2021-03-02                56.073523               0.000722
#
#                                        ...       CSCO                       \
#            MACD_Sig Close_Log_Returns  ...        Low       Open    Volume
# Date                                   ...
# 2021-02-24                  -0.005451  ...  39.178786  39.352760  17823600
# 2021-02-25                  -0.005218  ...  39.352752  39.657204  21916700
# 2021-02-26                  -0.005410  ...  38.935217  39.648511  22144900
# 2021-03-01                  -0.005245  ...  39.335356  39.335356  17394100
# 2021-03-02                  -0.004051  ...  39.509325  39.952959  14833000
#
#                                                        \
#            Close_Log_Returns SMA_20 Close_Log_Returns
# Date
# 2021-02-24          0.005041                 0.000530
# 2021-02-25         -0.004822                 0.000527
# 2021-02-26         -0.014382                -0.000197
# 2021-03-01          0.023131                -0.000521
# 2021-03-02         -0.008749                 0.001481
#
#                                                               \
#            EMA_20 Close_Log_Returns RSI_20 Close_Log_Returns
# Date
# 2021-02-24                -0.001497                50.527952
# 2021-02-25                -0.000874                51.224838
# 2021-02-26                -0.001250                49.039717
# 2021-03-01                -0.002501                46.994221
# 2021-03-02                -0.000060                54.783902
#
#                                                               \
#            MACD Close_Log_Returns MACD_Sig Close_Log_Returns
# Date
# 2021-02-24              -0.001681                  -0.000759
# 2021-02-25              -0.000967                  -0.000801
# 2021-02-26              -0.001184                  -0.000877
# 2021-03-01              -0.002102                  -0.001122
# 2021-03-02               0.000194                  -0.000859
#
#
#            MACD_Hist Close_Log_Returns
# Date
# 2021-02-24                   -0.000923
# 2021-02-25                   -0.000167
# 2021-02-26                   -0.000307
# 2021-03-01                   -0.000980
# 2021-03-02                    0.001053
#
# [5 rows x 154 columns]

# %%
basket.align(joint_strategy)

print(f"Basket data shape: {basket.data.shape}")
basket.data.head(5)
# Out:
# INFO:strategies.concrete:Aligned: 14 orig -> 14 clean assets -> 970 rows
# DEBUG:entities.basket:Aligned data shape: (970, 154)
# INFO:entities.basket:Assets updated in-place to aligned index (Length: 970)
# Basket data shape: (970, 154)
#                   AAPL                                                       \
#                   High         Low        Open     Volume Close_Log_Returns
# Date
# 2021-02-24  122.527972  119.278390  121.922948  111039900         -0.004060
# 2021-02-25  123.406232  117.629191  121.669217  148199500         -0.035402
# 2021-02-26  121.835107  118.273246  119.629680  164560400          0.002229
# 2021-03-01  124.840766  119.824887  120.761704  116307900          0.052452
# 2021-03-02  125.611668  121.991258  125.309156  102260900         -0.021115
#
#                                                               \
#            SMA_20 Close_Log_Returns EMA_20 Close_Log_Returns
# Date
# 2021-02-24                -0.006281                -0.004764
# 2021-02-25                -0.006568                -0.004697
# 2021-02-26                -0.007952                -0.007621
# 2021-03-01                -0.006060                -0.006683
# 2021-03-02                -0.001531                -0.001051
#
#                                                             \
#            RSI_20 Close_Log_Returns MACD Close_Log_Returns
# Date
# 2021-02-24                49.443327              -0.005006
# 2021-02-25                49.042061              -0.004288
# 2021-02-26                44.959599              -0.006177
# 2021-03-01                50.199121              -0.004584
# 2021-03-02                56.073523               0.000722
#
#                                        ...       CSCO                       \
#            MACD_Sig Close_Log_Returns  ...        Low       Open    Volume
# Date                                   ...
# 2021-02-24                  -0.005451  ...  39.178786  39.352760  17823600
# 2021-02-25                  -0.005218  ...  39.352752  39.657204  21916700
# 2021-02-26                  -0.005410  ...  38.935217  39.648511  22144900
# 2021-03-01                  -0.005245  ...  39.335356  39.335356  17394100
# 2021-03-02                  -0.004051  ...  39.509325  39.952959  14833000
#
#                                                        \
#            Close_Log_Returns SMA_20 Close_Log_Returns
# Date
# 2021-02-24          0.005041                 0.000530
# 2021-02-25         -0.004822                 0.000527
# 2021-02-26         -0.014382                -0.000197
# 2021-03-01          0.023131                -0.000521
# 2021-03-02         -0.008749                 0.001481
#
#                                                               \
#            EMA_20 Close_Log_Returns RSI_20 Close_Log_Returns
# Date
# 2021-02-24                -0.001497                50.527952
# 2021-02-25                -0.000874                51.224838
# 2021-02-26                -0.001250                49.039717
# 2021-03-01                -0.002501                46.994221
# 2021-03-02                -0.000060                54.783902
#
#                                                               \
#            MACD Close_Log_Returns MACD_Sig Close_Log_Returns
# Date
# 2021-02-24              -0.001681                  -0.000759
# 2021-02-25              -0.000967                  -0.000801
# 2021-02-26              -0.001184                  -0.000877
# 2021-03-01              -0.002102                  -0.001122
# 2021-03-02               0.000194                  -0.000859
#
#
#            MACD_Hist Close_Log_Returns
# Date
# 2021-02-24                   -0.000923
# 2021-02-25                   -0.000167
# 2021-02-26                   -0.000307
# 2021-03-01                   -0.000980
# 2021-03-02                    0.001053
#
# [5 rows x 154 columns]

# %% [markdown]
# ## Filter only Target Features ($F_{target} $)

# %%
targets = basket.get_keyword_features("Returns")
print(f"Targets: {targets}")


for symbol, asset in basket.assets.items():
    mask = asset.data.columns.isin(targets)
    asset.data = asset.data.loc[:, mask]

print(f"Basket shape: {basket.data.shape}")
basket.data.head(5)
# Out:
# Targets: {'MACD_Sig Close_Log_Returns', 'SMA_20 Close_Log_Returns', 'EMA_20 Close_Log_Returns', 'MACD_Hist Close_Log_Returns', 'RSI_20 Close_Log_Returns', 'MACD Close_Log_Returns', 'Close_Log_Returns'}
# Basket shape: (970, 98)
#                         AAPL                           \
#            Close_Log_Returns SMA_20 Close_Log_Returns
# Date
# 2021-02-24         -0.004060                -0.006281
# 2021-02-25         -0.035402                -0.006568
# 2021-02-26          0.002229                -0.007952
# 2021-03-01          0.052452                -0.006060
# 2021-03-02         -0.021115                -0.001531
#
#                                                               \
#            EMA_20 Close_Log_Returns RSI_20 Close_Log_Returns
# Date
# 2021-02-24                -0.004764                49.443327
# 2021-02-25                -0.004697                49.042061
# 2021-02-26                -0.007621                44.959599
# 2021-03-01                -0.006683                50.199121
# 2021-03-02                -0.001051                56.073523
#
#                                                               \
#            MACD Close_Log_Returns MACD_Sig Close_Log_Returns
# Date
# 2021-02-24              -0.005006                  -0.005451
# 2021-02-25              -0.004288                  -0.005218
# 2021-02-26              -0.006177                  -0.005410
# 2021-03-01              -0.004584                  -0.005245
# 2021-03-02               0.000722                  -0.004051
#
#                                                     TSLA  \
#            MACD_Hist Close_Log_Returns Close_Log_Returns
# Date
# 2021-02-24                    0.000445          0.059954
# 2021-02-25                    0.000930         -0.084024
# 2021-02-26                   -0.000767         -0.009899
# 2021-03-01                    0.000661          0.061615
# 2021-03-02                    0.004773         -0.045549
#
#                                                               ...  \
#            SMA_20 Close_Log_Returns EMA_20 Close_Log_Returns  ...
# Date                                                          ...
# 2021-02-24                -0.011570                -0.012856  ...
# 2021-02-25                -0.008703                -0.005921  ...
# 2021-02-26                -0.011820                -0.013360  ...
# 2021-03-01                -0.010625                -0.013030  ...
# 2021-03-02                -0.004971                -0.005921  ...
#
#                               AMD                             \
#            MACD Close_Log_Returns MACD_Sig Close_Log_Returns
# Date
# 2021-02-24              -0.004678                  -0.002595
# 2021-02-25              -0.001476                  -0.002371
# 2021-02-26              -0.005253                  -0.002947
# 2021-03-01              -0.001896                  -0.002737
# 2021-03-02               0.000513                  -0.002087
#
#                                                     CSCO  \
#            MACD_Hist Close_Log_Returns Close_Log_Returns
# Date
# 2021-02-24                   -0.002084          0.005041
# 2021-02-25                    0.000895         -0.004822
# 2021-02-26                   -0.002306         -0.014382
# 2021-03-01                    0.000841          0.023131
# 2021-03-02                    0.002600         -0.008749
#
#                                                               \
#            SMA_20 Close_Log_Returns EMA_20 Close_Log_Returns
# Date
# 2021-02-24                 0.000530                -0.001497
# 2021-02-25                 0.000527                -0.000874
# 2021-02-26                -0.000197                -0.001250
# 2021-03-01                -0.000521                -0.002501
# 2021-03-02                 0.001481                -0.000060
#
#                                                             \
#            RSI_20 Close_Log_Returns MACD Close_Log_Returns
# Date
# 2021-02-24                50.527952              -0.001681
# 2021-02-25                51.224838              -0.000967
# 2021-02-26                49.039717              -0.001184
# 2021-03-01                46.994221              -0.002102
# 2021-03-02                54.783902               0.000194
#
#
#            MACD_Sig Close_Log_Returns MACD_Hist Close_Log_Returns
# Date
# 2021-02-24                  -0.000759                   -0.000923
# 2021-02-25                  -0.000801                   -0.000167
# 2021-02-26                  -0.000877                   -0.000307
# 2021-03-01                  -0.001122                   -0.000980
# 2021-03-02                  -0.000859                    0.001053
#
# [5 rows x 98 columns]

# %% [markdown]
# # Dataset & Dataloader

# %%
n_obs = len(basket.data)
n_assets = basket.data.columns.levels[0].size
n_features = basket.data.columns.levels[1].size

print(n_obs, n_assets, n_features)

basket_np = basket.data.values.reshape(n_obs, n_assets, n_features)
basket_np.shape
# Out:
# 970 14 7
# (970, 14, 7)

# %% [markdown]
# ## Ratio Dataset

# %%
ratios = [0.8, 0.1, 0.1]
total_count = len(basket_np)
train_count = int(total_count * ratios[0])
val_count = int(total_count * ratios[1])
test_count = total_count - train_count - val_count

print(f"Ratios DS\nTrain:\t{train_count}\nVal:\t{val_count}\nTest:\t{test_count}\nTotal:\t{total_count}")
# Out:
# Ratios DS
# Train:	776
# Val:	97
# Test:	97
# Total:	970

# %%
all_dates = basket.data.index.get_level_values(0).unique().to_numpy()
print(f"Dates shape: {all_dates.shape}")
# Out:
# Dates shape: (970,)

# %%
end_val = train_count + val_count

# Ratios
train_part = basket_np[:train_count]
val_part = basket_np[train_count:end_val]
test_part = basket_np[end_val:]

train_dates = all_dates[:train_count]
val_dates   = all_dates[train_count:end_val]
test_dates  = all_dates[end_val:]

print(f"Train: {train_part.shape}\nVal: {val_part.shape}\nTest:{test_part.shape}")
print(f"Train Dates: {train_dates.shape}\nVal Dates: {val_dates.shape}\nTest Dates:{test_dates.shape}")
# Out:
# Train: (776, 14, 7)
# Val: (97, 14, 7)
# Test:(97, 14, 7)
# Train Dates: (776,)
# Val Dates: (97,)
# Test Dates:(97,)

# %% [markdown]
# ## Scale Dataset

# %%
# scaler = MinMaxScaler(feature_range=(-1, 1))
scaler = StandardScaler()

# Require 2D Numpy Array
T, A, F = train_part.shape
scaler.fit(train_part.reshape(-1, F))

scaled_train_part = scale(train_part, scaler)
scaled_val_part = scale(val_part, scaler)
scaled_test_part = scale(test_part, scaler)

inspect(scaled_train_part, "Scaled Train Part")
inspect(scaled_val_part, "Scaled Val Part")
inspect(scaled_test_part, "Scaled Test Part")
print(f"Train:\t{scaled_train_part.shape}\nVal:\t{scaled_val_part.shape}\nTest:\t{scaled_test_part.shape}")
# Out:
# --- Inspecting: Scaled Train Part ---
# ------------------------------------
# Shape: (776, 14, 7)
# Min:   -12.4922
# Max:   8.8458
# Mean:  0.0000
# Std:   1.0000
# ------------------------------------
# --- Inspecting: Scaled Val Part ---
# ------------------------------------
# Shape: (97, 14, 7)
# Min:   -8.9719
# Max:   6.1577
# Mean:  -0.0437
# Std:   0.9942
# ------------------------------------
# --- Inspecting: Scaled Test Part ---
# ------------------------------------
# Shape: (97, 14, 7)
# Min:   -6.1881
# Max:   8.8664
# Mean:  0.1223
# Std:   0.9497
# ------------------------------------
# Train:	(776, 14, 7)
# Val:	(97, 14, 7)
# Test:	(97, 14, 7)

# %% [markdown]
# ## Dataloader

# %%
train_ds = MarketDataset(data=scaled_train_part, dates=train_dates, window_size=window_size)
val_ds = MarketDataset(data=scaled_val_part, dates=val_dates, window_size=window_size)
test_ds = MarketDataset(data=scaled_test_part, dates=test_dates, window_size=window_size)

print(f"Num of Windows\nTrain DS: {len(train_ds)}, Val Ds: {len(val_ds)}, Test DS: {len(test_ds)}\n")
print(f"A sample shape from Train DS\n\tx: {train_ds[0]['x'].shape},\n\tx_cond: {train_ds[0]['x_cond'].shape}")
# Out:
# Num of Windows
# Train DS: 713, Val Ds: 34, Test DS: 34
#
# A sample shape from Train DS
# 	x: (64, 14, 1),
# 	x_cond: (64, 14, 6)

# %%
train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_ds, batch_size=1, shuffle=False)

batch = next(iter(train_loader))
print(len(train_loader))
print(batch["x"].shape)
print(batch["x_cond"].shape)
# Out:
# 60
# torch.Size([12, 64, 14, 1])
# torch.Size([12, 64, 14, 6])

# %% [markdown]
# # Model, Engine
# Use *Condition DDPM*

# %%
# n_window mean batch size
n_window, window, n_assets, n_features = batch["x"].shape
n_window, window, n_assets, n_conds = batch["x_cond"].shape
ddpm_transformer['n_cond'] = n_conds

print(n_assets, n_features, n_conds)

input_channels = n_assets * n_features
cond_channels = n_assets * n_conds
print(input_channels, cond_channels)
# Out:
# 14 1 6
# 14 84

# %%
model = DiffusionTransformer(
    n_features=input_channels,
    n_cond=cond_channels,        
    window_size=window_size,             
    d_model=ddpm_transformer['d_model'],                
    nhead=ddpm_transformer['nhead'],
    num_layers=ddpm_transformer['num_layers'],
    dim_feedforward=ddpm_transformer['dim_feedforward'],
    dropout=ddpm_transformer['dropout']
).to(device)

# %%
diffusion = Diffusion(model, timesteps=ddpm['timesteps'], beta_start=ddpm['beta_start'], beta_end=ddpm['beta_end']).to(device)

# %%
optimizer = AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

# %%
engine = Engine(
    train_dataloader=train_loader,
    val_dataloader=val_loader,
    model=diffusion,
    scaler=scaler,
    optimizer=optimizer,
    device=device,
    file_name=f"ddpm_transformer_d{ddpm_transformer['d_model']}_l{ddpm_transformer['num_layers']}",
)

# %%
ckpt_name = "ddpm_transformer_d64_l64_e1000.pt"
engine.load_checkpoint(ckpt_name)
# Out:
# /home/narodom.y@FUSION.LAB/research/src/engine/trainer.py:170: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=self.device)
# INFO:engine.trainer:Loaded model weights from ddpm_transformer_d64_l64_e1000.pt

# %%
batch = next(iter(test_loader))
batch_expand = engine.expand_batch_with_n_sample(batch, 10)
dates = engine.transform_dates(batch['dates'][-sim_steps:])

_, sim_genai, x, x_cond = engine.ar_simulate(batch_expand['x'], batch_expand['x_cond'], steps=sim_steps)
sim_genai.shape
# Out:
# Start Auto-regression: Initial W=48, Target Steps=16
# window size 48...:   0%|          | 0/16 [00:00<?, ?it/s]
# ERROR! Session/line number was not unique in database. History logging moved to new session 218
# window size 63...: 100%|██████████| 16/16 [09:03<00:00, 33.99s/it]
# (10, 16, 14, 1)

# %%
x, x_coond, _, _ = engine.transform_batch(batch)
batch_stat = {
    "x": torch.as_tensor(x).to(device),
    "x_cond": torch.as_tensor(x_cond).to(device)
}
sim_stat = engine.gbm_simulate(batch_stat, sim_steps, 10)
sim_stat.shape
# Out:
# (10, 16, 14, 1)

# %%
x.shape
# Out:
# (1, 64, 14, 1)

# %%
x.shape
# Out:
# (1, 64, 14, 1)

# %%
gt = x[0, -sim_steps:, :, :].squeeze(-1)
gt_cond = x_cond[0, -sim_steps:, :, :]
# sim_genai = sim_genai.squeeze(-1)
sim_stat = sim_stat.squeeze(-1)

# %%
# engine.eval(test_loader, steps= sim_steps, n_samples=num_sims, context_file=f"d{ddpm_transformer['d_model']}_l{ddpm_transformer['num_layers']}_")

# %%
engine.benchmark(gt, sim_genai, sim_stat, dates, is_calc_distribution=True, filename="Boring_bro_ar")
# Out:
# DEBUG:engine.trainer:Mu_genai: (14,), Sigma_genai: (14, 14)
# DEBUG:engine.trainer:Mu_stats: (14,), Sigma_stats: (14, 14)
# DEBUG:engine.trainer:weights_genai: (14,)
# DEBUG:engine.trainer:weights_stats: (14,)
# DEBUG:entities.portfolio:Returns: (16, 14), Weights: (14,)
# DEBUG:entities.portfolio:Max Log Return: 0.0572
# DEBUG:entities.portfolio:Min Log Return: -0.0400
# DEBUG:entities.portfolio:Max Log Return Benchmark: 0.0462
# DEBUG:entities.portfolio:Min Log Return Benchmark: -0.0484
# Generating QuantStats Report...
# Report saved to /home/narodom.y@FUSION.LAB/research/results/reports/quantstats/Boring_bro_ar
#                      Strategy
# Start Period       2024-10-22
# End Period         2024-11-12
# Risk-Free Rate              0
# Time in Market            1.0
# Cumulative Return        0.08
# ...                       ...
# Avg. Down Month             -
# Win Days                 0.69
# Win Month                 1.0
# Win Quarter               1.0
# Win Year                  1.0
#
# [75 rows x 1 columns]

# %%
r = engine.inspect_simulation(gt,gt_cond, sim_genai.mean(axis=0), sim_stat.mean(axis=0), filename="helllow_ar", is_saved=True)
r
# def inspect_simulation(
#         self,
#         gt,
#         gt_cond,
#         sim_genai,
#         sim_stats,
#         sim_idx: Optional[int] = None,
#         save_dir: Optional[str] = REPORTS_SIM_DIR,
#         filename: Optional[str] = "sim",
#         is_saved: bool = False
#     ):
# Out:
# DEBUG:engine.trainer:
# gt: (16, 14)
# gt_cond: (16, 14, 6)
# sim_genai: (16, 14)
# sim_stats: (16, 14)
# {'idx': -1,
#  'metrics': {'Ground Truth Mean Return': '0.0038',
#   'GenAI Mean Return': '-0.1450',
#   'Statistic Mean Return': '0.0023',
#   'Ground Truth Volatility': '0.0281',
#   'GenAI Volatility': '1.7272',
#   'Statistic Volatility': '0.0067'},
#  'plots': {'Ground Truth Correlation': '...',
#   'GenAI Correlation': '...',
#   'Statistic Correlation': '...'},
#  'data': {'gt': array([[ 7.98186101e-03, -3.65363294e-03,  5.24472259e-03,
#            2.60736756e-02,  8.74070171e-03, -5.58757340e-04,
#            9.63887759e-03, -6.11010520e-03, -1.18003052e-03,
#           -1.27196098e-02, -1.23409983e-02,  1.06924567e-02,
#            1.19132418e-02, -1.45312194e-02],
#          [-7.42399879e-03, -2.95231759e-04,  5.08404113e-02,
#           -4.97328350e-03,  1.39933759e-02,  4.66978503e-03,
#            1.29337059e-02,  1.82954744e-02, -4.62644687e-03,
#            9.03957430e-03, -1.88922435e-02, -8.07810016e-03,
#           -2.02510860e-02, -7.73492455e-03],
#          [-3.93184498e-02, -1.27331968e-02, -1.62956230e-02,
#           -2.47634947e-02, -2.96483301e-02, -4.68298420e-02,
#           -2.91853286e-02, -5.23747653e-02, -3.05110328e-02,
#           -2.32553724e-02, -2.39173714e-02, -1.71413794e-02,
#           -4.97406721e-03, -2.00140327e-02],
#          [-1.82197930e-03,  1.23948425e-01,  4.68614540e-04,
#            1.53198850e-03,  4.47311759e-04,  1.53732458e-02,
#            1.62678922e-03,  1.07904105e-02, -1.09601598e-02,
#            7.46367220e-03,  1.05879223e-02, -9.13783908e-04,
#            5.23183262e-03, -2.00836286e-02],
#          [ 5.87170525e-03,  1.48566458e-02,  1.83147900e-02,
#            3.01020779e-03,  3.23540643e-02,  1.32187568e-02,
#            3.07421014e-02,  1.43238949e-02,  9.38805752e-03,
#           -1.10768629e-02,  1.77686270e-02,  7.49694789e-03,
#            1.86336674e-02, -1.57802235e-02],
#          [ 1.45363351e-02, -1.66437197e-02, -9.52277053e-03,
#           -8.98481533e-03,  1.75251532e-02,  4.73774830e-03,
#            1.59880854e-02,  1.25822229e-02, -4.91299853e-03,
#           -1.32327434e-02,  1.52398730e-02, -2.80454918e-03,
#            2.36092489e-02, -2.59678308e-02],
#          [ 6.91550318e-04, -8.89322907e-03,  2.76540611e-02,
#            1.24279712e-03,  3.53955068e-02,  2.20709126e-02,
#            3.31200883e-02,  3.95766124e-02,  3.73046659e-02,
#            6.56179758e-03,  2.50562523e-02,  1.78075675e-02,
#            3.82362343e-02,  1.26182083e-02],
#          [-2.92095821e-02, -6.64711185e-03,  1.13652507e-03,
#           -1.42924096e-02,  5.53825721e-02,  1.64019559e-02,
#            5.72440811e-02, -7.29809143e-03, -1.35917403e-02,
#            7.63490377e-03, -1.90232731e-02,  8.27682298e-03,
#           -9.11624655e-02, -8.97285435e-03],
#          [-3.44956480e-02, -1.98573526e-02, -1.16516933e-01,
#           -4.20217663e-02, -4.06901911e-02, -5.79587221e-02,
#           -4.10722867e-02, -6.31829724e-02, -3.45720351e-02,
#           -6.25547618e-02, -3.31627913e-02, -2.17124447e-02,
#           -2.00506225e-02, -3.97146419e-02],
#          [-2.41008829e-02, -3.06156743e-03,  1.88797042e-02,
#            1.52133116e-02, -8.97376100e-04,  8.07863325e-02,
#           -3.20942979e-03, -5.85546368e-04, -2.93756952e-03,
#            1.78653188e-02,  1.58601627e-02,  1.88465901e-02,
#           -7.72046391e-03,  2.67754663e-02],
#          [-4.82180296e-03, -1.62136797e-02, -4.23932541e-03,
#            2.97577586e-03, -2.45331191e-02, -1.57061368e-02,
#           -2.34371051e-02, -1.54724512e-02, -3.88159766e-04,
#           -4.25065402e-03,  1.52835846e-02, -1.09526693e-04,
#           -1.79847272e-03,  9.59460065e-03],
#          [ 1.63600240e-02,  2.10840628e-02,  1.46671645e-02,
#            2.16977466e-02,  3.87988309e-03,  1.98564678e-02,
#            6.29151287e-03,  2.90761311e-02,  2.94006635e-02,
#            1.74643882e-02, -7.28297886e-03,  1.94324031e-02,
#            1.04302652e-02,  9.51058045e-03],
#          [-3.89038026e-03,  7.69032612e-02,  3.56227718e-02,
#            3.13034281e-02,  6.42835945e-02,  4.07111347e-02,
#            6.50676042e-02, -1.01407280e-03,  3.00411955e-02,
#            6.96043223e-02,  4.66641635e-02,  5.57557605e-02,
#            2.46220250e-02,  6.22144900e-02],
#          [ 4.37323004e-02,  1.08435107e-02,  2.08771229e-02,
#            1.52536882e-02,  3.52909230e-02,  1.16339484e-02,
#            3.19075435e-02,  4.33678217e-02,  2.13270299e-02,
#            3.17502245e-02,  1.42606422e-02, -9.68901441e-03,
#            3.12766992e-02,  5.12149942e-04],
#          [-1.50708144e-03,  3.67903933e-02, -1.10861566e-02,
#           -1.16743995e-02, -2.68710665e-02, -1.58677883e-02,
#           -2.68209651e-02, -6.93210261e-03, -3.30948550e-03,
#            1.40855992e-02,  4.90819775e-02, -1.60768963e-02,
#           -8.77848733e-03, -8.07707291e-03],
#          [-2.20554229e-02,  4.04438972e-02, -1.75250415e-02,
#           -1.83948614e-02,  1.27496077e-02, -1.27422158e-02,
#            1.35554317e-02, -1.51323155e-02, -2.76629794e-02,
#           -7.82950502e-03,  8.29496980e-02,  2.78666411e-02,
#           -1.15681544e-03,  1.43863987e-02]], dtype=float32),
#   'gt_cond': array([[[-1.18467120e-04,  2.15259055e-03,  5.10804253e+01,
#             1.34373060e-03,  7.99642701e-04,  5.44087903e-04],
#           [-4.31548950e-04, -6.60565775e-03,  4.73603058e+01,
#            -2.50593037e-03, -3.87541880e-03,  1.36948831e-03],
#           [ 5.06750355e-03, -1.71281444e-03,  4.96760559e+01,
#             4.04678343e-04, -6.87519641e-05,  4.73430351e-04],
#           ...,
#           [-1.60359184e-03, -2.91799381e-03,  4.88585014e+01,
#             6.62103528e-04,  4.91585932e-04,  1.70517553e-04],
#           [-4.97951452e-03,  3.67351982e-04,  4.90991287e+01,
#            -2.17544660e-03, -2.83944444e-03,  6.63997664e-04],
#           [ 5.06309734e-04,  4.40286752e-03,  5.20108986e+01,
#             8.80610023e-04,  1.14222313e-03, -2.61613022e-04]],
#
#          [[-4.40761680e-03,  1.82520063e-03,  5.08423271e+01,
#             7.10925087e-04,  7.81899143e-04, -7.09740634e-05],
#           [-3.99687933e-03, -7.64700677e-03,  4.74184952e+01,
#            -2.09822156e-03, -3.51997931e-03,  1.42175774e-03],
#           [-1.05613458e-03, -1.88222446e-04,  5.05325394e+01,
#             2.00133165e-03,  3.45264707e-04,  1.65606686e-03],
#           ...,
#           [-3.21714650e-03, -3.02034384e-03,  4.85568542e+01,
#            -9.71107602e-06,  3.91326554e-04, -4.01037629e-04],
#           [-1.24725606e-03, -1.34089356e-03,  4.81490860e+01,
#            -3.73702589e-03, -3.01896082e-03, -7.18065479e-04],
#           [-7.97390298e-04,  4.09856252e-03,  5.17999382e+01,
#             3.66703287e-04,  9.87119158e-04, -6.20415783e-04]],
#
#          [[ 2.83231057e-04,  9.58320277e-04,  4.98322220e+01,
#            -1.32739788e-03,  3.60039761e-04, -1.68743765e-03],
#           [ 4.46594544e-02, -9.17565357e-03,  4.68105698e+01,
#            -3.03036906e-03, -3.42205749e-03,  3.91688169e-04],
#           [ 5.35146333e-04, -8.66591232e-04,  5.01728897e+01,
#             1.03874598e-03,  4.83960961e-04,  5.54785016e-04],
#           ...,
#           [-5.28355071e-04, -3.25272651e-03,  4.79849777e+01,
#            -1.11319625e-03,  9.04219924e-05, -1.20361825e-03],
#           [ 1.23843260e-03, -2.87020020e-03,  4.79810219e+01,
#            -3.58269154e-03, -3.13170697e-03, -4.50984866e-04],
#           [-8.04583717e-04,  3.69414198e-03,  5.13675232e+01,
#            -5.06504788e-04,  6.88394357e-04, -1.19489909e-03]],
#
#          ...,
#
#          [[ 2.01776536e-04, -3.35194345e-04,  4.96547050e+01,
#             5.19556343e-04, -1.17232255e-03,  1.69187901e-03],
#           [ 1.80151127e-02,  1.08289812e-02,  5.73218613e+01,
#             1.06360419e-02,  4.72489558e-03,  5.91114676e-03],
#           [-1.05304341e-03,  1.13675708e-03,  5.03382607e+01,
#             1.68661808e-03, -1.21508601e-04,  1.80812681e-03],
#           ...,
#           [-2.32829992e-03, -2.57807376e-04,  5.04009132e+01,
#             2.90515204e-03,  1.54915848e-03,  1.35599356e-03],
#           [-2.33385316e-03, -4.54204809e-03,  4.91760635e+01,
#             2.38695415e-03, -2.02436629e-03,  4.41132020e-03],
#           [ 3.90074885e-04,  4.04711021e-03,  5.17178955e+01,
#             1.64306920e-03,  5.68522883e-05,  1.58621697e-03]],
#
#          [[-2.23156065e-03, -7.00677119e-05,  4.96117210e+01,
#             3.55325348e-04, -8.66792980e-04,  1.22211839e-03],
#           [ 1.96004696e-02,  1.93038769e-02,  5.98490677e+01,
#             1.41285509e-02,  6.60562608e-03,  7.52292341e-03],
#           [-1.93659088e-03,  7.40887772e-04,  4.99976883e+01,
#             8.01175600e-04,  6.30282520e-05,  7.38147355e-04],
#           ...,
#           [ 4.84120008e-03, -6.99782468e-05,  4.98180962e+01,
#             1.40125747e-03,  1.51957828e-03, -1.18320866e-04],
#           [-4.39233059e-04, -6.27585873e-03,  4.87088699e+01,
#             1.13588118e-03, -1.39231666e-03,  2.52819806e-03],
#           [ 2.64534773e-03,  3.37564130e-03,  5.15133018e+01,
#             1.02638034e-03,  2.50757905e-04,  7.75622379e-04]],
#
#          [[ 4.66887170e-04, -1.48306065e-03,  4.91219902e+01,
#            -6.47915702e-04, -8.23017559e-04,  1.75101799e-04],
#           [-1.36762839e-02,  2.32567936e-02,  6.24293137e+01,
#             1.72709934e-02,  8.73869937e-03,  8.53229500e-03],
#           [ 3.12880496e-03, -1.29821885e-04,  4.95258484e+01,
#            -2.17764362e-04,  6.86972680e-06, -2.24634103e-04],
#           ...,
#           [ 9.95957386e-03, -5.02172508e-04,  5.06191254e+01,
#             2.77189584e-03,  1.77004177e-03,  1.00185408e-03],
#           [-5.23485569e-03, -5.69645362e-03,  4.86372032e+01,
#             8.20547401e-04, -9.49743902e-04,  1.77029136e-03],
#           [ 7.70919898e-04,  3.84259364e-03,  5.17460442e+01,
#             1.33834151e-03,  4.68274637e-04,  8.70066928e-04]]],
#         shape=(16, 14, 6), dtype=float32),
#   'sim_genai': array([[-6.48573875e-01, -3.07403302e+00, -1.92320955e+00,
#           -3.37821007e+00,  1.78808439e+00,  3.02994817e-01,
#           -2.13660479e+00, -1.45431721e+00, -1.24949956e+00,
#           -1.98390603e+00, -2.63689470e+00,  1.56339121e+00,
#           -4.52605188e-01,  1.26847005e+00],
#          [-1.40849984e+00, -1.21211720e+00, -1.17073488e+00,
#            3.89176226e+00, -1.77354097e-01, -5.75924516e-01,
#            3.29367071e-01, -8.82609189e-01, -3.51073563e-01,
#           -2.94745326e+00, -3.76494229e-01, -3.84589076e-01,
#            6.51239574e-01,  8.81102681e-01],
#          [-2.11879873e+00, -2.21361065e+00,  1.67065907e+00,
#           -2.39810967e+00,  1.77585733e+00,  1.72094119e+00,
#           -1.18092918e+00, -2.13632655e+00, -2.29226589e+00,
#           -6.63284600e-01,  1.74343896e+00, -3.93200731e+00,
#            6.27486110e-01,  1.50938773e+00],
#          [-7.99348235e-01,  1.14321637e+00, -9.94298100e-01,
#           -1.49671280e+00,  1.59236777e+00,  7.29200393e-02,
#            1.07357788e+00,  4.45378363e-01, -7.16482043e-01,
#           -4.24408531e+00,  1.12104154e+00, -2.09589624e+00,
#            1.03617573e+00,  1.18642843e+00],
#          [-1.60817075e+00, -2.83033490e+00,  1.44181573e+00,
#            1.39086032e+00, -7.39613175e-01,  1.47220802e+00,
#            9.53827262e-01, -2.32112265e+00, -3.56618690e+00,
#           -1.65873140e-01,  4.71092075e-01, -2.23116970e+00,
#            2.82036066e+00,  3.54407763e+00],
#          [-1.32906288e-01, -3.27816200e+00, -2.57173657e+00,
#            1.42044976e-01, -8.33175063e-01, -2.31778979e+00,
#            1.01998258e+00, -1.74075508e+00,  1.96595550e+00,
#            2.93021314e-02,  1.87080646e+00, -2.87638712e+00,
#            1.52802467e+00,  8.44548881e-01],
#          [-2.60133839e+00, -5.73767424e-02, -7.68439412e-01,
#           -3.90058756e-01,  5.04333138e-01,  1.21452010e+00,
#           -9.08628941e-01,  1.42227077e+00, -1.44550967e+00,
#           -1.49107194e+00,  1.37315810e+00, -2.33870840e+00,
#           -1.72804981e-01, -1.13161719e+00],
#          [ 7.22649455e-01,  3.20717804e-02,  2.03761673e+00,
#            2.08035684e+00,  2.78262901e+00, -1.16073325e-01,
#            4.47432131e-01, -1.45091283e+00,  1.91460633e+00,
#            1.46244740e+00, -8.62476826e-01, -1.41874397e+00,
#            3.46945554e-01,  1.15533268e+00],
#          [ 2.42591810e+00,  3.53388791e-03,  1.95840120e-01,
#           -1.79125190e-01,  2.91438246e+00, -1.52805448e+00,
#            7.39599407e-01,  1.83916414e+00,  1.77970922e+00,
#           -2.32214189e+00, -7.68199563e-01,  2.43183756e+00,
#            1.02717948e+00, -4.11400497e-01],
#          [-3.45874548e+00, -1.68117568e-01, -3.43222618e-01,
#            1.64865136e+00,  3.04047346e+00, -8.90750110e-01,
#           -6.52660668e-01, -2.93053818e+00,  5.43460071e-01,
#           -3.91003156e+00, -1.86550272e+00,  7.64222145e-01,
#           -5.57753921e-01,  1.57391503e-01],
#          [ 1.13712430e+00,  1.02953434e+00, -5.60070753e-01,
#           -9.11577404e-01,  1.88794780e+00, -2.34981680e+00,
#            3.01998377e+00, -2.09885836e+00,  4.71843815e+00,
#           -2.54384375e+00,  2.09349006e-01,  2.47794199e+00,
#           -3.08012414e+00, -2.52366686e+00],
#          [ 1.12224674e+00,  2.23608255e+00, -1.11481702e+00,
#            2.48723650e+00, -9.33477104e-01, -5.95340133e-01,
#           -2.91343904e+00, -1.95058250e+00,  2.83690429e+00,
#            8.15034509e-01, -4.91861492e-01, -1.09545112e+00,
#           -1.34495258e+00, -2.89082885e-01],
#          [-9.85012650e-01,  2.70246625e-01, -2.10036281e-02,
#            1.72228789e+00, -2.13267398e+00, -1.29180586e+00,
#            1.24191213e+00,  2.58126885e-01, -4.64876032e+00,
#            1.89032042e+00, -2.23966265e+00,  1.43404055e+00,
#            7.60598660e-01,  9.28941846e-01],
#          [ 1.53319097e+00,  1.17664361e+00,  9.57816005e-01,
#           -5.54373741e-01,  2.05404377e+00, -6.15907669e-01,
#            1.86779594e+00,  8.37907195e-01, -1.10427785e+00,
#           -2.89203310e+00, -7.05864787e-01,  2.07972622e+00,
#           -2.51686263e+00, -3.53398263e-01],
#          [ 8.74831975e-01, -2.73348570e-01,  5.83210289e-01,
#            2.94452834e+00, -1.95163250e+00, -2.82229900e-01,
#            2.55424643e+00, -2.70447898e+00, -3.53992999e-01,
#            3.03099394e+00, -1.73975813e+00,  1.27720034e+00,
#           -7.96197772e-01, -2.81062633e-01],
#          [ 3.14700782e-01, -2.86112666e+00, -3.04090977e+00,
#            6.02860808e-01,  1.21880841e+00, -1.38213825e+00,
#            3.63396764e-01,  1.58405435e+00,  1.37082174e-01,
#           -1.23957229e+00,  8.45969677e-01,  4.70684052e+00,
#           -6.79786921e-01,  1.06672622e-01]], dtype=float32),
#   'sim_stats': array([[-3.37160868e-03, -2.48170178e-03,  5.48885437e-03,
#            1.17812934e-03,  4.94468119e-03,  1.24887666e-02,
#            1.12009887e-02, -2.28014379e-03,  2.46565067e-03,
#            9.94504802e-03,  5.10881143e-03, -2.42643082e-03,
#           -3.76005238e-03, -2.00418336e-03],
#          [ 5.99949900e-03,  5.65600768e-03,  6.80848584e-03,
#           -4.28705767e-04,  2.61676591e-03,  5.21596149e-03,
#            9.76625364e-03,  1.67519657e-03, -1.04835117e-03,
#            2.92080501e-03,  2.46451003e-03, -1.16272038e-03,
#           -7.83345476e-03,  4.40902635e-03],
#          [ 2.15501012e-03, -2.93365726e-03,  6.71038311e-03,
#            9.60370712e-03,  4.75790771e-03, -1.50553212e-02,
#            1.47505207e-02, -8.87349062e-03,  1.02583123e-02,
#            4.33255732e-03, -4.37877700e-03,  3.40215606e-03,
#            7.32671760e-04, -1.92826462e-03],
#          [-2.24208320e-03, -4.24837321e-03,  4.75787139e-03,
#            5.89394523e-03, -8.12167116e-03,  2.08320050e-03,
#           -3.81662766e-03, -5.27944183e-03, -2.58628326e-03,
#            1.11120846e-02, -2.28951615e-03, -2.14668131e-03,
#           -5.56019600e-03,  2.42801365e-02],
#          [ 5.58900740e-03, -6.18868601e-03,  9.10807867e-03,
#           -3.63237294e-03,  7.09895929e-03,  1.26976389e-02,
#           -1.78973691e-03, -2.47084023e-03,  1.26091270e-02,
#            5.44675905e-03, -1.18812285e-02,  4.18591360e-03,
#            5.27621666e-03, -1.12659764e-02],
#          [ 1.49877160e-03,  9.87751875e-03,  1.22568524e-03,
#            1.28470715e-02, -1.02644763e-03,  4.66032885e-03,
#            1.51401712e-02, -1.92757917e-03, -4.14325017e-03,
#            3.61208012e-03,  2.72538755e-02,  2.59544849e-02,
#           -1.27503788e-03, -2.49071396e-03],
#          [ 2.58303073e-04, -4.91930870e-03, -4.25930414e-03,
#           -4.34259942e-04, -2.99152685e-03,  3.41015635e-03,
#            7.50425085e-03,  1.47620426e-03,  7.91590847e-03,
#            1.30357714e-02, -5.03005367e-03, -2.68873945e-03,
#            3.48148635e-03,  9.67108086e-03],
#          [-3.39822541e-03,  1.82505581e-03, -1.61875971e-03,
#            7.86773767e-03, -3.54245608e-03, -8.95249378e-03,
#            3.22782760e-03,  7.30434258e-04,  1.62542681e-03,
#            1.27966851e-02,  1.45330904e-02,  3.83233232e-03,
#            1.14028323e-02,  9.81389731e-03],
#          [ 6.58906414e-04, -5.73258800e-03,  1.19822077e-03,
#           -3.18819890e-03,  1.85631064e-03, -4.17057937e-03,
#            4.40062396e-03,  9.01930965e-03,  3.75481625e-03,
#            1.22287357e-02,  1.59340836e-02,  4.44484118e-04,
#            6.99702883e-03,  2.93949805e-03],
#          [ 8.38283231e-05,  9.95032303e-03, -1.22560645e-02,
#           -8.00814480e-04,  4.69329488e-03, -3.77740385e-03,
#            4.42190189e-03,  6.44064334e-04,  8.44813138e-03,
#           -1.03209382e-02, -6.41485327e-04,  2.16025440e-03,
#            2.75793672e-03,  7.44981971e-03],
#          [-7.38135632e-03, -3.78161552e-03,  1.16206789e-02,
#            1.97990419e-04, -3.51325306e-03,  6.48287404e-03,
#           -2.22223112e-03, -5.42587275e-03, -3.27896629e-03,
#            5.41564915e-03, -6.70712302e-03, -1.10337157e-02,
#            6.51362678e-03,  1.34784486e-02],
#          [ 3.60035966e-03, -3.96809028e-03, -1.15786577e-02,
#            1.96676192e-04,  3.27481329e-03, -5.14544407e-03,
#            1.01019377e-02,  5.63777937e-03,  3.27914022e-03,
#           -7.05550890e-03,  8.14469345e-03, -5.52278431e-03,
#           -2.50517833e-03,  1.38110593e-02],
#          [ 1.05275977e-02, -2.49659200e-03,  1.70507915e-02,
#           -2.33426268e-04, -1.05473027e-02,  4.94821556e-03,
#           -5.39741199e-03,  5.82652818e-03,  6.91461959e-04,
#            7.84001895e-04,  6.14421722e-03, -8.93481635e-03,
#            6.76859636e-03,  7.89205916e-03],
#          [-2.65721441e-03,  5.84947178e-03,  8.70189443e-03,
#           -2.27324618e-03,  5.76085132e-03,  2.91395443e-03,
#            3.41144647e-03, -6.18222868e-03,  4.16094717e-03,
#           -2.76343198e-03, -3.93485592e-04,  1.02869822e-02,
#            7.30470708e-03,  1.90567446e-03],
#          [ 3.26727703e-03, -6.95270661e-04, -8.65813717e-03,
#            3.85545869e-03, -1.34486426e-02,  5.39344316e-03,
#            3.74304887e-04,  3.97134060e-03,  9.93239693e-03,
#            5.51750232e-03,  1.09854145e-02,  1.22813787e-02,
#            2.00357521e-04,  9.65212099e-03],
#          [ 5.27953869e-03,  8.61748122e-03,  1.15721999e-02,
#           -8.13261577e-05, -8.81127920e-03,  5.42049110e-03,
#            2.21677753e-03,  1.75400660e-03,  1.81971141e-03,
#           -1.12192216e-03, -2.65150005e-03, -5.50154131e-03,
#            3.96629842e-03,  3.28414585e-03]], dtype=float32)}}
